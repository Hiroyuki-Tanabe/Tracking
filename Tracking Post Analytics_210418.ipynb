# %% [markdown]
# ## Import Packages

# %%
import os
import json
import datetime
import urllib.error
import urllib.parse
import urllib.request

import pytz
import ipywidgets
import ipydatetime

import matplotlib.pyplot as plt
import pandas as pd

from functools import reduce

# from here_map_widget import Map, GeoJSON, Marker
from ipyleaflet import Map, GeoJSON, Marker, TileLayer
from ipyleaflet.external.here import basemap_to_tiles, basemaps

import folium
from folium import plugins

from decimal import Decimal, ROUND_HALF_UP, ROUND_DOWN

# pd.set_option('max_rows', 10)
pd.set_option('max_rows', None)

# %% [markdown]
# ## Define Functions

# %%
def tracking_login(email, password):
    url = 'https://tracking.api.here.com/users/v2/login'
    headers = {'Content-Type': 'application/json'}
    body = dict(email=email, password=password)
    data = json.dumps(body).encode()
    print(url)
    req = urllib.request.Request(url, headers=headers, data=data, method='POST')
    with urllib.request.urlopen(req) as res:
        data = res.read()
        return json.loads(data).get('accessToken')
    
    
def tracking_get_device_list(access_token, **kwargs):
    base_url = f'https://tracking.api.here.com/users/v2/devices'
    params = urllib.parse.urlencode(dict(**kwargs))
    url = f'{base_url}?{params}'
    headers = {
        'Authorization': f'Bearer {access_token}',
        'Content-Type': 'application/json',
    }
    print(url)
    req = urllib.request.Request(url, headers=headers)
    with urllib.request.urlopen(req) as res:
        data = res.read()
        return json.loads(data).get('data')

    
def tracking_get_shadow(access_token, tracking_id, **kwargs):
    base_url = f'https://tracking.api.here.com/shadows/v2/{tracking_id}'
    params = urllib.parse.urlencode(dict(**kwargs))
    url = f'{base_url}?{params}'
    headers = {
        'Authorization': f'Bearer {access_token}',
        'Content-Type': 'application/json',
    }
    print(url)
    req = urllib.request.Request(url, headers=headers)
    with urllib.request.urlopen(req) as res:
        data = res.read()
        return json.loads(data)
    

def tracking_get_trace(access_token, tracking_id, **kwargs):
    base_url = f'https://tracking.api.here.com/traces/v2/{tracking_id}'
    params = urllib.parse.urlencode(dict(**kwargs))
    url = f'{base_url}?{params}'
    headers = {
        'Authorization': f'Bearer {access_token}',
        'Content-Type': 'application/json',
    }
    print(url)
    req = urllib.request.Request(url, headers=headers)
    with urllib.request.urlopen(req) as res:
        data = res.read()
        return json.loads(data)

# %%
def match_route(apikey, mode, trace, **kwargs):
    base_url = 'https://fleet.ls.hereapi.com/2'
    resource_uri = 'calculateroute.json'
    headers = {'Content-Type': 'text/plain'}
    params = urllib.parse.urlencode(dict(routeMatch=1, apiKey=apikey, mode=mode, **kwargs))
    data = trace.encode()
    url = f'{base_url}/{resource_uri}?{params}'
    print(url)
    req = urllib.request.Request(url, headers=headers, data=data, method='POST')
    try:
        with urllib.request.urlopen(req) as res:
            data = res.read()
            return json.loads(data)
    except urllib.error.HTTPError as e:
        print(e, e.reason, e.code, e.read())

# %% [markdown]
# ## Define Variables

# %%
TRACKING_EMAIL = 'xxx'
TRACKING_PASSWORD = 'xxx'
APIKEY = 'xxx'

project_id = 'xxx'
device_id = 'xxx'

# %% [markdown]
# ## User Login

# %%
access_token = tracking_login(TRACKING_EMAIL, TRACKING_PASSWORD)
access_token
# Out:
# https://tracking.api.here.com/users/v2/login
# 'h1.hPdNtW48uiT0ZZPswKoT8Q.nu1YbCljOuT-0lpXieAKv--u5rMou383j7AGCgGcDEz7p822AKBRj0zxtx9L-vOgrR9nQfiM6ebvVQPssNWqyEdiukg0gdfIkeusO1Z-Y0QKG67laXsK5ig1oxO4pZGmQJZ8QP9-kHd4Pa4oJEFVNFOrzqgFPLHMHK19jaYn_aGpHPffVBNpFSX68UsuExUt0s5VCWDLIsnmt82qncE1gRn66r8TcAU04z2JazmgsZsHjVeXuXvsc_Y4pMgAbjnWYZwvWudEdw-LRQ1hIcafeWtxDQwthFZzErLOQUkow9ybDlL7_QusgHkO24JYO1ciozaHa7_SHuAPTGDVd3DDTXgG6jOHxy_UwVOEN2V_Qyjxbh63vkOT6Wc24Uh-XubOQwK10e8zdDnYUGqwqBVa4He6GsBDRairEji4sefwoM-_pFFiqU-jUKbMm96BkJakUrohriBmOssUlc8b7jDznw.TNPr8v1UW1kDaJH7LwpH7i71OOHGvSSCdjTDxPP6qjChA57yJ2zXmgYLhWSpVxsk_xWnkP09Ph1yxXBvE9uPdKjLtZo5F-zVjkX7XRoqSo5huFk8X4PEbUmPXmAvsaK-8FJfzO7sm-5rn6LlSnx_G8jhrRttbxZPl7Mjh61NuqGMRTxQVJIPYEHmEQmla105rGwv6I4JB2Rbw9yFFMo_x2rpCJM7CasM2k5_xl9k9YDqEeloC5XKkaclMXf-DydlBqIMdV42cD2S6LaOwAdOg4zJwos9nlXbmxyEZerb_G3xPYSE-LVU-rJekTAvJeEO7Oy61KXHNu9fMuuNaFzvnA'

# %% [markdown]
# ## Get user's list of devices

# %%
device_list = tracking_get_device_list(access_token, projectId=project_id)
device_list
# Out:
# https://tracking.api.here.com/users/v2/devices?projectId=CUST-7d3d712c-e368-40a3-892d-b572d4491874
# [{'shadow': {'desired': {'payload': {'refAppData': {'icon': 'GENERIC',
#       'name': '田邊私用端末'}},
#     'system': {'stateVersion': 5,
#      'rate': {'sendMs': 300000, 'sampleMs': 60000, 'distanceM': 0},
#      'lastModifiedGeofenceTimestamp': 0},
#     'timestamp': 1610955861383},
#    'reported': {'payload': {'refAppData': {'icon': 'GENERIC',
#       'name': '田邊私用端末',
#       'nwpos': True}},
#     'system': {'stateVersion': 77248,
#      'client': {'name': 'HERE Tracker',
#       'model': 'Pixel 3a',
#       'version': '1.1.5',
#       'firmware': 'RQ2A.210305.006',
#       'platform': 'android',
#       'manufacturer': 'Google'},
#      'computed': {'moving': False,
#       'lastMovedTimestamp': 1615505721620,
#       'online': True},
#      'reportedSensorData': {'batteryLevel': 80, 'batteryIsCharging': False}},
#     'timestamp': 1615513740731,
#     'position': {'alt': 145,
#      'lat': 35.6799996,
#      'lng': 139.764204,
#      'type': 'cell',
#      'accuracy': 2026,
#      'altaccuracy': 710}}},
#   'trackingId': 'HERE-230a4588-74b8-479e-b4ea-73344b2200d6'},
#  {'shadow': {'desired': {'payload': {'refAppData': {'icon': 'GENERIC',
#       'name': 'msk-poc-1'}},
#     'system': {'stateVersion': 11,
#      'rate': {'sendMs': 86400000, 'sampleMs': 86400000, 'distanceM': 0},
#      'lastModifiedGeofenceTimestamp': 0},
#     'timestamp': 1612424743157},
#    'reported': {'payload': {'refAppData': {'icon': 'GENERIC',
#       'name': 'msk-poc-1',
#       'nwpos': True}},
#     'system': {'stateVersion': 6351,
#      'client': {'name': 'HERE Tracker',
#       'model': 'SO-01H',
#       'version': '1.1.5',
#       'firmware': '32.1.F.0.43',
#       'platform': 'android',
#       'manufacturer': 'Sony'},
#      'computed': {'online': False},
#      'reportedSensorData': {'batteryLevel': 1, 'batteryIsCharging': False}},
#     'timestamp': 1610541631792,
#     'position': {'alt': 40,
#      'lat': 35.3374922,
#      'lng': 139.4996953,
#      'type': 'cell',
#      'accuracy': 599,
#      'altaccuracy': 155}}},
#   'trackingId': 'HERE-7c0af8ad-39cf-4c73-97ca-211fe03557f4'},
#  {'shadow': {'desired': {'payload': {'refAppData': {'icon': 'GENERIC',
#       'name': 'msk-poc-2'}},
#     'system': {'stateVersion': 7,
#      'rate': {'sendMs': 86400000, 'sampleMs': 86400000, 'distanceM': 0},
#      'lastModifiedGeofenceTimestamp': 0},
#     'timestamp': 1612424729047},
#    'reported': {'payload': {'refAppData': {'icon': 'GENERIC',
#       'name': 'msk-poc-2',
#       'nwpos': True}},
#     'system': {'stateVersion': 11728,
#      'client': {'name': 'HERE Tracker',
#       'model': 'SO-04H',
#       'version': '1.1.5',
#       'firmware': '41.3.B.1.82',
#       'platform': 'android',
#       'manufacturer': 'Sony'},
#      'computed': {'moving': False,
#       'lastMovedTimestamp': 1611277695977,
#       'online': False},
#      'reportedSensorData': {'batteryLevel': 100, 'batteryIsCharging': True}},
#     'timestamp': 1611502595475,
#     'position': {'lat': 35.6241593,
#      'lng': 139.899401,
#      'type': 'wlan',
#      'accuracy': 36}}},
#   'trackingId': 'HERE-5c02456f-e379-4f55-ba77-095d7d9d8c74'},
#  {'shadow': {'desired': {'payload': {'refAppData': {'icon': 'GENERIC',
#       'name': 'msk-poc-5'}},
#     'system': {'stateVersion': 14,
#      'rate': {'sendMs': 86400000, 'sampleMs': 86400000, 'distanceM': 0},
#      'lastModifiedGeofenceTimestamp': 0},
#     'timestamp': 1612424718907},
#    'reported': {'payload': {'refAppData': {'icon': 'GENERIC',
#       'name': 'msk-poc-5',
#       'nwpos': True}},
#     'system': {'stateVersion': 13423,
#      'client': {'name': 'HERE Tracker',
#       'model': 'F-03H',
#       'version': '1.1.5',
#       'firmware': 'V07R043A',
#       'platform': 'android',
#       'manufacturer': 'FUJITSU'},
#      'computed': {'moving': False,
#       'lastMovedTimestamp': 1612766287062,
#       'online': False},
#      'reportedSensorData': {'batteryLevel': 99, 'batteryIsCharging': False}},
#     'timestamp': 1612766324987,
#     'position': {'lat': 35.6699896,
#      'lng': 139.7419524,
#      'type': 'cell',
#      'accuracy': 1721}}},
#   'trackingId': 'HERE-01f24170-a342-4bb4-a434-e7333f7e134d'},
#  {'shadow': {'desired': {'payload': {'refAppData': {'icon': 'GENERIC',
#       'name': 'msk-poc-4'}},
#     'system': {'stateVersion': 11,
#      'rate': {'sendMs': 86400000, 'sampleMs': 86400000, 'distanceM': 0},
#      'lastModifiedGeofenceTimestamp': 0},
#     'timestamp': 1612424689728},
#    'reported': {'payload': {'refAppData': {'icon': 'GENERIC',
#       'name': 'msk-poc-4',
#       'nwpos': True}},
#     'system': {'stateVersion': 8788,
#      'client': {'name': 'HERE Tracker',
#       'model': 'SH-01H',
#       'version': '1.1.5',
#       'firmware': '03.00.04',
#       'platform': 'android',
#       'manufacturer': 'SHARP'},
#      'computed': {'moving': True,
#       'lastMovedTimestamp': 1612767634870,
#       'online': False},
#      'reportedSensorData': {'batteryLevel': 87, 'batteryIsCharging': False}},
#     'timestamp': 1612767634870,
#     'position': {'lat': 35.6699199,
#      'lng': 139.7419358,
#      'type': 'wlan',
#      'accuracy': 50}}},
#   'trackingId': 'HERE-054741ff-3318-4dda-b609-e4fe68c2f03e'},
#  {'shadow': {'desired': {'payload': {'refAppData': {'icon': 'GENERIC',
#       'name': 'msk-poc-3'}},
#     'system': {'stateVersion': 11,
#      'rate': {'sendMs': 86400000, 'sampleMs': 86400000, 'distanceM': 0},
#      'lastModifiedGeofenceTimestamp': 0},
#     'timestamp': 1612424710433},
#    'reported': {'payload': {'refAppData': {'icon': 'GENERIC',
#       'name': 'msk-poc-3',
#       'nwpos': True}},
#     'system': {'stateVersion': 9489,
#      'client': {'name': 'HERE Tracker',
#       'model': 'SO-04H',
#       'version': '1.1.5',
#       'firmware': '41.3.B.1.82',
#       'platform': 'android',
#       'manufacturer': 'Sony'},
#      'computed': {'moving': False,
#       'lastMovedTimestamp': 1611954286361,
#       'online': False},
#      'reportedSensorData': {'batteryLevel': 100, 'batteryIsCharging': True}},
#     'timestamp': 1612144917668,
#     'position': {'alt': 57,
#      'lat': 35.6249928,
#      'lng': 139.8990655,
#      'type': 'cell',
#      'accuracy': 2139,
#      'altaccuracy': 1000}}},
#   'trackingId': 'HERE-89b7eb6c-be16-464a-a16c-ed0196fd82bd'},
#  {'shadow': {'desired': {'payload': {'refAppData': {'icon': 'GENERIC',
#       'name': 'msk-poc-6'}},
#     'system': {'stateVersion': 10,
#      'rate': {'sendMs': 86400000, 'sampleMs': 86400000, 'distanceM': 0},
#      'lastModifiedGeofenceTimestamp': 0},
#     'timestamp': 1612424703207},
#    'reported': {'payload': {'refAppData': {'icon': 'GENERIC',
#       'name': 'msk-poc-6',
#       'nwpos': True}},
#     'system': {'stateVersion': 7428,
#      'client': {'name': 'HERE Tracker',
#       'model': 'SH-02H',
#       'version': '1.1.5',
#       'firmware': '03.00.08',
#       'platform': 'android',
#       'manufacturer': 'SHARP'},
#      'computed': {'moving': False,
#       'lastMovedTimestamp': 1612767651374,
#       'online': False},
#      'reportedSensorData': {'batteryLevel': 100, 'batteryIsCharging': False}},
#     'timestamp': 1612767685577,
#     'position': {'lat': 35.6699004,
#      'lng': 139.7418713,
#      'type': 'wlan',
#      'accuracy': 55}}},
#   'trackingId': 'HERE-d612a574-fec0-4ac1-abb1-c883ffb073b8'}]

# %%
pd.DataFrame(device_list)
# Out:
#                                               shadow  \
# 0  {'desired': {'payload': {'refAppData': {'icon'...
# 1  {'desired': {'payload': {'refAppData': {'icon'...
# 2  {'desired': {'payload': {'refAppData': {'icon'...
# 3  {'desired': {'payload': {'refAppData': {'icon'...
# 4  {'desired': {'payload': {'refAppData': {'icon'...
# 5  {'desired': {'payload': {'refAppData': {'icon'...
# 6  {'desired': {'payload': {'refAppData': {'icon'...
#
#                                   trackingId
# 0  HERE-230a4588-74b8-479e-b4ea-73344b2200d6
# 1  HERE-7c0af8ad-39cf-4c73-97ca-211fe03557f4
# 2  HERE-5c02456f-e379-4f55-ba77-095d7d9d8c74
# 3  HERE-01f24170-a342-4bb4-a434-e7333f7e134d
# 4  HERE-054741ff-3318-4dda-b609-e4fe68c2f03e
# 5  HERE-89b7eb6c-be16-464a-a16c-ed0196fd82bd
# 6  HERE-d612a574-fec0-4ac1-abb1-c883ffb073b8

# %%
# 端末を選択
tracking_id = device_list[0].get('trackingId')
tracking_id
# Out:
# 'HERE-230a4588-74b8-479e-b4ea-73344b2200d6'

# %% [markdown]
# ## Retrieve the device shadow

# %%
shadow = tracking_get_shadow(access_token, tracking_id, projectId=project_id)
shadow
# Out:
# https://tracking.api.here.com/shadows/v2/HERE-230a4588-74b8-479e-b4ea-73344b2200d6?projectId=CUST-7d3d712c-e368-40a3-892d-b572d4491874
# {'desired': {'payload': {'refAppData': {'icon': 'GENERIC', 'name': '田邊私用端末'}},
#   'system': {'stateVersion': 5,
#    'rate': {'sendMs': 300000, 'sampleMs': 60000, 'distanceM': 0},
#    'lastModifiedGeofenceTimestamp': 0},
#   'timestamp': 1610955861383},
#  'reported': {'payload': {'refAppData': {'icon': 'GENERIC',
#     'name': '田邊私用端末',
#     'nwpos': True}},
#   'system': {'stateVersion': 77248,
#    'client': {'name': 'HERE Tracker',
#     'model': 'Pixel 3a',
#     'version': '1.1.5',
#     'firmware': 'RQ2A.210305.006',
#     'platform': 'android',
#     'manufacturer': 'Google'},
#    'computed': {'moving': False,
#     'lastMovedTimestamp': 1615505721620,
#     'online': True},
#    'reportedSensorData': {'batteryLevel': 80, 'batteryIsCharging': False}},
#   'timestamp': 1615513740731,
#   'position': {'alt': 145,
#    'lat': 35.6799996,
#    'lng': 139.764204,
#    'type': 'cell',
#    'accuracy': 2026,
#    'altaccuracy': 710}}}

# %% [markdown]
# ## Retrive the device trace

# %%
jst = pytz.timezone('Asia/Tokyo')
after_picker = ipydatetime.DatetimePicker(description='After:', value=jst.localize(datetime.datetime(
    2021, 1, 19, 17, 30, 0
)))
before_picker = ipydatetime.DatetimePicker(description='Before:', value=jst.localize(datetime.datetime(
    2021, 1, 19,20 , 0, 0
)))
display(after_picker)
display(before_picker)
# Out:
# DatetimePicker(value=datetime.datetime(2021, 1, 19, 17, 30, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), …
# DatetimePicker(value=datetime.datetime(2021, 1, 19, 20, 0, tzinfo=<DstTzInfo 'Asia/Tokyo' JST+9:00:00 STD>), d…

# %%
after = int(after_picker.value.timestamp() * 1000)
before = int(before_picker.value.timestamp() * 1000)
trace = tracking_get_trace(access_token, tracking_id, projectId=project_id, after=after, before=before)
trace
# Out:
# https://tracking.api.here.com/traces/v2/HERE-230a4588-74b8-479e-b4ea-73344b2200d6?projectId=CUST-7d3d712c-e368-40a3-892d-b572d4491874&after=1611045000000&before=1611054000000
# {'count': 149,
#  'data': [{'timestamp': 1611053946054,
#    'position': {'alt': 49,
#     'lat': 35.33830382,
#     'lng': 139.50076906,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 16.150562286376953,
#     'timestamp': 1611053956000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611054100975},
#   {'timestamp': 1611053886049,
#    'position': {'alt': 49,
#     'lat': 35.33830283,
#     'lng': 139.50076558,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 6.694888114929199,
#     'timestamp': 1611053896000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611054100975},
#   {'timestamp': 1611053825947,
#    'position': {'alt': 49,
#     'lat': 35.33829415,
#     'lng': 139.50077231,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 7.70382022857666,
#     'timestamp': 1611053835000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611054100975},
#   {'timestamp': 1611053765918,
#    'position': {'alt': 52,
#     'lat': 35.33826498,
#     'lng': 139.50073697,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 10.166523933410645,
#     'timestamp': 1611053774000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611053792125},
#   {'timestamp': 1611053705895,
#    'position': {'alt': 53,
#     'lat': 35.33825346,
#     'lng': 139.50072245,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 8.131720542907715,
#     'timestamp': 1611053716000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611053792125},
#   {'timestamp': 1611053645875,
#    'position': {'alt': 52,
#     'lat': 35.33825408,
#     'lng': 139.50071666,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 10.151713371276855,
#     'timestamp': 1611053658000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611053792125},
#   {'timestamp': 1611053585771,
#    'position': {'alt': 53,
#     'lat': 35.33824909,
#     'lng': 139.50070919,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 9.975324630737305,
#     'timestamp': 1611053595000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611053792125},
#   {'timestamp': 1611053525749,
#    'position': {'alt': 52,
#     'lat': 35.33825934,
#     'lng': 139.50070044,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 11.854682922363281,
#     'timestamp': 1611053535000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611053792125},
#   {'timestamp': 1611053465660,
#    'position': {'alt': 51,
#     'lat': 35.33826772,
#     'lng': 139.50068763,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 11.932479858398438,
#     'timestamp': 1611053474000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611053492125},
#   {'timestamp': 1611053405559,
#    'position': {'alt': 51,
#     'lat': 35.3382739,
#     'lng': 139.50069065,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 21.947154998779297,
#     'timestamp': 1611053419000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611053492125},
#   {'timestamp': 1611053345488,
#    'position': {'alt': 50,
#     'lat': 35.3382342,
#     'lng': 139.5006209,
#     'type': 'wlan',
#     'accuracy': 27,
#     'altaccuracy': 15},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611053492125},
#   {'timestamp': 1611053285443,
#    'position': {'alt': 47,
#     'lat': 35.33828364,
#     'lng': 139.50069071,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 11.643896102905273,
#     'timestamp': 1611053295000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611053492125},
#   {'timestamp': 1611053225343,
#    'position': {'alt': 46,
#     'lat': 35.33828721,
#     'lng': 139.50069256,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 19.283727645874023,
#     'timestamp': 1611053241000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611053492125},
#   {'timestamp': 1611053165321,
#    'position': {'alt': 45,
#     'lat': 35.3382893,
#     'lng': 139.50070629,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 9.977134704589844,
#     'timestamp': 1611053173000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611053191568},
#   {'timestamp': 1611053105299,
#    'position': {'alt': 43,
#     'lat': 35.33829708,
#     'lng': 139.50075313,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 21.634326934814453,
#     'timestamp': 1611053118000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611053191568},
#   {'timestamp': 1611053045198,
#    'position': {'alt': 41,
#     'lat': 35.338301,
#     'lng': 139.50076329,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 14.924589157104492,
#     'timestamp': 1611053064000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611053191568},
#   {'timestamp': 1611052985095,
#    'position': {'alt': 38,
#     'lat': 35.33829898,
#     'lng': 139.50078262,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 16.12342071533203,
#     'timestamp': 1611053004000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611053191568},
#   {'timestamp': 1611052925087,
#    'position': {'alt': 37,
#     'lat': 35.33830426,
#     'lng': 139.50078106,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 20.38939666748047,
#     'timestamp': 1611052935000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611053191568},
#   {'timestamp': 1611052865061,
#    'position': {'alt': 35,
#     'lat': 35.33830742,
#     'lng': 139.50078375,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 23.665245056152344,
#     'timestamp': 1611052876000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611052895456},
#   {'timestamp': 1611052805016,
#    'position': {'alt': 32,
#     'lat': 35.3383095,
#     'lng': 139.50079755,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 11.808148384094238,
#     'timestamp': 1611052818000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611052895456},
#   {'timestamp': 1611052745004,
#    'position': {'alt': 32,
#     'lat': 35.33831769,
#     'lng': 139.50080663,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 6.549738883972168,
#     'timestamp': 1611052752000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611052895456},
#   {'timestamp': 1611052684954,
#    'position': {'alt': 50,
#     'lat': 35.3382389,
#     'lng': 139.5006288,
#     'type': 'wlan',
#     'accuracy': 25,
#     'altaccuracy': 14},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 37, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611052895456},
#   {'timestamp': 1611052624944,
#    'position': {'alt': 50,
#     'lat': 35.3382736,
#     'lng': 139.5006193,
#     'type': 'wlan',
#     'accuracy': 32,
#     'altaccuracy': 18},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 38, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611052895456},
#   {'timestamp': 1611052564905,
#    'position': {'alt': 55,
#     'lat': 35.33853997,
#     'lng': 139.50108858,
#     'type': 'gnss',
#     'speed': 0,
#     'heading': 148,
#     'accuracy': 36.14133834838867,
#     'timestamp': 1611052581000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 38, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611052591641},
#   {'timestamp': 1611052504865,
#    'position': {'alt': 55,
#     'lat': 35.3383665,
#     'lng': 139.50065896,
#     'type': 'gnss',
#     'speed': 1,
#     'heading': 309,
#     'accuracy': 11.79837703704834,
#     'timestamp': 1611052511000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 38, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611052591641},
#   {'timestamp': 1611052444765,
#    'position': {'alt': 58,
#     'lat': 35.33824491,
#     'lng': 139.50085557,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 4.8888163566589355,
#     'timestamp': 1611052451000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 38, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611052591641},
#   {'timestamp': 1611052384665,
#    'position': {'alt': 113,
#     'lat': 35.33819186,
#     'lng': 139.50094361,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 4.78621768951416,
#     'timestamp': 1611052390000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 38, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611052591641},
#   {'timestamp': 1611052324564,
#    'position': {'alt': 54,
#     'lat': 35.33963864,
#     'lng': 139.49866784,
#     'type': 'gnss',
#     'speed': 8,
#     'heading': 152,
#     'accuracy': 5.222775459289551,
#     'timestamp': 1611052330000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 38, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611052591641},
#   {'timestamp': 1611052264463,
#    'position': {'alt': 54,
#     'lat': 35.34027917,
#     'lng': 139.49864256,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 3.7900924682617188,
#     'timestamp': 1611052270000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 38, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611052291442},
#   {'timestamp': 1611052204385,
#    'position': {'alt': 51,
#     'lat': 35.34028769,
#     'lng': 139.49864509,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 3.7900924682617188,
#     'timestamp': 1611052210000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611052291442},
#   {'timestamp': 1611052144358,
#    'position': {'alt': 53,
#     'lat': 35.34029617,
#     'lng': 139.49865026,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 3.7900924682617188,
#     'timestamp': 1611052150000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611052291442},
#   {'timestamp': 1611052084257,
#    'position': {'alt': 64,
#     'lat': 35.34029454,
#     'lng': 139.49862883,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 3.7900924682617188,
#     'timestamp': 1611052089000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611052291442},
#   {'timestamp': 1611052024253,
#    'position': {'alt': 55,
#     'lat': 35.34023312,
#     'lng': 139.49855135,
#     'type': 'gnss',
#     'speed': 3,
#     'heading': 55,
#     'accuracy': 3.949789524078369,
#     'timestamp': 1611052030000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611052291442},
#   {'timestamp': 1611051964243,
#    'position': {'alt': 38,
#     'lat': 35.34051308,
#     'lng': 139.49604915,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 13.446990013122559,
#     'timestamp': 1611051970000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051990854},
#   {'timestamp': 1611051904160,
#    'position': {'alt': 38,
#     'lat': 35.3403375,
#     'lng': 139.49258535,
#     'type': 'gnss',
#     'speed': 6,
#     'heading': 91,
#     'accuracy': 6.200125694274902,
#     'timestamp': 1611051911000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051990854},
#   {'timestamp': 1611051844156,
#    'position': {'alt': 59,
#     'lat': 35.34006126,
#     'lng': 139.49020078,
#     'type': 'gnss',
#     'speed': 7,
#     'heading': 78,
#     'accuracy': 9.11100959777832,
#     'timestamp': 1611051851000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051990854},
#   {'timestamp': 1611051784121,
#    'position': {'alt': 63,
#     'lat': 35.3402119,
#     'lng': 139.48655334,
#     'type': 'gnss',
#     'speed': 6,
#     'heading': 95,
#     'accuracy': 4.314599514007568,
#     'timestamp': 1611051790000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051990854},
#   {'timestamp': 1611051724029,
#    'position': {'alt': 55,
#     'lat': 35.34123467,
#     'lng': 139.48381579,
#     'type': 'gnss',
#     'speed': 6,
#     'heading': 145,
#     'accuracy': 5.028228759765625,
#     'timestamp': 1611051731000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051990854},
#   {'timestamp': 1611051663923,
#    'position': {'alt': 68,
#     'lat': 35.34016632,
#     'lng': 139.48254896,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 5.425495624542236,
#     'timestamp': 1611051670000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051691210},
#   {'timestamp': 1611051603821,
#    'position': {'alt': -16,
#     'lat': 35.33950406,
#     'lng': 139.4860282,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 12.330653190612793,
#     'timestamp': 1611051611000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051691210},
#   {'timestamp': 1611051543720,
#    'position': {'alt': 54,
#     'lat': 35.33938469,
#     'lng': 139.48605316,
#     'type': 'gnss',
#     'speed': 5,
#     'heading': 266,
#     'accuracy': 4.396219253540039,
#     'timestamp': 1611051549000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051691210},
#   {'timestamp': 1611051483708,
#    'position': {'alt': 58,
#     'lat': 35.33930677,
#     'lng': 139.4873696,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 5.043956279754639,
#     'timestamp': 1611051489000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051691210},
#   {'timestamp': 1611051423678,
#    'position': {'alt': 56,
#     'lat': 35.33932948,
#     'lng': 139.4873765,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 7.766125202178955,
#     'timestamp': 1611051430000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051691210},
#   {'timestamp': 1611051363578,
#    'position': {'alt': 90,
#     'lat': 35.33934437,
#     'lng': 139.48739978,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 9.059776306152344,
#     'timestamp': 1611051370000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051390089},
#   {'timestamp': 1611051303470,
#    'position': {'alt': 103,
#     'lat': 35.33934035,
#     'lng': 139.48739833,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 12.17674732208252,
#     'timestamp': 1611051310000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051390089},
#   {'timestamp': 1611051243435,
#    'position': {'alt': 90,
#     'lat': 35.3396331,
#     'lng': 139.48744994,
#     'type': 'gnss',
#     'speed': 0,
#     'heading': 173,
#     'accuracy': 14.420723915100098,
#     'timestamp': 1611051252000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 39, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051390089},
#   {'timestamp': 1611051183343,
#    'position': {'alt': 143,
#     'lat': 35.33950308,
#     'lng': 139.48762115,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 11.282964706420898,
#     'timestamp': 1611051190000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 40, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051390089},
#   {'timestamp': 1611051123327,
#    'position': {'alt': 122,
#     'lat': 35.33955357,
#     'lng': 139.4877657,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 18.33049774169922,
#     'timestamp': 1611051130000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 40, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051390089},
#   {'timestamp': 1611051063225,
#    'position': {'alt': 154,
#     'lat': 35.3396004,
#     'lng': 139.48769518,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 10.915783882141113,
#     'timestamp': 1611051070000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 40, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051090656},
#   {'timestamp': 1611051003219,
#    'position': {'alt': 86,
#     'lat': 35.33927633,
#     'lng': 139.48737901,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 14.430694580078125,
#     'timestamp': 1611051010000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 40, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051090656},
#   {'timestamp': 1611050943163,
#    'position': {'alt': 84,
#     'lat': 35.33929014,
#     'lng': 139.48745115,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 8.903282165527344,
#     'timestamp': 1611050950000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 40, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051090656},
#   {'timestamp': 1611050883155,
#    'position': {'alt': 84,
#     'lat': 35.33934272,
#     'lng': 139.48746387,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 8.259203910827637,
#     'timestamp': 1611050889000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 40, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051090656},
#   {'timestamp': 1611050823054,
#    'position': {'alt': 71,
#     'lat': 35.33982407,
#     'lng': 139.48793027,
#     'type': 'gnss',
#     'speed': 3,
#     'heading': 210,
#     'accuracy': 5.733861446380615,
#     'timestamp': 1611050829000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 40, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611051090656},
#   {'timestamp': 1611050763032,
#    'position': {'alt': 39,
#     'lat': 35.33981067,
#     'lng': 139.49025267,
#     'type': 'gnss',
#     'speed': 12,
#     'heading': 343,
#     'accuracy': 5.95233678817749,
#     'timestamp': 1611050769000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 40, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611050791264},
#   {'timestamp': 1611050703013,
#    'position': {'alt': 67,
#     'lat': 35.33634417,
#     'lng': 139.49012999,
#     'type': 'gnss',
#     'speed': 1,
#     'heading': 165,
#     'accuracy': 11.224956512451172,
#     'timestamp': 1611050708000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 40, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611050791264},
#   {'timestamp': 1611050642911,
#    'position': {'alt': 76,
#     'lat': 35.33628181,
#     'lng': 139.49007694,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 5.22314453125,
#     'timestamp': 1611050649000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 40, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611050791264},
#   {'timestamp': 1611050582890,
#    'position': {'alt': 55,
#     'lat': 35.3311081,
#     'lng': 139.48812623,
#     'type': 'gnss',
#     'speed': 10,
#     'heading': 15,
#     'accuracy': 3.7964351177215576,
#     'timestamp': 1611050588000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 40, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611050791264},
#   {'timestamp': 1611050522869,
#    'position': {'alt': 47,
#     'lat': 35.32860256,
#     'lng': 139.48812396,
#     'type': 'gnss',
#     'speed': 4,
#     'heading': 245,
#     'accuracy': 3.7900924682617188,
#     'timestamp': 1611050528000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 40, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611050791264},
#   {'timestamp': 1611050462850,
#    'position': {'alt': 47,
#     'lat': 35.32931872,
#     'lng': 139.48790258,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 19.209440231323242,
#     'timestamp': 1611050471000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 41, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611050490457},
#   {'timestamp': 1611050402846,
#    'position': {'alt': 51,
#     'lat': 35.3293155,
#     'lng': 139.48791592,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 18.140317916870117,
#     'timestamp': 1611050412000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 41, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611050490457},
#   {'timestamp': 1611050342745,
#    'position': {'alt': 41,
#     'lat': 35.32930204,
#     'lng': 139.48793563,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 11.127232551574707,
#     'timestamp': 1611050353000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 41, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611050490457},
#   {'timestamp': 1611050282678,
#    'position': {'alt': 53,
#     'lat': 35.32929445,
#     'lng': 139.48796048,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 23.525157928466797,
#     'timestamp': 1611050292000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 41, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611050490457},
#   {'timestamp': 1611050222662,
#    'position': {'alt': 51,
#     'lat': 35.32929413,
#     'lng': 139.48797865,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 11.920080184936523,
#     'timestamp': 1611050232000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 41, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611050490457},
#   {'timestamp': 1611050162631,
#    'position': {'alt': 49,
#     'lat': 35.3292686,
#     'lng': 139.48798706,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 17.409278869628906,
#     'timestamp': 1611050176000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 41, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611050190522},
#   {'timestamp': 1611050102551,
#    'position': {'alt': 58,
#     'lat': 35.329253,
#     'lng': 139.48797076,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 12.501708984375,
#     'timestamp': 1611050112000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 42, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611050190522},
#   {'timestamp': 1611050042490,
#    'position': {'alt': 43,
#     'lat': 35.32922408,
#     'lng': 139.48801806,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 17.77391815185547,
#     'timestamp': 1611050056000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 42, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611050190522},
#   {'timestamp': 1611049982487,
#    'position': {'alt': 60,
#     'lat': 35.32919776,
#     'lng': 139.4880241,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 9.906179428100586,
#     'timestamp': 1611049990000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 42, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611050190522},
#   {'timestamp': 1611049922445,
#    'position': {'alt': 74,
#     'lat': 35.3291807,
#     'lng': 139.48804487,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 10.009407043457031,
#     'timestamp': 1611049930000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 42, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611050190522},
#   {'timestamp': 1611049862342,
#    'position': {'alt': 98,
#     'lat': 35.32929483,
#     'lng': 139.48826787,
#     'type': 'gnss',
#     'speed': 0,
#     'heading': 238,
#     'accuracy': 15.737512588500977,
#     'timestamp': 1611049871000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 42, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611049890837},
#   {'timestamp': 1611049802240,
#    'position': {'alt': 59,
#     'lat': 35.32915146,
#     'lng': 139.48807138,
#     'type': 'gnss',
#     'speed': 1,
#     'heading': 284,
#     'accuracy': 26.06024932861328,
#     'timestamp': 1611049832000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 42, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611049890837},
#   {'timestamp': 1611049742209,
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 42, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611049890837},
#   {'timestamp': 1611049682193,
#    'position': {'alt': 29,
#     'lat': 35.3292874,
#     'lng': 139.48853095,
#     'type': 'gnss',
#     'speed': 1,
#     'heading': 255,
#     'accuracy': 15.281435012817383,
#     'timestamp': 1611049690000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 42, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611049890837},
#   {'timestamp': 1611049622092,
#    'position': {'alt': 67,
#     'lat': 35.32956817,
#     'lng': 139.48856453,
#     'type': 'gnss',
#     'speed': 1,
#     'heading': 301,
#     'accuracy': 11.032716751098633,
#     'timestamp': 1611049629000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 43, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611049890837},
#   {'timestamp': 1611049562069,
#    'position': {'alt': 44,
#     'lat': 35.32946755,
#     'lng': 139.48819214,
#     'type': 'gnss',
#     'speed': 2,
#     'heading': 341,
#     'accuracy': 20.109790802001953,
#     'timestamp': 1611049571000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 43, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611049590290},
#   {'timestamp': 1611049502004,
#    'position': {'alt': 48,
#     'lat': 35.32899919,
#     'lng': 139.488321,
#     'type': 'gnss',
#     'speed': 1,
#     'heading': 340,
#     'accuracy': 11.480886459350586,
#     'timestamp': 1611049510000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 43, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611049590290},
#   {'timestamp': 1611049441964,
#    'position': {'alt': 57,
#     'lat': 35.32966277,
#     'lng': 139.48815049,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 21.4155330657959,
#     'timestamp': 1611049453000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 43, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611049590290},
#   {'timestamp': 1611049381955,
#    'position': {'alt': 72,
#     'lat': 35.3378034,
#     'lng': 139.4888163,
#     'type': 'wlan',
#     'accuracy': 250,
#     'altaccuracy': 1000},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 43, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611049590290},
#   {'timestamp': 1611049321871,
#    'position': {'alt': 72,
#     'lat': 35.329709,
#     'lng': 139.4878285,
#     'type': 'wlan',
#     'accuracy': 74,
#     'altaccuracy': 1000},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 43, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611049590290},
#   {'timestamp': 1611049261774,
#    'position': {'alt': 65,
#     'lat': 35.32952987,
#     'lng': 139.48831923,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 24.790283203125,
#     'timestamp': 1611049271000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 44, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611049289872},
#   {'timestamp': 1611049201670,
#    'position': {'alt': 80,
#     'lat': 35.32925496,
#     'lng': 139.48784613,
#     'type': 'gnss',
#     'speed': 1,
#     'heading': 29,
#     'accuracy': 12.406611442565918,
#     'timestamp': 1611049209000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 44, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611049289872},
#   {'timestamp': 1611049141578,
#    'position': {'alt': 61,
#     'lat': 35.32955579,
#     'lng': 139.48737095,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 20.765661239624023,
#     'timestamp': 1611049164000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 44, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611049289872},
#   {'timestamp': 1611049081569,
#    'position': {'alt': 51,
#     'lat': 35.32947682,
#     'lng': 139.48759994,
#     'type': 'gnss',
#     'speed': 1,
#     'heading': 82,
#     'accuracy': 6.970455169677734,
#     'timestamp': 1611049088000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 44, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611049289872},
#   {'timestamp': 1611049021516,
#    'position': {'alt': 58,
#     'lat': 35.33024998,
#     'lng': 139.48791895,
#     'type': 'gnss',
#     'speed': 10,
#     'heading': 194,
#     'accuracy': 3.8847436904907227,
#     'timestamp': 1611049027000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 44, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611049289872},
#   {'timestamp': 1611048961409,
#    'position': {'alt': 49,
#     'lat': 35.33340493,
#     'lng': 139.48900799,
#     'type': 'gnss',
#     'speed': 9,
#     'heading': 197,
#     'accuracy': 3.7900924682617188,
#     'timestamp': 1611048967000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 44, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611048989730},
#   {'timestamp': 1611048901301,
#    'position': {'alt': 55,
#     'lat': 35.33864283,
#     'lng': 139.49048144,
#     'type': 'gnss',
#     'speed': 10,
#     'heading': 185,
#     'accuracy': 4.117976665496826,
#     'timestamp': 1611048907000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 44, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611048989730},
#   {'timestamp': 1611048841230,
#    'position': {'alt': 81,
#     'lat': 35.33988755,
#     'lng': 139.48987355,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 12.942228317260742,
#     'timestamp': 1611048847000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 44, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611048989730},
#   {'timestamp': 1611048781217,
#    'position': {'alt': 60,
#     'lat': 35.34019256,
#     'lng': 139.48720263,
#     'type': 'gnss',
#     'speed': 5,
#     'heading': 99,
#     'accuracy': 7.430721282958984,
#     'timestamp': 1611048788000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 44, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611048989730},
#   {'timestamp': 1611048721115,
#    'position': {'alt': 71,
#     'lat': 35.34014629,
#     'lng': 139.48684615,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 6.46159029006958,
#     'timestamp': 1611048727000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
# ...
#     'timestamp': 1611046806000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 48, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611046890346},
#   {'timestamp': 1611046738931,
#    'position': {'alt': 50,
#     'lat': 35.34025547,
#     'lng': 139.49850724,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 5.154803276062012,
#     'timestamp': 1611046745000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 48, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611046890346},
#   {'timestamp': 1611046678901,
#    'position': {'alt': 51,
#     'lat': 35.34022325,
#     'lng': 139.49850249,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 3.976649522781372,
#     'timestamp': 1611046684000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 48, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611046890346},
#   {'timestamp': 1611046618809,
#    'position': {'alt': 55,
#     'lat': 35.34023244,
#     'lng': 139.49852207,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 4.412955284118652,
#     'timestamp': 1611046624000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 49, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611046890346},
#   {'timestamp': 1611046558791,
#    'position': {'alt': 53,
#     'lat': 35.34024315,
#     'lng': 139.49847236,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 3.7900924682617188,
#     'timestamp': 1611046564000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 49, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611046590093},
#   {'timestamp': 1611046498713,
#    'position': {'alt': 52,
#     'lat': 35.34037686,
#     'lng': 139.49847182,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 3.7900924682617188,
#     'timestamp': 1611046504000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 49, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611046590093},
#   {'timestamp': 1611046438658,
#    'position': {'alt': 57,
#     'lat': 35.34039316,
#     'lng': 139.49847376,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 4.74265718460083,
#     'timestamp': 1611046446000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 49, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611046590093},
#   {'timestamp': 1611046378634,
#    'position': {'alt': 48,
#     'lat': 35.33881748,
#     'lng': 139.4991214,
#     'type': 'gnss',
#     'speed': 6,
#     'heading': 333,
#     'accuracy': 7.955001354217529,
#     'timestamp': 1611046384000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 49, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611046590093},
#   {'timestamp': 1611046318576,
#    'position': {'alt': 42,
#     'lat': 35.33826667,
#     'lng': 139.50081919,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 4.930978775024414,
#     'timestamp': 1611046325000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 49, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611046590093},
#   {'timestamp': 1611046258565,
#    'position': {'alt': 56,
#     'lat': 35.33839352,
#     'lng': 139.50080493,
#     'type': 'gnss',
#     'speed': 2,
#     'heading': 199,
#     'accuracy': 4.034955024719238,
#     'timestamp': 1611046265000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 49, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611046288707},
#   {'timestamp': 1611046198542,
#    'position': {'alt': 61,
#     'lat': 35.33834023,
#     'lng': 139.50079875,
#     'type': 'gnss',
#     'speed': 1,
#     'heading': 253,
#     'accuracy': 62.09436798095703,
#     'timestamp': 1611046220000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 50, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611046288707},
#   {'timestamp': 1611046138522,
#    'position': {'alt': 41,
#     'lat': 35.33827677,
#     'lng': 139.50085612,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 22.766345977783203,
#     'timestamp': 1611046156000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 50, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611046288707},
#   {'timestamp': 1611046078469,
#    'position': {'alt': 50,
#     'lat': 35.3382724,
#     'lng': 139.5006584,
#     'type': 'wlan',
#     'accuracy': 29,
#     'altaccuracy': 18},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 50, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611046288707},
#   {'timestamp': 1611046018445,
#    'position': {'alt': 50,
#     'lat': 35.3382754,
#     'lng': 139.5006824,
#     'type': 'wlan',
#     'accuracy': 35,
#     'altaccuracy': 19},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 50, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611046288707},
#   {'timestamp': 1611045958343,
#    'position': {'alt': 40,
#     'lat': 35.33832014,
#     'lng': 139.50071534,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 11.875839233398438,
#     'timestamp': 1611045968000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 50, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611045990561},
#   {'timestamp': 1611045898339,
#    'position': {'alt': 42,
#     'lat': 35.33831393,
#     'lng': 139.50071217,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 23.19566535949707,
#     'timestamp': 1611045910000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 50, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611045990561},
#   {'timestamp': 1611045838320,
#    'position': {'alt': 42,
#     'lat': 35.33831082,
#     'lng': 139.5007235,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 11.383431434631348,
#     'timestamp': 1611045846000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 50, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611045990561},
#   {'timestamp': 1611045778318,
#    'position': {'alt': 40,
#     'lat': 35.33831433,
#     'lng': 139.50073318,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 12.267021179199219,
#     'timestamp': 1611045786000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 50, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611045990561},
#   {'timestamp': 1611045718219,
#    'position': {'alt': 38,
#     'lat': 35.33831278,
#     'lng': 139.5007776,
#     'type': 'gnss',
#     'speed': 1,
#     'heading': 59,
#     'accuracy': 21.073423385620117,
#     'timestamp': 1611045728000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 51, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611045990561},
#   {'timestamp': 1611045658195,
#    'position': {'alt': 38,
#     'lat': 35.33827327,
#     'lng': 139.50069663,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 18.85418701171875,
#     'timestamp': 1611045667000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 51, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611045689030},
#   {'timestamp': 1611045598140,
#    'position': {'alt': 39,
#     'lat': 35.33827649,
#     'lng': 139.50069365,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 6.670629501342773,
#     'timestamp': 1611045605000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 51, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611045689030},
#   {'timestamp': 1611045538052,
#    'position': {'alt': 40,
#     'lat': 35.33828275,
#     'lng': 139.50070454,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 5.997530460357666,
#     'timestamp': 1611045547000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 51, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611045689030},
#   {'timestamp': 1611045478048,
#    'position': {'alt': 38,
#     'lat': 35.33828369,
#     'lng': 139.50072634,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 16.24046516418457,
#     'timestamp': 1611045486000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 51, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611045689030},
#   {'timestamp': 1611045418047,
#    'position': {'alt': 41,
#     'lat': 35.33828333,
#     'lng': 139.50071084,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 7.349483966827393,
#     'timestamp': 1611045427000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 51, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611045689030},
#   {'timestamp': 1611045357997,
#    'position': {'alt': 46,
#     'lat': 35.33828129,
#     'lng': 139.50068301,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 9.839345932006836,
#     'timestamp': 1611045366000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 51, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611045389607},
#   {'timestamp': 1611045297895,
#    'position': {'alt': 50,
#     'lat': 35.3382389,
#     'lng': 139.5006288,
#     'type': 'wlan',
#     'accuracy': 25,
#     'altaccuracy': 14},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 51, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611045389607},
#   {'timestamp': 1611045237810,
#    'position': {'alt': 55,
#     'lat': 35.33827716,
#     'lng': 139.50063571,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 9.57207202911377,
#     'timestamp': 1611045247000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 51, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611045389607},
#   {'timestamp': 1611045177730,
#    'position': {'alt': 56,
#     'lat': 35.33827109,
#     'lng': 139.50062819,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 4.360132694244385,
#     'timestamp': 1611045185000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 51, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611045389607},
#   {'timestamp': 1611045117629,
#    'position': {'alt': 54,
#     'lat': 35.33826835,
#     'lng': 139.50062026,
#     'type': 'gnss',
#     'speed': 0,
#     'accuracy': 6.827189922332764,
#     'timestamp': 1611045126000,
#     'altaccuracy': 1},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 51, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611045389607},
#   {'timestamp': 1611045057524,
#    'position': {'alt': 50,
#     'lat': 35.3382386,
#     'lng': 139.5006277,
#     'type': 'wlan',
#     'accuracy': 25,
#     'altaccuracy': 15},
#    'system': {'client': {'name': 'HERE Tracker',
#      'model': 'Pixel 3a',
#      'version': '1.1.5',
#      'firmware': 'RQ1A.210105.002',
#      'platform': 'android',
#      'manufacturer': 'Google'},
#     'reportedSensorData': {'batteryLevel': 51, 'batteryIsCharging': False}},
#    'serverTimestamp': 1611045089248}]}

# %%
pd.DataFrame(trace.get('data'))
# Out:
#          timestamp                                           position  \
# 0    1611053946054  {'alt': 49, 'lat': 35.33830382, 'lng': 139.500...
# 1    1611053886049  {'alt': 49, 'lat': 35.33830283, 'lng': 139.500...
# 2    1611053825947  {'alt': 49, 'lat': 35.33829415, 'lng': 139.500...
# 3    1611053765918  {'alt': 52, 'lat': 35.33826498, 'lng': 139.500...
# 4    1611053705895  {'alt': 53, 'lat': 35.33825346, 'lng': 139.500...
# 5    1611053645875  {'alt': 52, 'lat': 35.33825408, 'lng': 139.500...
# 6    1611053585771  {'alt': 53, 'lat': 35.33824909, 'lng': 139.500...
# 7    1611053525749  {'alt': 52, 'lat': 35.33825934, 'lng': 139.500...
# 8    1611053465660  {'alt': 51, 'lat': 35.33826772, 'lng': 139.500...
# 9    1611053405559  {'alt': 51, 'lat': 35.3382739, 'lng': 139.5006...
# 10   1611053345488  {'alt': 50, 'lat': 35.3382342, 'lng': 139.5006...
# 11   1611053285443  {'alt': 47, 'lat': 35.33828364, 'lng': 139.500...
# 12   1611053225343  {'alt': 46, 'lat': 35.33828721, 'lng': 139.500...
# 13   1611053165321  {'alt': 45, 'lat': 35.3382893, 'lng': 139.5007...
# 14   1611053105299  {'alt': 43, 'lat': 35.33829708, 'lng': 139.500...
# 15   1611053045198  {'alt': 41, 'lat': 35.338301, 'lng': 139.50076...
# 16   1611052985095  {'alt': 38, 'lat': 35.33829898, 'lng': 139.500...
# 17   1611052925087  {'alt': 37, 'lat': 35.33830426, 'lng': 139.500...
# 18   1611052865061  {'alt': 35, 'lat': 35.33830742, 'lng': 139.500...
# 19   1611052805016  {'alt': 32, 'lat': 35.3383095, 'lng': 139.5007...
# 20   1611052745004  {'alt': 32, 'lat': 35.33831769, 'lng': 139.500...
# 21   1611052684954  {'alt': 50, 'lat': 35.3382389, 'lng': 139.5006...
# 22   1611052624944  {'alt': 50, 'lat': 35.3382736, 'lng': 139.5006...
# 23   1611052564905  {'alt': 55, 'lat': 35.33853997, 'lng': 139.501...
# 24   1611052504865  {'alt': 55, 'lat': 35.3383665, 'lng': 139.5006...
# 25   1611052444765  {'alt': 58, 'lat': 35.33824491, 'lng': 139.500...
# 26   1611052384665  {'alt': 113, 'lat': 35.33819186, 'lng': 139.50...
# 27   1611052324564  {'alt': 54, 'lat': 35.33963864, 'lng': 139.498...
# 28   1611052264463  {'alt': 54, 'lat': 35.34027917, 'lng': 139.498...
# 29   1611052204385  {'alt': 51, 'lat': 35.34028769, 'lng': 139.498...
# 142  1611045418047  {'alt': 41, 'lat': 35.33828333, 'lng': 139.500...
# 143  1611045357997  {'alt': 46, 'lat': 35.33828129, 'lng': 139.500...
# 144  1611045297895  {'alt': 50, 'lat': 35.3382389, 'lng': 139.5006...
# 145  1611045237810  {'alt': 55, 'lat': 35.33827716, 'lng': 139.500...
# 146  1611045177730  {'alt': 56, 'lat': 35.33827109, 'lng': 139.500...
# 147  1611045117629  {'alt': 54, 'lat': 35.33826835, 'lng': 139.500...
# 148  1611045057524  {'alt': 50, 'lat': 35.3382386, 'lng': 139.5006...
#
#                                                 system  serverTimestamp
# 0    {'client': {'name': 'HERE Tracker', 'model': '...    1611054100975
# 1    {'client': {'name': 'HERE Tracker', 'model': '...    1611054100975
# 2    {'client': {'name': 'HERE Tracker', 'model': '...    1611054100975
# 3    {'client': {'name': 'HERE Tracker', 'model': '...    1611053792125
# 4    {'client': {'name': 'HERE Tracker', 'model': '...    1611053792125
# 5    {'client': {'name': 'HERE Tracker', 'model': '...    1611053792125
# 6    {'client': {'name': 'HERE Tracker', 'model': '...    1611053792125
# 7    {'client': {'name': 'HERE Tracker', 'model': '...    1611053792125
# 8    {'client': {'name': 'HERE Tracker', 'model': '...    1611053492125
# 9    {'client': {'name': 'HERE Tracker', 'model': '...    1611053492125
# 10   {'client': {'name': 'HERE Tracker', 'model': '...    1611053492125
# 11   {'client': {'name': 'HERE Tracker', 'model': '...    1611053492125
# 12   {'client': {'name': 'HERE Tracker', 'model': '...    1611053492125
# 13   {'client': {'name': 'HERE Tracker', 'model': '...    1611053191568
# 14   {'client': {'name': 'HERE Tracker', 'model': '...    1611053191568
# 15   {'client': {'name': 'HERE Tracker', 'model': '...    1611053191568
# 16   {'client': {'name': 'HERE Tracker', 'model': '...    1611053191568
# 17   {'client': {'name': 'HERE Tracker', 'model': '...    1611053191568
# 18   {'client': {'name': 'HERE Tracker', 'model': '...    1611052895456
# 19   {'client': {'name': 'HERE Tracker', 'model': '...    1611052895456
# 20   {'client': {'name': 'HERE Tracker', 'model': '...    1611052895456
# 21   {'client': {'name': 'HERE Tracker', 'model': '...    1611052895456
# 22   {'client': {'name': 'HERE Tracker', 'model': '...    1611052895456
# 23   {'client': {'name': 'HERE Tracker', 'model': '...    1611052591641
# 24   {'client': {'name': 'HERE Tracker', 'model': '...    1611052591641
# 25   {'client': {'name': 'HERE Tracker', 'model': '...    1611052591641
# 26   {'client': {'name': 'HERE Tracker', 'model': '...    1611052591641
# 27   {'client': {'name': 'HERE Tracker', 'model': '...    1611052591641
# 28   {'client': {'name': 'HERE Tracker', 'model': '...    1611052291442
# 29   {'client': {'name': 'HERE Tracker', 'model': '...    1611052291442
# 30   {'client': {'name': 'HERE Tracker', 'model': '...    1611052291442
# 31   {'client': {'name': 'HERE Tracker', 'model': '...    1611052291442
# 32   {'client': {'name': 'HERE Tracker', 'model': '...    1611052291442
# 33   {'client': {'name': 'HERE Tracker', 'model': '...    1611051990854
# 34   {'client': {'name': 'HERE Tracker', 'model': '...    1611051990854
# 35   {'client': {'name': 'HERE Tracker', 'model': '...    1611051990854
# 36   {'client': {'name': 'HERE Tracker', 'model': '...    1611051990854
# 37   {'client': {'name': 'HERE Tracker', 'model': '...    1611051990854
# 38   {'client': {'name': 'HERE Tracker', 'model': '...    1611051691210
# 39   {'client': {'name': 'HERE Tracker', 'model': '...    1611051691210
# 40   {'client': {'name': 'HERE Tracker', 'model': '...    1611051691210
# 41   {'client': {'name': 'HERE Tracker', 'model': '...    1611051691210
# 42   {'client': {'name': 'HERE Tracker', 'model': '...    1611051691210
# 43   {'client': {'name': 'HERE Tracker', 'model': '...    1611051390089
# 44   {'client': {'name': 'HERE Tracker', 'model': '...    1611051390089
# 45   {'client': {'name': 'HERE Tracker', 'model': '...    1611051390089
# 46   {'client': {'name': 'HERE Tracker', 'model': '...    1611051390089
# 47   {'client': {'name': 'HERE Tracker', 'model': '...    1611051390089
# 48   {'client': {'name': 'HERE Tracker', 'model': '...    1611051090656
# 49   {'client': {'name': 'HERE Tracker', 'model': '...    1611051090656
# 50   {'client': {'name': 'HERE Tracker', 'model': '...    1611051090656
# 51   {'client': {'name': 'HERE Tracker', 'model': '...    1611051090656
# 52   {'client': {'name': 'HERE Tracker', 'model': '...    1611051090656
# 53   {'client': {'name': 'HERE Tracker', 'model': '...    1611050791264
# 54   {'client': {'name': 'HERE Tracker', 'model': '...    1611050791264
# 55   {'client': {'name': 'HERE Tracker', 'model': '...    1611050791264
# 56   {'client': {'name': 'HERE Tracker', 'model': '...    1611050791264
# 57   {'client': {'name': 'HERE Tracker', 'model': '...    1611050791264
# 58   {'client': {'name': 'HERE Tracker', 'model': '...    1611050490457
# 59   {'client': {'name': 'HERE Tracker', 'model': '...    1611050490457
# 60   {'client': {'name': 'HERE Tracker', 'model': '...    1611050490457
# 61   {'client': {'name': 'HERE Tracker', 'model': '...    1611050490457
# 62   {'client': {'name': 'HERE Tracker', 'model': '...    1611050490457
# 63   {'client': {'name': 'HERE Tracker', 'model': '...    1611050190522
# 64   {'client': {'name': 'HERE Tracker', 'model': '...    1611050190522
# 65   {'client': {'name': 'HERE Tracker', 'model': '...    1611050190522
# 66   {'client': {'name': 'HERE Tracker', 'model': '...    1611050190522
# 67   {'client': {'name': 'HERE Tracker', 'model': '...    1611050190522
# 68   {'client': {'name': 'HERE Tracker', 'model': '...    1611049890837
# 69   {'client': {'name': 'HERE Tracker', 'model': '...    1611049890837
# 70   {'client': {'name': 'HERE Tracker', 'model': '...    1611049890837
# 71   {'client': {'name': 'HERE Tracker', 'model': '...    1611049890837
# 72   {'client': {'name': 'HERE Tracker', 'model': '...    1611049890837
# 73   {'client': {'name': 'HERE Tracker', 'model': '...    1611049590290
# 74   {'client': {'name': 'HERE Tracker', 'model': '...    1611049590290
# 75   {'client': {'name': 'HERE Tracker', 'model': '...    1611049590290
# 76   {'client': {'name': 'HERE Tracker', 'model': '...    1611049590290
# 77   {'client': {'name': 'HERE Tracker', 'model': '...    1611049590290
# 78   {'client': {'name': 'HERE Tracker', 'model': '...    1611049289872
# 79   {'client': {'name': 'HERE Tracker', 'model': '...    1611049289872
# 80   {'client': {'name': 'HERE Tracker', 'model': '...    1611049289872
# 81   {'client': {'name': 'HERE Tracker', 'model': '...    1611049289872
# 82   {'client': {'name': 'HERE Tracker', 'model': '...    1611049289872
# 83   {'client': {'name': 'HERE Tracker', 'model': '...    1611048989730
# 84   {'client': {'name': 'HERE Tracker', 'model': '...    1611048989730
# 85   {'client': {'name': 'HERE Tracker', 'model': '...    1611048989730
# 86   {'client': {'name': 'HERE Tracker', 'model': '...    1611048989730
# 87   {'client': {'name': 'HERE Tracker', 'model': '...    1611048989730
# 88   {'client': {'name': 'HERE Tracker', 'model': '...    1611048690442
# 89   {'client': {'name': 'HERE Tracker', 'model': '...    1611048690442
# 90   {'client': {'name': 'HERE Tracker', 'model': '...    1611048690442
# 91   {'client': {'name': 'HERE Tracker', 'model': '...    1611048690442
# 92   {'client': {'name': 'HERE Tracker', 'model': '...    1611048690442
# 93   {'client': {'name': 'HERE Tracker', 'model': '...    1611048390975
# 94   {'client': {'name': 'HERE Tracker', 'model': '...    1611048390975
# 95   {'client': {'name': 'HERE Tracker', 'model': '...    1611048390975
# 96   {'client': {'name': 'HERE Tracker', 'model': '...    1611048390975
# 97   {'client': {'name': 'HERE Tracker', 'model': '...    1611048390975
# 98   {'client': {'name': 'HERE Tracker', 'model': '...    1611048090413
# 99   {'client': {'name': 'HERE Tracker', 'model': '...    1611048090413
# 100  {'client': {'name': 'HERE Tracker', 'model': '...    1611048090413
# 101  {'client': {'name': 'HERE Tracker', 'model': '...    1611048090413
# 102  {'client': {'name': 'HERE Tracker', 'model': '...    1611048090413
# 103  {'client': {'name': 'HERE Tracker', 'model': '...    1611047789826
# 104  {'client': {'name': 'HERE Tracker', 'model': '...    1611047789826
# 105  {'client': {'name': 'HERE Tracker', 'model': '...    1611047789826
# 106  {'client': {'name': 'HERE Tracker', 'model': '...    1611047789826
# 107  {'client': {'name': 'HERE Tracker', 'model': '...    1611047789826
# 108  {'client': {'name': 'HERE Tracker', 'model': '...    1611047491018
# 109  {'client': {'name': 'HERE Tracker', 'model': '...    1611047491018
# 110  {'client': {'name': 'HERE Tracker', 'model': '...    1611047491018
# 111  {'client': {'name': 'HERE Tracker', 'model': '...    1611047491018
# 112  {'client': {'name': 'HERE Tracker', 'model': '...    1611047491018
# 113  {'client': {'name': 'HERE Tracker', 'model': '...    1611047190534
# 114  {'client': {'name': 'HERE Tracker', 'model': '...    1611047190534
# 115  {'client': {'name': 'HERE Tracker', 'model': '...    1611047190534
# 116  {'client': {'name': 'HERE Tracker', 'model': '...    1611047190534
# 117  {'client': {'name': 'HERE Tracker', 'model': '...    1611047190534
# 118  {'client': {'name': 'HERE Tracker', 'model': '...    1611046890346
# 119  {'client': {'name': 'HERE Tracker', 'model': '...    1611046890346
# 120  {'client': {'name': 'HERE Tracker', 'model': '...    1611046890346
# 121  {'client': {'name': 'HERE Tracker', 'model': '...    1611046890346
# 122  {'client': {'name': 'HERE Tracker', 'model': '...    1611046890346
# 123  {'client': {'name': 'HERE Tracker', 'model': '...    1611046590093
# 124  {'client': {'name': 'HERE Tracker', 'model': '...    1611046590093
# 125  {'client': {'name': 'HERE Tracker', 'model': '...    1611046590093
# 126  {'client': {'name': 'HERE Tracker', 'model': '...    1611046590093
# 127  {'client': {'name': 'HERE Tracker', 'model': '...    1611046590093
# 128  {'client': {'name': 'HERE Tracker', 'model': '...    1611046288707
# 129  {'client': {'name': 'HERE Tracker', 'model': '...    1611046288707
# 130  {'client': {'name': 'HERE Tracker', 'model': '...    1611046288707
# 131  {'client': {'name': 'HERE Tracker', 'model': '...    1611046288707
# 132  {'client': {'name': 'HERE Tracker', 'model': '...    1611046288707
# 133  {'client': {'name': 'HERE Tracker', 'model': '...    1611045990561
# 134  {'client': {'name': 'HERE Tracker', 'model': '...    1611045990561
# 135  {'client': {'name': 'HERE Tracker', 'model': '...    1611045990561
# 136  {'client': {'name': 'HERE Tracker', 'model': '...    1611045990561
# 137  {'client': {'name': 'HERE Tracker', 'model': '...    1611045990561
# 138  {'client': {'name': 'HERE Tracker', 'model': '...    1611045689030
# 139  {'client': {'name': 'HERE Tracker', 'model': '...    1611045689030
# 140  {'client': {'name': 'HERE Tracker', 'model': '...    1611045689030
# 141  {'client': {'name': 'HERE Tracker', 'model': '...    1611045689030
# 142  {'client': {'name': 'HERE Tracker', 'model': '...    1611045689030
# 143  {'client': {'name': 'HERE Tracker', 'model': '...    1611045389607
# 144  {'client': {'name': 'HERE Tracker', 'model': '...    1611045389607
# 145  {'client': {'name': 'HERE Tracker', 'model': '...    1611045389607
# 146  {'client': {'name': 'HERE Tracker', 'model': '...    1611045389607
# 147  {'client': {'name': 'HERE Tracker', 'model': '...    1611045389607
# 148  {'client': {'name': 'HERE Tracker', 'model': '...    1611045089248

# %%
df = pd.json_normalize(trace.get('data'))
print(len(df))
df
# Out:
# 149
#          timestamp  serverTimestamp  position.alt  position.lat  position.lng  \
# 0    1611053946054    1611054100975          49.0     35.338304    139.500769
# 1    1611053886049    1611054100975          49.0     35.338303    139.500766
# 2    1611053825947    1611054100975          49.0     35.338294    139.500772
# 3    1611053765918    1611053792125          52.0     35.338265    139.500737
# 4    1611053705895    1611053792125          53.0     35.338253    139.500722
# 5    1611053645875    1611053792125          52.0     35.338254    139.500717
# 6    1611053585771    1611053792125          53.0     35.338249    139.500709
# 7    1611053525749    1611053792125          52.0     35.338259    139.500700
# 8    1611053465660    1611053492125          51.0     35.338268    139.500688
# 9    1611053405559    1611053492125          51.0     35.338274    139.500691
# 10   1611053345488    1611053492125          50.0     35.338234    139.500621
# 11   1611053285443    1611053492125          47.0     35.338284    139.500691
# 12   1611053225343    1611053492125          46.0     35.338287    139.500693
# 13   1611053165321    1611053191568          45.0     35.338289    139.500706
# 14   1611053105299    1611053191568          43.0     35.338297    139.500753
# 15   1611053045198    1611053191568          41.0     35.338301    139.500763
# 16   1611052985095    1611053191568          38.0     35.338299    139.500783
# 17   1611052925087    1611053191568          37.0     35.338304    139.500781
#
#      position.altaccuracy system.client.name system.client.model  \
# 0                     1.0       HERE Tracker            Pixel 3a
# 1                     1.0       HERE Tracker            Pixel 3a
# 2                     1.0       HERE Tracker            Pixel 3a
# 3                     1.0       HERE Tracker            Pixel 3a
# 4                     1.0       HERE Tracker            Pixel 3a
# 5                     1.0       HERE Tracker            Pixel 3a
# 6                     1.0       HERE Tracker            Pixel 3a
# 7                     1.0       HERE Tracker            Pixel 3a
# 8                     1.0       HERE Tracker            Pixel 3a
# 9                     1.0       HERE Tracker            Pixel 3a
# 10                   15.0       HERE Tracker            Pixel 3a
# 11                    1.0       HERE Tracker            Pixel 3a
# 12                    1.0       HERE Tracker            Pixel 3a
# 13                    1.0       HERE Tracker            Pixel 3a
# 14                    1.0       HERE Tracker            Pixel 3a
# 15                    1.0       HERE Tracker            Pixel 3a
# 16                    1.0       HERE Tracker            Pixel 3a
# 17                    1.0       HERE Tracker            Pixel 3a
# 18                    1.0       HERE Tracker            Pixel 3a
# 19                    1.0       HERE Tracker            Pixel 3a
# 20                    1.0       HERE Tracker            Pixel 3a
# 21                   14.0       HERE Tracker            Pixel 3a
# 22                   18.0       HERE Tracker            Pixel 3a
# 23                    1.0       HERE Tracker            Pixel 3a
# 24                    1.0       HERE Tracker            Pixel 3a
# 25                    1.0       HERE Tracker            Pixel 3a
# 26                    1.0       HERE Tracker            Pixel 3a
# 27                    1.0       HERE Tracker            Pixel 3a
# 28                    1.0       HERE Tracker            Pixel 3a
# 29                    1.0       HERE Tracker            Pixel 3a
# 30                    1.0       HERE Tracker            Pixel 3a
# 31                    1.0       HERE Tracker            Pixel 3a
# 32                    1.0       HERE Tracker            Pixel 3a
# 33                    1.0       HERE Tracker            Pixel 3a
# 34                    1.0       HERE Tracker            Pixel 3a
# 35                    1.0       HERE Tracker            Pixel 3a
# 36                    1.0       HERE Tracker            Pixel 3a
# 37                    1.0       HERE Tracker            Pixel 3a
# 38                    1.0       HERE Tracker            Pixel 3a
# 39                    1.0       HERE Tracker            Pixel 3a
# 40                    1.0       HERE Tracker            Pixel 3a
# 41                    1.0       HERE Tracker            Pixel 3a
# 42                    1.0       HERE Tracker            Pixel 3a
# 43                    1.0       HERE Tracker            Pixel 3a
# 44                    1.0       HERE Tracker            Pixel 3a
# 45                    1.0       HERE Tracker            Pixel 3a
# 46                    1.0       HERE Tracker            Pixel 3a
# 47                    1.0       HERE Tracker            Pixel 3a
# 48                    1.0       HERE Tracker            Pixel 3a
# 49                    1.0       HERE Tracker            Pixel 3a
# 50                    1.0       HERE Tracker            Pixel 3a
# 51                    1.0       HERE Tracker            Pixel 3a
# 52                    1.0       HERE Tracker            Pixel 3a
# 53                    1.0       HERE Tracker            Pixel 3a
# 54                    1.0       HERE Tracker            Pixel 3a
# 55                    1.0       HERE Tracker            Pixel 3a
# 56                    1.0       HERE Tracker            Pixel 3a
# 57                    1.0       HERE Tracker            Pixel 3a
# 58                    1.0       HERE Tracker            Pixel 3a
# 59                    1.0       HERE Tracker            Pixel 3a
# 60                    1.0       HERE Tracker            Pixel 3a
# 61                    1.0       HERE Tracker            Pixel 3a
# 62                    1.0       HERE Tracker            Pixel 3a
# 63                    1.0       HERE Tracker            Pixel 3a
# 64                    1.0       HERE Tracker            Pixel 3a
# 65                    1.0       HERE Tracker            Pixel 3a
# 66                    1.0       HERE Tracker            Pixel 3a
# 67                    1.0       HERE Tracker            Pixel 3a
# 68                    1.0       HERE Tracker            Pixel 3a
# 69                    1.0       HERE Tracker            Pixel 3a
# 70                    NaN       HERE Tracker            Pixel 3a
# 71                    1.0       HERE Tracker            Pixel 3a
# 72                    1.0       HERE Tracker            Pixel 3a
# 73                    1.0       HERE Tracker            Pixel 3a
# 74                    1.0       HERE Tracker            Pixel 3a
# 75                    1.0       HERE Tracker            Pixel 3a
# 76                 1000.0       HERE Tracker            Pixel 3a
# 77                 1000.0       HERE Tracker            Pixel 3a
# 78                    1.0       HERE Tracker            Pixel 3a
# 79                    1.0       HERE Tracker            Pixel 3a
# 80                    1.0       HERE Tracker            Pixel 3a
# 81                    1.0       HERE Tracker            Pixel 3a
# 82                    1.0       HERE Tracker            Pixel 3a
# 83                    1.0       HERE Tracker            Pixel 3a
# 84                    1.0       HERE Tracker            Pixel 3a
# 85                    1.0       HERE Tracker            Pixel 3a
# 86                    1.0       HERE Tracker            Pixel 3a
# 87                    1.0       HERE Tracker            Pixel 3a
# 88                    1.0       HERE Tracker            Pixel 3a
# 89                    1.0       HERE Tracker            Pixel 3a
# 90                    1.0       HERE Tracker            Pixel 3a
# 91                    1.0       HERE Tracker            Pixel 3a
# 92                    1.0       HERE Tracker            Pixel 3a
# 93                    1.0       HERE Tracker            Pixel 3a
# 94                    1.0       HERE Tracker            Pixel 3a
# 95                    1.0       HERE Tracker            Pixel 3a
# 96                    1.0       HERE Tracker            Pixel 3a
# 97                    1.0       HERE Tracker            Pixel 3a
# 98                    1.0       HERE Tracker            Pixel 3a
# 99                    1.0       HERE Tracker            Pixel 3a
# 100                   1.0       HERE Tracker            Pixel 3a
# 101                   1.0       HERE Tracker            Pixel 3a
# 102                   1.0       HERE Tracker            Pixel 3a
# 103                   1.0       HERE Tracker            Pixel 3a
# 104                   1.0       HERE Tracker            Pixel 3a
# 105                   1.0       HERE Tracker            Pixel 3a
# 106                   1.0       HERE Tracker            Pixel 3a
# 107                   1.0       HERE Tracker            Pixel 3a
# 108                   1.0       HERE Tracker            Pixel 3a
# 109                   1.0       HERE Tracker            Pixel 3a
# 110                   1.0       HERE Tracker            Pixel 3a
# 111                   1.0       HERE Tracker            Pixel 3a
# 112                   1.0       HERE Tracker            Pixel 3a
# 113                   1.0       HERE Tracker            Pixel 3a
# 114                   1.0       HERE Tracker            Pixel 3a
# 115                   1.0       HERE Tracker            Pixel 3a
# 116                   1.0       HERE Tracker            Pixel 3a
# 117                   1.0       HERE Tracker            Pixel 3a
# 118                   1.0       HERE Tracker            Pixel 3a
# 119                   1.0       HERE Tracker            Pixel 3a
# 120                   1.0       HERE Tracker            Pixel 3a
# 121                   1.0       HERE Tracker            Pixel 3a
# 122                   1.0       HERE Tracker            Pixel 3a
# 123                   1.0       HERE Tracker            Pixel 3a
# 124                   1.0       HERE Tracker            Pixel 3a
# 125                   1.0       HERE Tracker            Pixel 3a
# 126                   1.0       HERE Tracker            Pixel 3a
# 127                   1.0       HERE Tracker            Pixel 3a
# 128                   1.0       HERE Tracker            Pixel 3a
# 129                   1.0       HERE Tracker            Pixel 3a
# 130                   1.0       HERE Tracker            Pixel 3a
# 131                  18.0       HERE Tracker            Pixel 3a
# 132                  19.0       HERE Tracker            Pixel 3a
# 133                   1.0       HERE Tracker            Pixel 3a
# 134                   1.0       HERE Tracker            Pixel 3a
# 135                   1.0       HERE Tracker            Pixel 3a
# 136                   1.0       HERE Tracker            Pixel 3a
# 137                   1.0       HERE Tracker            Pixel 3a
# 138                   1.0       HERE Tracker            Pixel 3a
# 139                   1.0       HERE Tracker            Pixel 3a
# 140                   1.0       HERE Tracker            Pixel 3a
# 141                   1.0       HERE Tracker            Pixel 3a
# 142                   1.0       HERE Tracker            Pixel 3a
# 143                   1.0       HERE Tracker            Pixel 3a
# 144                  14.0       HERE Tracker            Pixel 3a
# 145                   1.0       HERE Tracker            Pixel 3a
# 146                   1.0       HERE Tracker            Pixel 3a
# 147                   1.0       HERE Tracker            Pixel 3a
# 148                  15.0       HERE Tracker            Pixel 3a
#
#     system.client.version system.client.firmware system.client.platform  \
# 0                   1.1.5        RQ1A.210105.002                android
# 1                   1.1.5        RQ1A.210105.002                android
# 2                   1.1.5        RQ1A.210105.002                android
# 3                   1.1.5        RQ1A.210105.002                android
# 4                   1.1.5        RQ1A.210105.002                android
# 5                   1.1.5        RQ1A.210105.002                android
# 6                   1.1.5        RQ1A.210105.002                android
# 7                   1.1.5        RQ1A.210105.002                android
# 8                   1.1.5        RQ1A.210105.002                android
# 9                   1.1.5        RQ1A.210105.002                android
# 10                  1.1.5        RQ1A.210105.002                android
# 11                  1.1.5        RQ1A.210105.002                android
# 12                  1.1.5        RQ1A.210105.002                android
# 13                  1.1.5        RQ1A.210105.002                android
# 14                  1.1.5        RQ1A.210105.002                android
# 15                  1.1.5        RQ1A.210105.002                android
# 16                  1.1.5        RQ1A.210105.002                android
# 17                  1.1.5        RQ1A.210105.002                android
# 18                  1.1.5        RQ1A.210105.002                android
# 19                  1.1.5        RQ1A.210105.002                android
# 20                  1.1.5        RQ1A.210105.002                android
# 21                  1.1.5        RQ1A.210105.002                android
# 22                  1.1.5        RQ1A.210105.002                android
# 23                  1.1.5        RQ1A.210105.002                android
# 24                  1.1.5        RQ1A.210105.002                android
# 25                  1.1.5        RQ1A.210105.002                android
# 26                  1.1.5        RQ1A.210105.002                android
# 27                  1.1.5        RQ1A.210105.002                android
# 28                  1.1.5        RQ1A.210105.002                android
# 29                  1.1.5        RQ1A.210105.002                android
# 30                  1.1.5        RQ1A.210105.002                android
# 31                  1.1.5        RQ1A.210105.002                android
# 32                  1.1.5        RQ1A.210105.002                android
# 33                  1.1.5        RQ1A.210105.002                android
# 98                  1.1.5        RQ1A.210105.002                android
# 99                  1.1.5        RQ1A.210105.002                android
# 100                 1.1.5        RQ1A.210105.002                android
# 101                 1.1.5        RQ1A.210105.002                android
# 102                 1.1.5        RQ1A.210105.002                android
# 103                 1.1.5        RQ1A.210105.002                android
# 104                 1.1.5        RQ1A.210105.002                android
# 105                 1.1.5        RQ1A.210105.002                android
# 106                 1.1.5        RQ1A.210105.002                android
# 107                 1.1.5        RQ1A.210105.002                android
# 108                 1.1.5        RQ1A.210105.002                android
# 109                 1.1.5        RQ1A.210105.002                android
# 110                 1.1.5        RQ1A.210105.002                android
# 111                 1.1.5        RQ1A.210105.002                android
# 112                 1.1.5        RQ1A.210105.002                android
# 113                 1.1.5        RQ1A.210105.002                android
# 114                 1.1.5        RQ1A.210105.002                android
# 115                 1.1.5        RQ1A.210105.002                android
# 116                 1.1.5        RQ1A.210105.002                android
# 117                 1.1.5        RQ1A.210105.002                android
# 118                 1.1.5        RQ1A.210105.002                android
# 119                 1.1.5        RQ1A.210105.002                android
# 120                 1.1.5        RQ1A.210105.002                android
# 121                 1.1.5        RQ1A.210105.002                android
# 122                 1.1.5        RQ1A.210105.002                android
# 123                 1.1.5        RQ1A.210105.002                android
# 124                 1.1.5        RQ1A.210105.002                android
# 125                 1.1.5        RQ1A.210105.002                android
# 126                 1.1.5        RQ1A.210105.002                android
# 127                 1.1.5        RQ1A.210105.002                android
# 128                 1.1.5        RQ1A.210105.002                android
# 129                 1.1.5        RQ1A.210105.002                android
# 130                 1.1.5        RQ1A.210105.002                android
# 131                 1.1.5        RQ1A.210105.002                android
# 132                 1.1.5        RQ1A.210105.002                android
# 133                 1.1.5        RQ1A.210105.002                android
# 134                 1.1.5        RQ1A.210105.002                android
# 135                 1.1.5        RQ1A.210105.002                android
# 136                 1.1.5        RQ1A.210105.002                android
# 137                 1.1.5        RQ1A.210105.002                android
# 138                 1.1.5        RQ1A.210105.002                android
# 139                 1.1.5        RQ1A.210105.002                android
# 140                 1.1.5        RQ1A.210105.002                android
# 141                 1.1.5        RQ1A.210105.002                android
# 142                 1.1.5        RQ1A.210105.002                android
# 143                 1.1.5        RQ1A.210105.002                android
# 144                 1.1.5        RQ1A.210105.002                android
# 145                 1.1.5        RQ1A.210105.002                android
# 146                 1.1.5        RQ1A.210105.002                android
# 147                 1.1.5        RQ1A.210105.002                android
# 148                 1.1.5        RQ1A.210105.002                android
#
#     system.client.manufacturer  system.reportedSensorData.batteryLevel  \
# 0                       Google                                      37
# 1                       Google                                      37
# 2                       Google                                      37
# 3                       Google                                      37
# 4                       Google                                      37
# 5                       Google                                      37
# 6                       Google                                      37
# 7                       Google                                      37
# 8                       Google                                      37
# 9                       Google                                      37
# 10                      Google                                      37
# 11                      Google                                      37
# 12                      Google                                      37
# 13                      Google                                      37
# 14                      Google                                      37
# 15                      Google                                      37
# 16                      Google                                      37
# 17                      Google                                      37
# 18                      Google                                      37
# 19                      Google                                      37
# 20                      Google                                      37
# 21                      Google                                      37
# 22                      Google                                      38
# 23                      Google                                      38
# 24                      Google                                      38
# 25                      Google                                      38
# 26                      Google                                      38
# 27                      Google                                      38
# 28                      Google                                      38
# 29                      Google                                      39
# 30                      Google                                      39
# 31                      Google                                      39
# 32                      Google                                      39
# 33                      Google                                      39
# 34                      Google                                      39
# 35                      Google                                      39
# 36                      Google                                      39
# 37                      Google                                      39
# 38                      Google                                      39
# ...
# 73                      Google                                      43
# 74                      Google                                      43
# 75                      Google                                      43
# 76                      Google                                      43
# 77                      Google                                      43
# 78                      Google                                      44
# 79                      Google                                      44
# 80                      Google                                      44
# 81                      Google                                      44
# 82                      Google                                      44
# 83                      Google                                      44
# 84                      Google                                      44
# 85                      Google                                      44
# 86                      Google                                      44
# 87                      Google                                      45
# 88                      Google                                      45
# 89                      Google                                      45
# 90                      Google                                      46
# 91                      Google                                      46
# 92                      Google                                      46
# 93                      Google                                      46
# 94                      Google                                      46
# 95                      Google                                      46
# 96                      Google                                      46
# 97                      Google                                      46
# 98                      Google                                      46
# 99                      Google                                      46
# 100                     Google                                      46
# 101                     Google                                      46
# 102                     Google                                      46
# 103                     Google                                      47
# 104                     Google                                      47
# 105                     Google                                      47
# 106                     Google                                      47
# 107                     Google                                      47
# 108                     Google                                      47
# 109                     Google                                      47
# 110                     Google                                      47
# 111                     Google                                      47
# 112                     Google                                      47
# 113                     Google                                      47
# 114                     Google                                      47
# 115                     Google                                      47
# 116                     Google                                      48
# 117                     Google                                      48
# 118                     Google                                      48
# 119                     Google                                      48
# 120                     Google                                      48
# 121                     Google                                      48
# 122                     Google                                      49
# 123                     Google                                      49
# 124                     Google                                      49
# 125                     Google                                      49
# 126                     Google                                      49
# 127                     Google                                      49
# 128                     Google                                      49
# 129                     Google                                      50
# 130                     Google                                      50
# 131                     Google                                      50
# 132                     Google                                      50
# 133                     Google                                      50
# 134                     Google                                      50
# 135                     Google                                      50
# 136                     Google                                      50
# 137                     Google                                      51
# 138                     Google                                      51
# 139                     Google                                      51
# 140                     Google                                      51
# 141                     Google                                      51
# 142                     Google                                      51
# 143                     Google                                      51
# 144                     Google                                      51
# 145                     Google                                      51
# 146                     Google                                      51
# 147                     Google                                      51
# 148                     Google                                      51
#
#      system.reportedSensorData.batteryIsCharging  position.heading
# 0                                          False               NaN
# 1                                          False               NaN
# 2                                          False               NaN
# 3                                          False               NaN
# 4                                          False               NaN
# 5                                          False               NaN
# 6                                          False               NaN
# 7                                          False               NaN
# 8                                          False               NaN
# 9                                          False               NaN
# 10                                         False               NaN
# 11                                         False               NaN
# 12                                         False               NaN
# 13                                         False               NaN
# 14                                         False               NaN
# 15                                         False               NaN
# 16                                         False               NaN
# 17                                         False               NaN
# 18                                         False               NaN
# 19                                         False               NaN
# 20                                         False               NaN
# 21                                         False               NaN
# 22                                         False               NaN
# 23                                         False             148.0
# 24                                         False             309.0
# 25                                         False               NaN
# 26                                         False               NaN
# 27                                         False             152.0
# 28                                         False               NaN
# 29                                         False               NaN
# 30                                         False               NaN
# 31                                         False               NaN
# 32                                         False              55.0
# 33                                         False               NaN
# 34                                         False              91.0
# 35                                         False              78.0
# 36                                         False              95.0
# 37                                         False             145.0
# 38                                         False               NaN
# 39                                         False               NaN
# 40                                         False             266.0
# 41                                         False               NaN
# 42                                         False               NaN
# 43                                         False               NaN
# 44                                         False               NaN
# 45                                         False             173.0
# 46                                         False               NaN
# 47                                         False               NaN
# 48                                         False               NaN
# 49                                         False               NaN
# 50                                         False               NaN
# 51                                         False               NaN
# 52                                         False             210.0
# 53                                         False             343.0
# 54                                         False             165.0
# 55                                         False               NaN
# 56                                         False              15.0
# 57                                         False             245.0
# 58                                         False               NaN
# 59                                         False               NaN
# 60                                         False               NaN
# 61                                         False               NaN
# 62                                         False               NaN
# 63                                         False               NaN
# 64                                         False               NaN
# 65                                         False               NaN
# 66                                         False               NaN
# 67                                         False               NaN
# 68                                         False             238.0
# 69                                         False             284.0
# 70                                         False               NaN
# 71                                         False             255.0
# 72                                         False             301.0
# 73                                         False             341.0
# 74                                         False             340.0
# 75                                         False               NaN
# 76                                         False               NaN
# 77                                         False               NaN
# 78                                         False               NaN
# 79                                         False              29.0
# 80                                         False               NaN
# 81                                         False              82.0
# 82                                         False             194.0
# 83                                         False             197.0
# 84                                         False             185.0
# 85                                         False               NaN
# 86                                         False              99.0
# 87                                         False               NaN
# 88                                         False               NaN
# 89                                         False              73.0
# 90                                         False              81.0
# 91                                         False               NaN
# 92                                         False              82.0
# 93                                         False               NaN
# 94                                         False               NaN
# 95                                         False               NaN
# 96                                         False               NaN
# 97                                         False               NaN
# 98                                         False               NaN
# 99                                         False             281.0
# 100                                        False             256.0
# 101                                        False               NaN
# 102                                        False               NaN
# 103                                        False               NaN
# 104                                        False               NaN
# 105                                        False             248.0
# 106                                        False               NaN
# 107                                        False             252.0
# 108                                        False               NaN
# 109                                        False               NaN
# 110                                        False               NaN
# 111                                        False             346.0
# 112                                        False               NaN
# 113                                        False               NaN
# 114                                        False             185.0
# 115                                        False             252.0
# 116                                        False             271.0
# 117                                        False               NaN
# 118                                        False             270.0
# 119                                        False               NaN
# 120                                        False               NaN
# 121                                        False               NaN
# 122                                        False               NaN
# 123                                        False               NaN
# 124                                        False               NaN
# 125                                        False               NaN
# 126                                        False             333.0
# 127                                        False               NaN
# 128                                        False             199.0
# 129                                        False             253.0
# 130                                        False               NaN
# 131                                        False               NaN
# 132                                        False               NaN
# 133                                        False               NaN
# 134                                        False               NaN
# 135                                        False               NaN
# 136                                        False               NaN
# 137                                        False              59.0
# 138                                        False               NaN
# 139                                        False               NaN
# 140                                        False               NaN
# 141                                        False               NaN
# 142                                        False               NaN
# 143                                        False               NaN
# 144                                        False               NaN
# 145                                        False               NaN
# 146                                        False               NaN
# 147                                        False               NaN
# 148                                        False               NaN

# %%
#dfの緯度経度どちらかにnanが１つでもある行を削除
df2= df.dropna(subset=['position.lat', 'position.lng'])
print(len(df2))
df2
# Out:
# 148
#          timestamp  serverTimestamp  position.alt  position.lat  position.lng  \
# 0    1611053946054    1611054100975          49.0     35.338304    139.500769
# 130          gnss             0.0          22.766346        1.611046e+12
# 131          wlan             NaN          29.000000                 NaN
# 132          wlan             NaN          35.000000                 NaN
# 133          gnss             0.0          11.875839        1.611046e+12
# 134          gnss             0.0          23.195665        1.611046e+12
# 135          gnss             0.0          11.383431        1.611046e+12
# 136          gnss             0.0          12.267021        1.611046e+12
# 137          gnss             1.0          21.073423        1.611046e+12
# 138          gnss             0.0          18.854187        1.611046e+12
# 139          gnss             0.0           6.670630        1.611046e+12
# 140          gnss             0.0           5.997530        1.611046e+12
# 141          gnss             0.0          16.240465        1.611045e+12
# 142          gnss             0.0           7.349484        1.611045e+12
# 143          gnss             0.0           9.839346        1.611045e+12
# 144          wlan             NaN          25.000000                 NaN
# 145          gnss             0.0           9.572072        1.611045e+12
# 146          gnss             0.0           4.360133        1.611045e+12
# 147          gnss             0.0           6.827190        1.611045e+12
# 148          wlan             NaN          25.000000                 NaN
#
#      position.altaccuracy system.client.name system.client.model  \
# 0                     1.0       HERE Tracker            Pixel 3a
# 1                     1.0       HERE Tracker            Pixel 3a
# 2                     1.0       HERE Tracker            Pixel 3a
# 3                     1.0       HERE Tracker            Pixel 3a
# 4                     1.0       HERE Tracker            Pixel 3a
# 5                     1.0       HERE Tracker            Pixel 3a
# 6                     1.0       HERE Tracker            Pixel 3a
# 7                     1.0       HERE Tracker            Pixel 3a
# 8                     1.0       HERE Tracker            Pixel 3a
# 9                     1.0       HERE Tracker            Pixel 3a
# 10                   15.0       HERE Tracker            Pixel 3a
# 11                    1.0       HERE Tracker            Pixel 3a
# 12                    1.0       HERE Tracker            Pixel 3a
# 13                    1.0       HERE Tracker            Pixel 3a
# 14                    1.0       HERE Tracker            Pixel 3a
# 15                    1.0       HERE Tracker            Pixel 3a
# 16                    1.0       HERE Tracker            Pixel 3a
# 17                    1.0       HERE Tracker            Pixel 3a
# 18                    1.0       HERE Tracker            Pixel 3a
# 19                    1.0       HERE Tracker            Pixel 3a
# 20                    1.0       HERE Tracker            Pixel 3a
# 21                   14.0       HERE Tracker            Pixel 3a
# 22                   18.0       HERE Tracker            Pixel 3a
# 23                    1.0       HERE Tracker            Pixel 3a
# 24                    1.0       HERE Tracker            Pixel 3a
# 25                    1.0       HERE Tracker            Pixel 3a
# 26                    1.0       HERE Tracker            Pixel 3a
# 27                    1.0       HERE Tracker            Pixel 3a
# 28                    1.0       HERE Tracker            Pixel 3a
# 29                    1.0       HERE Tracker            Pixel 3a
# 30                    1.0       HERE Tracker            Pixel 3a
# 31                    1.0       HERE Tracker            Pixel 3a
# 32                    1.0       HERE Tracker            Pixel 3a
# 33                    1.0       HERE Tracker            Pixel 3a
# 34                    1.0       HERE Tracker            Pixel 3a
# 35                    1.0       HERE Tracker            Pixel 3a
# 36                    1.0       HERE Tracker            Pixel 3a
# 37                    1.0       HERE Tracker            Pixel 3a
# 38                    1.0       HERE Tracker            Pixel 3a
# 39                    1.0       HERE Tracker            Pixel 3a
# 40                    1.0       HERE Tracker            Pixel 3a
# 41                    1.0       HERE Tracker            Pixel 3a
# 42                    1.0       HERE Tracker            Pixel 3a
# 43                    1.0       HERE Tracker            Pixel 3a
# 44                    1.0       HERE Tracker            Pixel 3a
# 45                    1.0       HERE Tracker            Pixel 3a
# 46                    1.0       HERE Tracker            Pixel 3a
# 47                    1.0       HERE Tracker            Pixel 3a
# 48                    1.0       HERE Tracker            Pixel 3a
# 49                    1.0       HERE Tracker            Pixel 3a
# 50                    1.0       HERE Tracker            Pixel 3a
# 51                    1.0       HERE Tracker            Pixel 3a
# 52                    1.0       HERE Tracker            Pixel 3a
# 53                    1.0       HERE Tracker            Pixel 3a
# 54                    1.0       HERE Tracker            Pixel 3a
# 55                    1.0       HERE Tracker            Pixel 3a
# 56                    1.0       HERE Tracker            Pixel 3a
# 57                    1.0       HERE Tracker            Pixel 3a
# 58                    1.0       HERE Tracker            Pixel 3a
# 59                    1.0       HERE Tracker            Pixel 3a
# 60                    1.0       HERE Tracker            Pixel 3a
# 61                    1.0       HERE Tracker            Pixel 3a
# 62                    1.0       HERE Tracker            Pixel 3a
# 63                    1.0       HERE Tracker            Pixel 3a
# 64                    1.0       HERE Tracker            Pixel 3a
# 65                    1.0       HERE Tracker            Pixel 3a
# 66                    1.0       HERE Tracker            Pixel 3a
# 67                    1.0       HERE Tracker            Pixel 3a
# 68                    1.0       HERE Tracker            Pixel 3a
# 69                    1.0       HERE Tracker            Pixel 3a
# 71                    1.0       HERE Tracker            Pixel 3a
# 72                    1.0       HERE Tracker            Pixel 3a
# 73                    1.0       HERE Tracker            Pixel 3a
# 74                    1.0       HERE Tracker            Pixel 3a
# 75                    1.0       HERE Tracker            Pixel 3a
# 76                 1000.0       HERE Tracker            Pixel 3a
# 77                 1000.0       HERE Tracker            Pixel 3a
# 78                    1.0       HERE Tracker            Pixel 3a
# 79                    1.0       HERE Tracker            Pixel 3a
# 80                    1.0       HERE Tracker            Pixel 3a
# 81                    1.0       HERE Tracker            Pixel 3a
# 82                    1.0       HERE Tracker            Pixel 3a
# 83                    1.0       HERE Tracker            Pixel 3a
# 84                    1.0       HERE Tracker            Pixel 3a
# 85                    1.0       HERE Tracker            Pixel 3a
# 86                    1.0       HERE Tracker            Pixel 3a
# 87                    1.0       HERE Tracker            Pixel 3a
# 88                    1.0       HERE Tracker            Pixel 3a
# 89                    1.0       HERE Tracker            Pixel 3a
# 90                    1.0       HERE Tracker            Pixel 3a
# 91                    1.0       HERE Tracker            Pixel 3a
# 92                    1.0       HERE Tracker            Pixel 3a
# 93                    1.0       HERE Tracker            Pixel 3a
# 94                    1.0       HERE Tracker            Pixel 3a
# 95                    1.0       HERE Tracker            Pixel 3a
# 96                    1.0       HERE Tracker            Pixel 3a
# 97                    1.0       HERE Tracker            Pixel 3a
# 98                    1.0       HERE Tracker            Pixel 3a
# 99                    1.0       HERE Tracker            Pixel 3a
# 100                   1.0       HERE Tracker            Pixel 3a
# 101                   1.0       HERE Tracker            Pixel 3a
# 102                   1.0       HERE Tracker            Pixel 3a
# 103                   1.0       HERE Tracker            Pixel 3a
# 104                   1.0       HERE Tracker            Pixel 3a
# 105                   1.0       HERE Tracker            Pixel 3a
# 106                   1.0       HERE Tracker            Pixel 3a
# 107                   1.0       HERE Tracker            Pixel 3a
# 108                   1.0       HERE Tracker            Pixel 3a
# 109                   1.0       HERE Tracker            Pixel 3a
# 110                   1.0       HERE Tracker            Pixel 3a
# 111                   1.0       HERE Tracker            Pixel 3a
# 112                   1.0       HERE Tracker            Pixel 3a
# 113                   1.0       HERE Tracker            Pixel 3a
# 114                   1.0       HERE Tracker            Pixel 3a
# 115                   1.0       HERE Tracker            Pixel 3a
# 116                   1.0       HERE Tracker            Pixel 3a
# 117                   1.0       HERE Tracker            Pixel 3a
# 118                   1.0       HERE Tracker            Pixel 3a
# 119                   1.0       HERE Tracker            Pixel 3a
# 120                   1.0       HERE Tracker            Pixel 3a
# 121                   1.0       HERE Tracker            Pixel 3a
# 122                   1.0       HERE Tracker            Pixel 3a
# 123                   1.0       HERE Tracker            Pixel 3a
# 124                   1.0       HERE Tracker            Pixel 3a
# 125                   1.0       HERE Tracker            Pixel 3a
# 126                   1.0       HERE Tracker            Pixel 3a
# 127                   1.0       HERE Tracker            Pixel 3a
# 128                   1.0       HERE Tracker            Pixel 3a
# 129                   1.0       HERE Tracker            Pixel 3a
# 130                   1.0       HERE Tracker            Pixel 3a
# 131                  18.0       HERE Tracker            Pixel 3a
# 132                  19.0       HERE Tracker            Pixel 3a
# 133                   1.0       HERE Tracker            Pixel 3a
# 134                   1.0       HERE Tracker            Pixel 3a
# 135                   1.0       HERE Tracker            Pixel 3a
# 136                   1.0       HERE Tracker            Pixel 3a
# 137                   1.0       HERE Tracker            Pixel 3a
# 138                   1.0       HERE Tracker            Pixel 3a
# 139                   1.0       HERE Tracker            Pixel 3a
# 140                   1.0       HERE Tracker            Pixel 3a
# 141                   1.0       HERE Tracker            Pixel 3a
# 142                   1.0       HERE Tracker            Pixel 3a
# 143                   1.0       HERE Tracker            Pixel 3a
# 144                  14.0       HERE Tracker            Pixel 3a
# 145                   1.0       HERE Tracker            Pixel 3a
# 146                   1.0       HERE Tracker            Pixel 3a
# 147                   1.0       HERE Tracker            Pixel 3a
# 148                  15.0       HERE Tracker            Pixel 3a
#
#     system.client.version system.client.firmware system.client.platform  \
# 0                   1.1.5        RQ1A.210105.002                android
# 1                   1.1.5        RQ1A.210105.002                android
# 2                   1.1.5        RQ1A.210105.002                android
# 3                   1.1.5        RQ1A.210105.002                android
# 4                   1.1.5        RQ1A.210105.002                android
# 5                   1.1.5        RQ1A.210105.002                android
# 6                   1.1.5        RQ1A.210105.002                android
# 7                   1.1.5        RQ1A.210105.002                android
# 8                   1.1.5        RQ1A.210105.002                android
# 9                   1.1.5        RQ1A.210105.002                android
# 10                  1.1.5        RQ1A.210105.002                android
# 11                  1.1.5        RQ1A.210105.002                android
# 12                  1.1.5        RQ1A.210105.002                android
# 13                  1.1.5        RQ1A.210105.002                android
# 14                  1.1.5        RQ1A.210105.002                android
# 15                  1.1.5        RQ1A.210105.002                android
# 81                  1.1.5        RQ1A.210105.002                android
# 82                  1.1.5        RQ1A.210105.002                android
# 83                  1.1.5        RQ1A.210105.002                android
# 84                  1.1.5        RQ1A.210105.002                android
# 85                  1.1.5        RQ1A.210105.002                android
# 86                  1.1.5        RQ1A.210105.002                android
# 87                  1.1.5        RQ1A.210105.002                android
# 88                  1.1.5        RQ1A.210105.002                android
# 89                  1.1.5        RQ1A.210105.002                android
# 90                  1.1.5        RQ1A.210105.002                android
# 91                  1.1.5        RQ1A.210105.002                android
# 92                  1.1.5        RQ1A.210105.002                android
# 93                  1.1.5        RQ1A.210105.002                android
# 94                  1.1.5        RQ1A.210105.002                android
# 95                  1.1.5        RQ1A.210105.002                android
# 96                  1.1.5        RQ1A.210105.002                android
# 97                  1.1.5        RQ1A.210105.002                android
# 98                  1.1.5        RQ1A.210105.002                android
# 99                  1.1.5        RQ1A.210105.002                android
# 100                 1.1.5        RQ1A.210105.002                android
# 101                 1.1.5        RQ1A.210105.002                android
# 102                 1.1.5        RQ1A.210105.002                android
# 103                 1.1.5        RQ1A.210105.002                android
# 104                 1.1.5        RQ1A.210105.002                android
# 105                 1.1.5        RQ1A.210105.002                android
# 106                 1.1.5        RQ1A.210105.002                android
# 107                 1.1.5        RQ1A.210105.002                android
# 108                 1.1.5        RQ1A.210105.002                android
# 109                 1.1.5        RQ1A.210105.002                android
# 110                 1.1.5        RQ1A.210105.002                android
# 111                 1.1.5        RQ1A.210105.002                android
# 112                 1.1.5        RQ1A.210105.002                android
# 113                 1.1.5        RQ1A.210105.002                android
# 114                 1.1.5        RQ1A.210105.002                android
# 115                 1.1.5        RQ1A.210105.002                android
# 116                 1.1.5        RQ1A.210105.002                android
# 117                 1.1.5        RQ1A.210105.002                android
# 118                 1.1.5        RQ1A.210105.002                android
# 119                 1.1.5        RQ1A.210105.002                android
# 120                 1.1.5        RQ1A.210105.002                android
# 121                 1.1.5        RQ1A.210105.002                android
# 122                 1.1.5        RQ1A.210105.002                android
# 123                 1.1.5        RQ1A.210105.002                android
# 124                 1.1.5        RQ1A.210105.002                android
# 125                 1.1.5        RQ1A.210105.002                android
# 126                 1.1.5        RQ1A.210105.002                android
# 127                 1.1.5        RQ1A.210105.002                android
# 128                 1.1.5        RQ1A.210105.002                android
# 129                 1.1.5        RQ1A.210105.002                android
# 130                 1.1.5        RQ1A.210105.002                android
# 131                 1.1.5        RQ1A.210105.002                android
# 132                 1.1.5        RQ1A.210105.002                android
# 133                 1.1.5        RQ1A.210105.002                android
# 134                 1.1.5        RQ1A.210105.002                android
# 135                 1.1.5        RQ1A.210105.002                android
# 136                 1.1.5        RQ1A.210105.002                android
# 137                 1.1.5        RQ1A.210105.002                android
# 138                 1.1.5        RQ1A.210105.002                android
# 139                 1.1.5        RQ1A.210105.002                android
# 140                 1.1.5        RQ1A.210105.002                android
# 141                 1.1.5        RQ1A.210105.002                android
# 142                 1.1.5        RQ1A.210105.002                android
# 143                 1.1.5        RQ1A.210105.002                android
# 144                 1.1.5        RQ1A.210105.002                android
# 145                 1.1.5        RQ1A.210105.002                android
# 146                 1.1.5        RQ1A.210105.002                android
# 147                 1.1.5        RQ1A.210105.002                android
# 148                 1.1.5        RQ1A.210105.002                android
#
#     system.client.manufacturer  system.reportedSensorData.batteryLevel  \
# 0                       Google                                      37
# 1                       Google                                      37
# 2                       Google                                      37
# 3                       Google                                      37
# 4                       Google                                      37
# 5                       Google                                      37
# 6                       Google                                      37
# 7                       Google                                      37
# 8                       Google                                      37
# 9                       Google                                      37
# 10                      Google                                      37
# 11                      Google                                      37
# 12                      Google                                      37
# 13                      Google                                      37
# 14                      Google                                      37
# 15                      Google                                      37
# 16                      Google                                      37
# 17                      Google                                      37
# 18                      Google                                      37
# 19                      Google                                      37
# 20                      Google                                      37
# 21                      Google                                      37
# 22                      Google                                      38
# 23                      Google                                      38
# 24                      Google                                      38
# 25                      Google                                      38
# 26                      Google                                      38
# 27                      Google                                      38
# 28                      Google                                      38
# 29                      Google                                      39
# 30                      Google                                      39
# 31                      Google                                      39
# 32                      Google                                      39
# 33                      Google                                      39
# 34                      Google                                      39
# 35                      Google                                      39
# 36                      Google                                      39
# 37                      Google                                      39
# 38                      Google                                      39
# 39                      Google                                      39
# 40                      Google                                      39
# 41                      Google                                      39
# 42                      Google                                      39
# ...
# 72                      Google                                      43
# 73                      Google                                      43
# 74                      Google                                      43
# 75                      Google                                      43
# 76                      Google                                      43
# 77                      Google                                      43
# 78                      Google                                      44
# 79                      Google                                      44
# 80                      Google                                      44
# 81                      Google                                      44
# 82                      Google                                      44
# 83                      Google                                      44
# 84                      Google                                      44
# 85                      Google                                      44
# 86                      Google                                      44
# 87                      Google                                      45
# 88                      Google                                      45
# 89                      Google                                      45
# 90                      Google                                      46
# 91                      Google                                      46
# 92                      Google                                      46
# 93                      Google                                      46
# 94                      Google                                      46
# 95                      Google                                      46
# 96                      Google                                      46
# 97                      Google                                      46
# 98                      Google                                      46
# 99                      Google                                      46
# 100                     Google                                      46
# 101                     Google                                      46
# 102                     Google                                      46
# 103                     Google                                      47
# 104                     Google                                      47
# 105                     Google                                      47
# 106                     Google                                      47
# 107                     Google                                      47
# 108                     Google                                      47
# 109                     Google                                      47
# 110                     Google                                      47
# 111                     Google                                      47
# 112                     Google                                      47
# 113                     Google                                      47
# 114                     Google                                      47
# 115                     Google                                      47
# 116                     Google                                      48
# 117                     Google                                      48
# 118                     Google                                      48
# 119                     Google                                      48
# 120                     Google                                      48
# 121                     Google                                      48
# 122                     Google                                      49
# 123                     Google                                      49
# 124                     Google                                      49
# 125                     Google                                      49
# 126                     Google                                      49
# 127                     Google                                      49
# 128                     Google                                      49
# 129                     Google                                      50
# 130                     Google                                      50
# 131                     Google                                      50
# 132                     Google                                      50
# 133                     Google                                      50
# 134                     Google                                      50
# 135                     Google                                      50
# 136                     Google                                      50
# 137                     Google                                      51
# 138                     Google                                      51
# 139                     Google                                      51
# 140                     Google                                      51
# 141                     Google                                      51
# 142                     Google                                      51
# 143                     Google                                      51
# 144                     Google                                      51
# 145                     Google                                      51
# 146                     Google                                      51
# 147                     Google                                      51
# 148                     Google                                      51
#
#      system.reportedSensorData.batteryIsCharging  position.heading
# 0                                          False               NaN
# 1                                          False               NaN
# 2                                          False               NaN
# 3                                          False               NaN
# 4                                          False               NaN
# 5                                          False               NaN
# 6                                          False               NaN
# 7                                          False               NaN
# 8                                          False               NaN
# 9                                          False               NaN
# 10                                         False               NaN
# 11                                         False               NaN
# 12                                         False               NaN
# 13                                         False               NaN
# 14                                         False               NaN
# 15                                         False               NaN
# 16                                         False               NaN
# 17                                         False               NaN
# 18                                         False               NaN
# 19                                         False               NaN
# 20                                         False               NaN
# 21                                         False               NaN
# 22                                         False               NaN
# 23                                         False             148.0
# 24                                         False             309.0
# 25                                         False               NaN
# 26                                         False               NaN
# 27                                         False             152.0
# 28                                         False               NaN
# 29                                         False               NaN
# 30                                         False               NaN
# 31                                         False               NaN
# 32                                         False              55.0
# 33                                         False               NaN
# 34                                         False              91.0
# 35                                         False              78.0
# 36                                         False              95.0
# 37                                         False             145.0
# 38                                         False               NaN
# 39                                         False               NaN
# 40                                         False             266.0
# 41                                         False               NaN
# 42                                         False               NaN
# 43                                         False               NaN
# 44                                         False               NaN
# 45                                         False             173.0
# 46                                         False               NaN
# 47                                         False               NaN
# 48                                         False               NaN
# 49                                         False               NaN
# 50                                         False               NaN
# 51                                         False               NaN
# 52                                         False             210.0
# 53                                         False             343.0
# 54                                         False             165.0
# 55                                         False               NaN
# 56                                         False              15.0
# 57                                         False             245.0
# 58                                         False               NaN
# 59                                         False               NaN
# 60                                         False               NaN
# 61                                         False               NaN
# 62                                         False               NaN
# 63                                         False               NaN
# 64                                         False               NaN
# 65                                         False               NaN
# 66                                         False               NaN
# 67                                         False               NaN
# 68                                         False             238.0
# 69                                         False             284.0
# 71                                         False             255.0
# 72                                         False             301.0
# 73                                         False             341.0
# 74                                         False             340.0
# 75                                         False               NaN
# 76                                         False               NaN
# 77                                         False               NaN
# 78                                         False               NaN
# 79                                         False              29.0
# 80                                         False               NaN
# 81                                         False              82.0
# 82                                         False             194.0
# 83                                         False             197.0
# 84                                         False             185.0
# 85                                         False               NaN
# 86                                         False              99.0
# 87                                         False               NaN
# 88                                         False               NaN
# 89                                         False              73.0
# 90                                         False              81.0
# 91                                         False               NaN
# 92                                         False              82.0
# 93                                         False               NaN
# 94                                         False               NaN
# 95                                         False               NaN
# 96                                         False               NaN
# 97                                         False               NaN
# 98                                         False               NaN
# 99                                         False             281.0
# 100                                        False             256.0
# 101                                        False               NaN
# 102                                        False               NaN
# 103                                        False               NaN
# 104                                        False               NaN
# 105                                        False             248.0
# 106                                        False               NaN
# 107                                        False             252.0
# 108                                        False               NaN
# 109                                        False               NaN
# 110                                        False               NaN
# 111                                        False             346.0
# 112                                        False               NaN
# 113                                        False               NaN
# 114                                        False             185.0
# 115                                        False             252.0
# 116                                        False             271.0
# 117                                        False               NaN
# 118                                        False             270.0
# 119                                        False               NaN
# 120                                        False               NaN
# 121                                        False               NaN
# 122                                        False               NaN
# 123                                        False               NaN
# 124                                        False               NaN
# 125                                        False               NaN
# 126                                        False             333.0
# 127                                        False               NaN
# 128                                        False             199.0
# 129                                        False             253.0
# 130                                        False               NaN
# 131                                        False               NaN
# 132                                        False               NaN
# 133                                        False               NaN
# 134                                        False               NaN
# 135                                        False               NaN
# 136                                        False               NaN
# 137                                        False              59.0
# 138                                        False               NaN
# 139                                        False               NaN
# 140                                        False               NaN
# 141                                        False               NaN
# 142                                        False               NaN
# 143                                        False               NaN
# 144                                        False               NaN
# 145                                        False               NaN
# 146                                        False               NaN
# 147                                        False               NaN
# 148                                        False               NaN

# %% [markdown]
# ## Plot on map

# %%
a = df2.iloc[:, 3:5].values
print(a)
print(len(a))
# Out:
# [[ 35.33830382 139.50076906]
#  [ 35.33830283 139.50076558]
#  [ 35.33829415 139.50077231]
#  [ 35.33826498 139.50073697]
#  [ 35.33825346 139.50072245]
#  [ 35.33825408 139.50071666]
#  [ 35.33824909 139.50070919]
#  [ 35.33825934 139.50070044]
#  [ 35.33826772 139.50068763]
#  [ 35.3382739  139.50069065]
#  [ 35.3382342  139.5006209 ]
#  [ 35.33828364 139.50069071]
#  [ 35.33828721 139.50069256]
#  [ 35.3382893  139.50070629]
#  [ 35.33829708 139.50075313]
#  [ 35.338301   139.50076329]
#  [ 35.33829898 139.50078262]
#  [ 35.33830426 139.50078106]
#  [ 35.33830742 139.50078375]
#  [ 35.3383095  139.50079755]
#  [ 35.33831769 139.50080663]
#  [ 35.3382389  139.5006288 ]
#  [ 35.3382736  139.5006193 ]
#  [ 35.33853997 139.50108858]
#  [ 35.3383665  139.50065896]
#  [ 35.33824491 139.50085557]
#  [ 35.33819186 139.50094361]
#  [ 35.33963864 139.49866784]
#  [ 35.34027917 139.49864256]
#  [ 35.34028769 139.49864509]
#  [ 35.34029617 139.49865026]
#  [ 35.34029454 139.49862883]
#  [ 35.34023312 139.49855135]
#  [ 35.34051308 139.49604915]
#  [ 35.3403375  139.49258535]
#  [ 35.34006126 139.49020078]
#  [ 35.3402119  139.48655334]
#  [ 35.34123467 139.48381579]
#  [ 35.34016632 139.48254896]
#  [ 35.33950406 139.4860282 ]
#  [ 35.33938469 139.48605316]
#  [ 35.33930677 139.4873696 ]
#  [ 35.33932948 139.4873765 ]
#  [ 35.33934437 139.48739978]
#  [ 35.33934035 139.48739833]
#  [ 35.3396331  139.48744994]
#  [ 35.33950308 139.48762115]
#  [ 35.33955357 139.4877657 ]
#  [ 35.3396004  139.48769518]
#  [ 35.33927633 139.48737901]
#  [ 35.33929014 139.48745115]
#  [ 35.33934272 139.48746387]
#  [ 35.33982407 139.48793027]
#  [ 35.33981067 139.49025267]
#  [ 35.33634417 139.49012999]
#  [ 35.33628181 139.49007694]
#  [ 35.3311081  139.48812623]
#  [ 35.32860256 139.48812396]
#  [ 35.32931872 139.48790258]
#  [ 35.3293155  139.48791592]
#  [ 35.32930204 139.48793563]
#  [ 35.32929445 139.48796048]
#  [ 35.32929413 139.48797865]
#  [ 35.3292686  139.48798706]
#  [ 35.329253   139.48797076]
#  [ 35.32922408 139.48801806]
#  [ 35.32919776 139.4880241 ]
#  [ 35.3291807  139.48804487]
#  [ 35.32929483 139.48826787]
#  [ 35.32915146 139.48807138]
#  [ 35.3292874  139.48853095]
#  [ 35.32956817 139.48856453]
#  [ 35.32946755 139.48819214]
#  [ 35.32899919 139.488321  ]
#  [ 35.32966277 139.48815049]
#  [ 35.3378034  139.4888163 ]
#  [ 35.329709   139.4878285 ]
#  [ 35.32952987 139.48831923]
#  [ 35.32925496 139.48784613]
#  [ 35.32955579 139.48737095]
#  [ 35.32947682 139.48759994]
#  [ 35.33024998 139.48791895]
#  [ 35.33340493 139.48900799]
#  [ 35.33864283 139.49048144]
#  [ 35.33988755 139.48987355]
#  [ 35.34019256 139.48720263]
#  [ 35.34014629 139.48684615]
#  [ 35.34009373 139.48663667]
#  [ 35.34017528 139.48611102]
#  [ 35.33919312 139.48523983]
#  [ 35.33920502 139.48473979]
#  [ 35.33893505 139.4837178 ]
#  [ 35.33919926 139.48101934]
#  [ 35.33921252 139.48098767]
#  [ 35.33922461 139.48098143]
#  [ 35.33925135 139.48099739]
#  [ 35.33914079 139.48099944]
#  [ 35.33917476 139.4810586 ]
#  [ 35.3391091  139.48098082]
#  [ 35.33907845 139.48409619]
#  [ 35.33941925 139.48720844]
#  [ 35.33941943 139.48718899]
#  [ 35.33946593 139.48718625]
#  [ 35.33950259 139.48717059]
#  [ 35.33940193 139.48767436]
#  [ 35.34024841 139.48823229]
#  [ 35.33974542 139.48922858]
#  [ 35.34015492 139.49045748]
#  [ 35.34020943 139.49043245]
#  [ 35.34041284 139.49186733]
#  [ 35.3403674  139.49267484]
#  [ 35.34019373 139.49236228]
#  [ 35.34022409 139.4923027 ]
#  [ 35.34023651 139.49232954]
#  [ 35.34049198 139.49281906]
#  [ 35.34038619 139.49369348]
#  [ 35.34046685 139.49460691]
#  [ 35.34052475 139.49583949]
#  [ 35.34026502 139.49850163]
#  [ 35.34025547 139.49850724]
#  [ 35.34022325 139.49850249]
#  [ 35.34023244 139.49852207]
#  [ 35.34024315 139.49847236]
#  [ 35.34037686 139.49847182]
#  [ 35.34039316 139.49847376]
#  [ 35.33881748 139.4991214 ]
#  [ 35.33826667 139.50081919]
#  [ 35.33839352 139.50080493]
#  [ 35.33834023 139.50079875]
#  [ 35.33827677 139.50085612]
#  [ 35.3382724  139.5006584 ]
#  [ 35.3382754  139.5006824 ]
#  [ 35.33832014 139.50071534]
#  [ 35.33831393 139.50071217]
#  [ 35.33831082 139.5007235 ]
#  [ 35.33831433 139.50073318]
#  [ 35.33831278 139.5007776 ]
#  [ 35.33827327 139.50069663]
#  [ 35.33827649 139.50069365]
#  [ 35.33828275 139.50070454]
#  [ 35.33828369 139.50072634]
#  [ 35.33828333 139.50071084]
#  [ 35.33828129 139.50068301]
#  [ 35.3382389  139.5006288 ]
#  [ 35.33827716 139.50063571]
#  [ 35.33827109 139.50062819]
#  [ 35.33826835 139.50062026]
#  [ 35.3382386  139.5006277 ]]
# 148

# %%
# 中心点を設定（藤沢駅）
lat = 35.338528
lng = 139.487632
# 描画
m = folium.Map(location=[lat, lng], zoom_start=14)

# %%
# 線の地図レイヤへの追加
line = folium.vector_layers.PolyLine(
            locations= a,        
            color='blue',                                  
            weight=2)
m.add_child(line)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_55820580be2443b5a6778f3e02986717%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_55820580be2443b5a6778f3e02986717%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_55820580be2443b5a6778f3e02986717%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_55820580be2443b5a6778f3e02986717%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.338528%2C%20139.487632%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ## Route matching

# %%
# nullを含む行を削除（要改善）
array = trace.get('data')[:70] + trace.get('data')[71:]
len(array)
# Out:
# 148

# %%
positions = [[datetime.datetime.fromtimestamp(data['timestamp'] / 1000), data['position']] for data in array]
rows = [[dt.isoformat(), p['lat'], p['lng'], p.get('speed', ''), p.get('heading', '')] for dt, p in positions]
rows = [['TIMESTAMP', 'LATITUDE', 'LONGITUDE', 'SPEED_MPS', 'HEADING']] + rows
trace_csv = '\n'.join(map(lambda x: ','.join(map(str, x)), rows))
print(trace_csv)
# Out:
# TIMESTAMP,LATITUDE,LONGITUDE,SPEED_MPS,HEADING
# 2021-01-19T19:59:06.054000,35.33830382,139.50076906,0,
# 2021-01-19T19:58:06.049000,35.33830283,139.50076558,0,
# 2021-01-19T19:57:05.947000,35.33829415,139.50077231,0,
# 2021-01-19T19:56:05.918000,35.33826498,139.50073697,0,
# 2021-01-19T19:55:05.895000,35.33825346,139.50072245,0,
# 2021-01-19T19:54:05.875000,35.33825408,139.50071666,0,
# 2021-01-19T19:53:05.771000,35.33824909,139.50070919,0,
# 2021-01-19T19:52:05.749000,35.33825934,139.50070044,0,
# 2021-01-19T19:51:05.660000,35.33826772,139.50068763,0,
# 2021-01-19T19:50:05.559000,35.3382739,139.50069065,0,
# 2021-01-19T19:49:05.488000,35.3382342,139.5006209,,
# 2021-01-19T19:48:05.443000,35.33828364,139.50069071,0,
# 2021-01-19T19:47:05.343000,35.33828721,139.50069256,0,
# 2021-01-19T19:46:05.321000,35.3382893,139.50070629,0,
# 2021-01-19T19:45:05.299000,35.33829708,139.50075313,0,
# 2021-01-19T19:44:05.198000,35.338301,139.50076329,0,
# 2021-01-19T19:43:05.095000,35.33829898,139.50078262,0,
# 2021-01-19T19:42:05.087000,35.33830426,139.50078106,0,
# 2021-01-19T19:41:05.061000,35.33830742,139.50078375,0,
# 2021-01-19T19:40:05.016000,35.3383095,139.50079755,0,
# 2021-01-19T19:39:05.004000,35.33831769,139.50080663,0,
# 2021-01-19T19:38:04.954000,35.3382389,139.5006288,,
# 2021-01-19T19:37:04.944000,35.3382736,139.5006193,,
# 2021-01-19T19:36:04.905000,35.33853997,139.50108858,0,148
# 2021-01-19T19:35:04.865000,35.3383665,139.50065896,1,309
# 2021-01-19T19:34:04.765000,35.33824491,139.50085557,0,
# 2021-01-19T19:33:04.665000,35.33819186,139.50094361,0,
# 2021-01-19T19:32:04.564000,35.33963864,139.49866784,8,152
# 2021-01-19T19:31:04.463000,35.34027917,139.49864256,0,
# 2021-01-19T17:56:58.809000,35.34023244,139.49852207,0,
# 2021-01-19T17:55:58.791000,35.34024315,139.49847236,0,
# 2021-01-19T17:54:58.713000,35.34037686,139.49847182,0,
# 2021-01-19T17:53:58.658000,35.34039316,139.49847376,0,
# 2021-01-19T17:52:58.634000,35.33881748,139.4991214,6,333
# 2021-01-19T17:51:58.576000,35.33826667,139.50081919,0,
# 2021-01-19T17:50:58.565000,35.33839352,139.50080493,2,199
# 2021-01-19T17:49:58.542000,35.33834023,139.50079875,1,253
# 2021-01-19T17:48:58.522000,35.33827677,139.50085612,0,
# 2021-01-19T17:47:58.469000,35.3382724,139.5006584,,
# 2021-01-19T17:46:58.445000,35.3382754,139.5006824,,
# 2021-01-19T17:45:58.343000,35.33832014,139.50071534,0,
# 2021-01-19T17:44:58.339000,35.33831393,139.50071217,0,
# 2021-01-19T17:43:58.320000,35.33831082,139.5007235,0,
# 2021-01-19T17:42:58.318000,35.33831433,139.50073318,0,
# 2021-01-19T17:41:58.219000,35.33831278,139.5007776,1,59
# 2021-01-19T17:40:58.195000,35.33827327,139.50069663,0,
# 2021-01-19T17:39:58.140000,35.33827649,139.50069365,0,
# 2021-01-19T17:38:58.052000,35.33828275,139.50070454,0,
# 2021-01-19T17:37:58.048000,35.33828369,139.50072634,0,
# 2021-01-19T17:36:58.047000,35.33828333,139.50071084,0,
# 2021-01-19T17:35:57.997000,35.33828129,139.50068301,0,
# 2021-01-19T17:34:57.895000,35.3382389,139.5006288,,
# 2021-01-19T17:33:57.810000,35.33827716,139.50063571,0,
# 2021-01-19T17:32:57.730000,35.33827109,139.50062819,0,
# 2021-01-19T17:31:57.629000,35.33826835,139.50062026,0,
# 2021-01-19T17:30:57.524000,35.3382386,139.5006277,,

# %%
mode = 'fastest;car;traffic:enabled'
response = match_route(APIKEY, mode, trace_csv, region='JPN')
response
# Out:
# https://fleet.ls.hereapi.com/2/calculateroute.json?routeMatch=1&apiKey=_5dAuxQ82T1V-yVw9jhVVjNn3rkbctA5_E4PVnzmy1w&mode=fastest%3Bcar%3Btraffic%3Aenabled&region=JPN
# {'response': {'route': [{'mode': {'type': 'matched',
#      'transportModes': ['car'],
#      'trafficMode': 'enabled'},
#     'boatFerry': False,
#     'railFerry': False,
#     'waypoint': [{'linkId': '+17641467904',
#       'mappedPosition': {'latitude': 35.33829, 'longitude': 139.50073},
#       'originalPosition': {'latitude': 35.33830382, 'longitude': 139.50076906},
#       'spot': 0.86143,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -25.0,
#       'matchDistance': 4.75,
#       'minError': 4.0,
#       'routeLinkSeqNrMatched': 0,
#       'speedMps': 0.0,
#       'timestamp': 1611086346054,
#       'breakDetected': True,
#       'breakDuration': -600566},
#      {'linkId': '+17641467904',
#       'mappedPosition': {'latitude': 35.33829, 'longitude': 139.50073},
#       'originalPosition': {'latitude': 35.33830283, 'longitude': 139.50076558},
#       'spot': 0.86143,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -25.0,
#       'matchDistance': 4.35,
#       'minError': 1000000.0,
#       'routeLinkSeqNrMatched': 0,
#       'speedMps': 0.0,
#       'timestamp': 1611086286049},
#      {'linkId': '+17641467904',
#       'mappedPosition': {'latitude': 35.33828, 'longitude': 139.50073},
#       'originalPosition': {'latitude': 35.33829415, 'longitude': 139.50077231},
#       'spot': 0.83717,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -25.0,
#       'matchDistance': 4.97,
#       'minError': 5.0,
#       'routeLinkSeqNrMatched': 0,
#       'speedMps': 0.0,
#       'timestamp': 1611086225947},
#      {'linkId': '+17641467904',
#       'mappedPosition': {'latitude': 35.33827, 'longitude': 139.50074},
#       'originalPosition': {'latitude': 35.33826498, 'longitude': 139.50073697},
#       'spot': 0.80196,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -25.0,
#       'matchDistance': 0.65,
#       'minError': 1.0,
#       'routeLinkSeqNrMatched': 0,
#       'speedMps': 0.0,
#       'timestamp': 1611086165918},
#      {'linkId': '+17641467904',
#       'mappedPosition': {'latitude': 35.33826, 'longitude': 139.50074},
#       'originalPosition': {'latitude': 35.33825346, 'longitude': 139.50072245},
#       'spot': 0.78852,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -25.0,
#       'matchDistance':

#      {'linkId': '-17650785280',
#       'mappedPosition': {'latitude': 35.33834, 'longitude': 139.5007},
#       'originalPosition': {'latitude': 35.33853997, 'longitude': 139.50108858},
#       'spot': 0.0,
#       'confidenceValue': 0.1,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 148.0,
#       'headingMatched': -118.0,
#       'matchDistance': 48.64,
#       'minError': 49.0,
#       'routeLinkSeqNrMatched': 1,
#       'speedMps': 0.0,
#       'timestamp': 1611084964905,
#       'breakDetected': True,
#       'breakDuration': -240341},
#      {'linkId': '-17650785280',
#       'mappedPosition': {'latitude': 35.33833, 'longitude': 139.50068},
#       'originalPosition': {'latitude': 35.3383665, 'longitude': 139.50065896},
#       'spot': 0.96519,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 309.0,
#       'headingMatched': -118.0,
#       'matchDistance': 4.61,
#       'minError': 2.0,
#       'routeLinkSeqNrMatched': 1,
#       'speedMps': 1.0,
#       'timestamp': 1611084904865},
#      {'linkId': '-17650785280',
#       'mappedPosition': {'latitude': 35.33834, 'longitude': 139.5007},
#       'originalPosition': {'latitude': 35.33824491, 'longitude': 139.50085557},
#       'spot': 0.0,
#       'confidenceValue': 0.25,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -118.0,
#       'matchDistance': 20.29,
#       'minError': 20.0,
#       'routeLinkSeqNrMatched': 1,
#       'speedMps': 0.0,
#       'timestamp': 1611084844765},
#      {'linkId': '-17650785280',
#       'mappedPosition': {'latitude': 35.33834, 'longitude': 139.5007},
#       'originalPosition': {'latitude': 35.33819186, 'longitude': 139.50094361},
#       'spot': 0.0,
#       'confidenceValue': 0.16,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -118.0,
#       'matchDistance': 31.73,
#       'minError': 32.0,
#       'routeLinkSeqNrMatched': 1,
#       'speedMps': 0.0,
#       'timestamp': 1611084784665},
#      {'linkId': '+17642044416',
#       'mappedPosition': {'latitude': 35.33964, 'longitude': 139.49867},
#       'originalPosition': {'latitude': 35.33963864, 'longitude': 139.49866784},
#       'spot': 0.46389,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 152.0,
#       'headingMatched': -27.0,
#       'matchDistance': 0.54,
#       'minError': 0.0,
#       'routeLinkSeqNrMatched': 5,
#       'speedMps': 8.0,
#       'timestamp': 1611084724564},
#      {'linkId': '+17666061312',
#       'mappedPosition': {'latitude': 35.34016, 'longitude': 139.49835},
#       'originalPosition': {'latitude': 35.34027917, 'longitude': 139.49864256},
#       'spot': 0.46118,
#       'confidenceValue': 0.14,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -27.0,
#       'matchDistance': 35.47,
#       'minError': 20.0,
#       'routeLinkSeqNrMatched': 6,
#       'speedMps': 0.0,
#       'timestamp': 1611084664463,
#       'breakDetected': True,
#       'breakDuration': -240210},
#      {'linkId': '+17666061312',
#       'mappedPosition': {'latitude': 35.34016, 'longitude': 139.49835},
#       'originalPosition': {'latitude': 35.34028769, 'longitude': 139.49864509},
#       'spot': 0.46118,
#       'confidenceValue': 0.14,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -27.0,
#       'matchDistance': 36.11,
#       'minError': 1000000.0,
#       'routeLinkSeqNrMatched': 6,
#       'speedMps': 0.0,
#       'timestamp': 1611084604385},
#      {'linkId': '+17666061312',
#       'mappedPosition': {'latitude': 35.34017, 'longitude': 139.49834},
#       'originalPosition': {'latitude': 35.34029617, 'longitude': 139.49865026},
#       'spot': 0.48346,
#       'confidenceValue': 0.13,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -27.0,
#       'matchDistance': 37.28,
#       'minError': 37.0,
#       'routeLinkSeqNrMatched': 6,
#       'speedMps': 0.0,
#       'timestamp': 1611084544358},
#      {'linkId': '+17666061312',
#       'mappedPosition': {'latitude': 35.34017, 'longitude': 139.49834},
#       'originalPosition': {'latitude': 35.34029454, 'longitude': 139.49862883},
#       'spot': 0.49522,
#       'confidenceValue': 0.14,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -27.0,
#       'matchDistance': 35.01,
#       'minError': 35.0,
#       'routeLinkSeqNrMatched': 6,
#       'speedMps': 0.0,
#       'timestamp': 1611084484257},
#      {'linkId': '+17666061312',
#       'mappedPosition': {'latitude': 35.34016, 'longitude': 139.49835},
#       'originalPosition': {'latitude': 35.34023312, 'longitude': 139.49855135},
#       'spot': 0.46118,
#       'confidenceValue': 0.21,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 55.0,
#       'headingMatched': -27.0,
#       'matchDistance': 24.15,
#       'minError': 20.0,
#       'routeLinkSeqNrMatched': 6,
#       'speedMps': 3.0,
#       'timestamp': 1611084424253},
#      {'linkId': '+17658278912',
#       'mappedPosition': {'latitude': 35.34048, 'longitude': 139.49605},
#       'originalPosition': {'latitude': 35.34051308, 'longitude': 139.49604915},
#       'spot': 0.45348,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -87.0,
#       'matchDistance': 3.18,
#       'minError': 3.0,
#       'routeLinkSeqNrMatched': 12,
#       'speedMps': 0.0,
#       'timestamp': 1611084364243,
#       'breakDetected': True,
#       'breakDuration': -60083},
#      {'linkId': '+17651906560',
#       'mappedPosition': {'latitude': 35.34038, 'longitude': 139.49259},
#       'originalPosition': {'latitude': 35.3403375, 'longitude': 139.49258535},
#       'spot': 0.11177,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 91.0,
#       'headingMatched': -89.0,
#       'matchDistance': 4.86,
#       'minError': 5.0,
#       'routeLinkSeqNrMatched': 19,
#       'speedMps': 6.0,
#       'timestamp': 1611084304160},
#      {'linkId': '-17656833024',
#       'mappedPosition': {'latitude': 35.34012, 'longitude': 139.49018},
#       'originalPosition': {'latitude': 35.34006126, 'longitude': 139.49020078},
#       'spot': 0.10907,
#       'confidenceValue': 0.68,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 78.0,
#       'headingMatched': -104.0,
#       'matchDistance': 7.33,
#       'minError': 1.0,
#       'routeLinkSeqNrMatched': 22,
#       'speedMps': 7.0,
#       'timestamp': 1611084244156},
#      {'linkId': '-17652381696',
#       'mappedPosition': {'latitude': 35.34017, 'longitude': 139.48656},
#       'originalPosition': {'latitude': 35.3402119, 'longitude': 139.48655334},
#       'spot': 0.56586,
#       'confidenceValue': 0.97,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 95.0,
#       'headingMatched': -95.0,
#       'matchDistance': 5.14,
#       'minError': 5.0,
#       'routeLinkSeqNrMatched': 28,
#       'speedMps': 6.0,
#       'timestamp': 1611084184121},
#      {'linkId': '+17661078528',
#       'mappedPosition': {'latitude': 35.34124, 'longitude': 139.48383},
#       'originalPosition': {'latitude': 35.34123467, 'longitude': 139.48381579},
#       'spot': 0.71222,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 145.0,
#       'headingMatched': -41.0,
#       'matchDistance': 1.79,
#       'minError': 2.0,
#       'routeLinkSeqNrMatched': 36,
#       'speedMps': 6.0,
#       'timestamp': 1611084124029},
#      {'linkId': '-17654185984',
#       'mappedPosition': {'latitude': 35.34016, 'longitude': 139.48255},
#       'originalPosition': {'latitude': 35.34016632, 'longitude': 139.48254896},
#       'spot': 0.60895,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 120.0,
#       'matchDistance': 0.5,
#       'minError': 0.0,
#       'routeLinkSeqNrMatched': 43,
#       'speedMps': 0.0,
#       'timestamp': 1611084063923,
#       'breakDetected': True,
#       'breakDuration': -120203},
#      {'linkId': '+17664318464',
#       'mappedPosition': {'latitude': 35.33927, 'longitude': 139.48605},
#       'originalPosition': {'latitude': 35.33950406, 'longitude': 139.4860282},
#       'spot': 0.31548,
#       'confidenceValue': 0.19,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 86.0,
#       'matchDistance': 25.91,
#       'minError': 9.0,
#       'routeLinkSeqNrMatched': 51,
#       'speedMps': 0.0,
#       'timestamp': 1611084003821},
#      {'linkId': '+17664318464',
#       'mappedPosition': {'latitude': 35.33927, 'longitude': 139.48606},
#       'originalPosition': {'latitude': 35.33938469, 'longitude': 139.48605316},
#       'spot': 0.32741,
#       'confidenceValue': 0.4,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 266.0,
#       'headingMatched': 86.0,
#       'matchDistance': 12.49,
#       'minError': 2.0,
#       'routeLinkSeqNrMatched': 51,
#       'speedMps': 5.0,
#       'timestamp': 1611083943720},
#      {'linkId': '-17667873792',
#       'mappedPosition': {'latitude': 35.33938, 'longitude': 139.48737},
#       'originalPosition': {'latitude': 35.33930677, 'longitude': 139.4873696},
#       'spot': 0.61425,
#       'confidenceValue': 0.61,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 87.0,
#       'matchDistance': 8.14,
#       'minError': 7.0,
#       'routeLinkSeqNrMatched': 53,
#       'speedMps': 0.0,
#       'timestamp': 1611083883708,
#       'breakDetected': True,
#       'breakDuration': -660654},
#      {'linkId': '-17667873792',
#       'mappedPosition': {'latitude': 35.33938, 'longitude': 139.48737},
#       'originalPosition': {'latitude': 35.33932948, 'longitude': 139.4873765},
#       'spot': 0.39129,
#       'confidenceValue': 0.88,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 72.0,
#       'matchDistance': 5.67,
#       'minError': 6.0,
#       'routeLinkSeqNrMatched': 53,
#       'speedMps': 0.0,
#       'timestamp': 1611083823678},
#      {'linkId': '-17667873792',
#       'mappedPosition': {'latitude': 35.33938, 'longitude': 139.48738},
#       'originalPosition': {'latitude': 35.33934437, 'longitude': 139.48739978},
#       'spot': 0.40731,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 72.0,
#       'matchDistance': 4.54,
#       'minError': 5.0,
#       'routeLinkSeqNrMatched': 53,
#       'speedMps': 0.0,
#       'timestamp': 1611083763578},
#      {'linkId': '-17667873792',
#       'mappedPosition': {'latitude': 35.33938, 'longitude': 139.48738},
#       'originalPosition': {'latitude': 35.33934035, 'longitude': 139.48739833},
#       'spot': 0.40731,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 72.0,
#       'matchDistance': 4.86,
#       'minError': 1000000.0,
#       'routeLinkSeqNrMatched': 53,
#       'speedMps': 0.0,
#       'timestamp': 1611083703470},
#      {'linkId': '-17667873792',
#       'mappedPosition': {'latitude': 35.33941, 'longitude': 139.48748},
#       'originalPosition': {'latitude': 35.3396331, 'longitude': 139.48744994},
#       'spot': 0.52034,
#       'confidenceValue': 0.2,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 173.0,
#       'headingMatched': 96.0,
#       'matchDistance': 25.06,
#       'minError': 25.0,
#       'routeLinkSeqNrMatched': 53,
#       'speedMps': 0.0,
#       'timestamp': 1611083643435},
#      {'linkId': '-17667873792',
#       'mappedPosition': {'latitude': 35.3394, 'longitude': 139.48759},
#       'originalPosition': {'latitude': 35.33950308, 'longitude': 139.48762115},
#       'spot': 0.64348,
#       'confidenceValue': 0.42,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 122.0,
#       'matchDistance': 11.99,
#       'minError': 12.0,
#       'routeLinkSeqNrMatched': 53,
#       'speedMps': 0.0,
#       'timestamp': 1611083583343},
#      {'linkId': '+17642933248',
#       'mappedPosition': {'latitude': 35.33955, 'longitude': 139.48788},
#       'originalPosition': {'latitude': 35.33955357, 'longitude': 139.4877657},
#       'spot': 0.32403,
#       'confidenceValue': 0.39,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 3.0,
#       'matchDistance': 12.73,
#       'minError': 13.0,
#       'routeLinkSeqNrMatched': 54,
#       'speedMps': 0.0,
#       'timestamp': 1611083523327},
#      {'linkId': '+17642933248',
#       'mappedPosition': {'latitude': 35.33959, 'longitude': 139.48788},
#       'originalPosition': {'latitude': 35.3396004, 'longitude': 139.48769518},
#       'spot': 0.37288,
#       'confidenceValue': 0.24,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 3.0,
#       'matchDistance': 20.6,
#       'minError': 21.0,
#       'routeLinkSeqNrMatched': 54,
#       'speedMps': 0.0,
#       'timestamp': 1611083463225},
#      {'linkId': '+17642933248',
#       'mappedPosition': {'latitude': 35.33926, 'longitude': 139.48786},
#       'originalPosition': {'latitude': 35.33927633, 'longitude': 139.48737901},
#       'spot': 0.0,
#       'confidenceValue': 0.09,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 3.0,
#       'matchDistance': 53.57,
#       'minError': 54.0,
#       'routeLinkSeqNrMatched': 54,
#       'speedMps': 0.0,
#       'timestamp': 1611083403219},
#      {'linkId': '+17642933248',
#       'mappedPosition': {'latitude': 35.33927, 'longitude': 139.48786},
#       'originalPosition': {'latitude': 35.33929014, 'longitude': 139.48745115},
#       'spot': 0.01289,
#       'confidenceValue': 0.11,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 3.0,
#       'matchDistance': 45.56,
#       'minError': 46.0,
#       'routeLinkSeqNrMatched': 54,
#       'speedMps': 0.0,
#       'timestamp': 1611083343163},
#      {'linkId': '+17642933248',
#       'mappedPosition': {'latitude': 35.33932, 'longitude': 139.48786},
#       'originalPosition': {'latitude': 35.33934272, 'longitude': 139.48746387},
#       'spot': 0.07243,
#       'confidenceValue': 0.11,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 3.0,
#       'matchDistance': 44.16,
#       'minError': 44.0,
#       'routeLinkSeqNrMatched': 54,
#       'speedMps': 0.0,
#       'timestamp': 1611083283155},
#      {'linkId': '+17642933248',
#       'mappedPosition': {'latitude': 35.33983, 'longitude': 139.4879},
#       'originalPosition': {'latitude': 35.33982407, 'longitude': 139.48793027},
#       'spot': 0.63543,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 210.0,
#       'headingMatched': 3.0,
#       'matchDistance': 3.51,
#       'minError': 3.0,
#       'routeLinkSeqNrMatched': 54,
#       'speedMps': 3.0,
#       'timestamp': 1611083223054},
#      {'linkId': '-17644083201',
#       'mappedPosition': {'latitude': 35.33982, 'longitude': 139.4903},
#       'originalPosition': {'latitude': 35.33981067, 'longitude': 139.49025267},
#       'spot': 0.55349,
#       'confidenceValue': 0.98,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 343.0,
#       'headingMatched': 162.0,
#       'matchDistance': 5.11,
#       'minError': 4.0,
#       'routeLinkSeqNrMatched': 58,
#       'speedMps': 12.0,
#       'timestamp': 1611083163032},
#      {'linkId': '-17640504320',
#       'mappedPosition': {'latitude': 35.33637, 'longitude': 139.49001},
#       'originalPosition': {'latitude': 35.33634417, 'longitude': 139.49012999},
#       'spot': 0.84745,
#       'confidenceValue': 0.35,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 165.0,
#       'headingMatched': -164.0,
#       'matchDistance': 14.16,
#       'minError': 12.0,
#       'routeLinkSeqNrMatched': 69,
#       'speedMps': 1.0,
#       'timestamp': 1611083103013,
#       'breakDetected': True,
#       'breakDuration': -120123},
#      {'linkId': '-17640504320',
#       'mappedPosition': {'latitude': 35.3363, 'longitude': 139.48998},
#       'originalPosition': {'latitude': 35.33628181, 'longitude': 139.49007694},
#       'spot': 0.2087,
#       'confidenceValue': 0.46,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -164.0,
#       'matchDistance': 10.98,
#       'minError': 11.0,
#       'routeLinkSeqNrMatched': 69,
#       'speedMps': 0.0,
#       'timestamp': 1611083042911},
#      {'linkId': '-16576349184',
#       'mappedPosition': {'latitude': 35.3311, 'longitude': 139.48815},
#       'originalPosition': {'latitude': 35.3311081, 'longitude': 139.48812623},
#       'spot': 0.63101,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise':

#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 284.0,
#       'headingMatched': 9.0,
#       'matchDistance': 51.27,
#       'minError': 30.0,
#       'routeLinkSeqNrMatched': 77,
#       'speedMps': 1.0,
#       'timestamp': 1611082202240},
#      {'linkId': '+16576532480',
#       'mappedPosition': {'latitude': 35.3294, 'longitude': 139.48767},
#       'originalPosition': {'latitude': 35.3292874, 'longitude': 139.48853095},
#       'spot': 0.3252,
#       'confidenceValue': 0.05,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 255.0,
#       'headingMatched': 9.0,
#       'matchDistance': 97.16,
#       'minError': 9.0,
#       'routeLinkSeqNrMatched': 77,
#       'speedMps': 1.0,
#       'timestamp': 1611082082193},
#      {'linkId': '+16576532480',
#       'mappedPosition': {'latitude': 35.32968, 'longitude': 139.48772},
#       'originalPosition': {'latitude': 35.32956817, 'longitude': 139.48856453},
#       'spot': 0.59272,
#       'confidenceValue': 0.05,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 301.0,
#       'headingMatched': 9.0,
#       'matchDistance': 94.93,
#       'minError': 7.0,
#       'routeLinkSeqNrMatched': 77,
#       'speedMps': 1.0,
#       'timestamp': 1611082022092},
#      {'linkId': '+16576532480',
#       'mappedPosition': {'latitude': 35.32968, 'longitude': 139.48772},
#       'originalPosition': {'latitude': 35.32946755, 'longitude': 139.48819214},
#       'spot': 0.59272,
#       'confidenceValue': 0.09,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 341.0,
#       'headingMatched': 9.0,
#       'matchDistance': 57.61,
#       'minError': 24.0,
#       'routeLinkSeqNrMatched': 77,
#       'speedMps': 2.0,
#       'timestamp': 1611081962069},
#      {'linkId': '+16576532480',
#       'mappedPosition': {'latitude': 35.32968, 'longitude': 139.48772},
#       'originalPosition': {'latitude': 35.32899919, 'longitude': 139.488321},
#       'spot': 0.59272,
#       'confidenceValue': 0.05,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 340.0,
#       'headingMatched': 9.0,
#       'matchDistance': 100.89,
#       'minError': 6.0,
#       'routeLinkSeqNrMatched': 77,
#       'speedMps': 1.0,
#       'timestamp': 1611081902004,
#       'breakDetected': True,
#       'breakDuration': -120049},
#      {'linkId': '+16576532480',
#       'mappedPosition': {'latitude': 35.32972, 'longitude': 139.48773},
#       'originalPosition': {'latitude': 35.32966277, 'longitude': 139.48815049},
#       'spot': 0.63178,
#       'confidenceValue': 0.11,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 9.0,
#       'matchDistance': 47.59,
#       'minError': 31.0,
#       'routeLinkSeqNrMatched': 77,
#       'speedMps': 0.0,
#       'timestamp': 1611081841964},
#      {'linkId': '-17665159168',
#       'mappedPosition': {'latitude': 35.33723, 'longitude': 139.4898},
#       'originalPosition': {'latitude': 35.3378034, 'longitude': 139.4888163},
#       'spot': 1.0,
#       'confidenceValue': 0.04,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -148.0,
#       'matchDistance': 126.73,
#       'minError': 10.0,
#       'routeLinkSeqNrMatched': 90,
#       'speedMps': 0.0,
#       'timestamp': 1611081781955},
#      {'linkId': '-16576532480',
#       'mappedPosition': {'latitude': 35.32972, 'longitude': 139.48773},
#       'originalPosition': {'latitude': 35.329709, 'longitude': 139.4878285},
#       'spot': 0.63649,
#       'confidenceValue': 0.44,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -171.0,
#       'matchDistance': 11.36,
#       'minError': 9.0,
#       'routeLinkSeqNrMatched': 101,
#       'speedMps': 0.0,
#       'timestamp': 1611081721871},
#      {'linkId': '-16576532480',
#       'mappedPosition': {'latitude': 35.32961, 'longitude': 139.48771},
#       'originalPosition': {'latitude': 35.32952987, 'longitude': 139.48831923},
#       'spot': 0.47266,
#       'confidenceValue': 0.07,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -171.0,
#       'matchDistance': 68.39,
#       'minError': 68.0,
#       'routeLinkSeqNrMatched': 101,
#       'speedMps': 0.0,
#       'timestamp': 1611081661774,
#       'breakDetected': True,
#       'breakDuration': -240258},
#      {'linkId': '+16576532480',
#       'mappedPosition': {'latitude': 35.32972, 'longitude': 139.48773},
#       'originalPosition': {'latitude': 35.32925496, 'longitude': 139.48784613},
#       'spot': 0.63649,
#       'confidenceValue': 0.09,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 29.0,
#       'headingMatched': 9.0,
#       'matchDistance': 53.63,
#       'minError': 19.0,
#       'routeLinkSeqNrMatched': 102,
#       'speedMps': 1.0,
#       'timestamp': 1611081601670},
#      {'linkId': '+16576532480',
#       'mappedPosition': {'latitude': 35.32952, 'longitude': 139.48769},
#       'originalPosition': {'latitude': 35.32955579, 'longitude': 139.48737095},
#       'spot': 0.43776,
#       'confidenceValue': 0.14,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 9.0,
#       'matchDistance': 35.73,
#       'minError': 36.0,
#       'routeLinkSeqNrMatched': 102,
#       'speedMps': 0.0,
#       'timestamp': 1611081541578},
#      {'linkId': '+16576532480',
#       'mappedPosition': {'latitude': 35.32972, 'longitude': 139.48773},
#       'originalPosition': {'latitude': 35.32947682, 'longitude': 139.48759994},
#       'spot': 0.63649,
#       'confidenceValue': 0.16,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 82.0,
#       'headingMatched': 9.0,
#       'matchDistance': 30.75,
#       'minError': 7.0,
#       'routeLinkSeqNrMatched': 102,
#       'speedMps': 1.0,
#       'timestamp': 1611081481569},
#      {'linkId': '+16576349184',
#       'mappedPosition': {'latitude': 35.33026, 'longitude': 139.48786},
#       'originalPosition': {'latitude': 35.33024998, 'longitude': 139.48791895},
#       'spot': 0.10332,
#       'confidenceValue': 0.7,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 194.0,
#       'headingMatched': 16.0,
#       'matchDistance': 7.1,
#       'minError': 6.0,
#       'routeLinkSeqNrMatched': 103,
#       'speedMps': 10.0,
#       'timestamp': 1611081421516},
#      {'linkId': '+17664087040',
#       'mappedPosition': {'latitude': 35.33342, 'longitude': 139.48896},
#       'originalPosition': {'latitude': 35.33340493, 'longitude': 139.48900799},
#       'spot': 0.25624,
#       'confidenceValue': 0.85,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 197.0,
#       'headingMatched': 15.0,
#       'matchDistance': 5.89,
#       'minError': 5.0,
#       'routeLinkSeqNrMatched': 106,
#       'speedMps': 9.0,
#       'timestamp': 1611081361409},
#      {'linkId': '+17640734724',
#       'mappedPosition': {'latitude': 35.33864, 'longitude': 139.49042},
#       'originalPosition': {'latitude': 35.33864283, 'longitude': 139.49048144},
#       'spot': 0.07871,
#       'confidenceValue': 0.74,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 185.0,
#       'headingMatched': 2.0,
#       'matchDistance': 6.75,
#       'minError': 6.0,
#       'routeLinkSeqNrMatched': 118,
#       'speedMps': 10.0,
#       'timestamp': 1611081301301},
#      {'linkId': '-17647150080',
#       'mappedPosition': {'latitude': 35.34007, 'longitude': 139.48983},
#       'originalPosition': {'latitude': 35.33988755, 'longitude': 139.48987355},
#       'spot': 0.32884,
#       'confidenceValue': 0.25,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -101.0,
#       'matchDistance': 20.35,
#       'minError': 13.0,
#       'routeLinkSeqNrMatched': 121,
#       'speedMps': 0.0,
#       'timestamp': 1611081241230,
#       'breakDetected': True,
#       'breakDuration': -60013},
#      {'linkId': '-17652381696',
#       'mappedPosition': {'latitude': 35.34019, 'longitude': 139.48698},
#       'originalPosition': {'latitude': 35.34019256, 'longitude': 139.48720263},
#       'spot': 1.0,
#       'confidenceValue': 0.2,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 99.0,
#       'headingMatched': -90.0,
#       'matchDistance': 24.78,
#       'minError': 0.0,
#       'routeLinkSeqNrMatched': 126,
#       'speedMps': 5.0,
#       'timestamp': 1611081181217},
#      {'linkId': '-17652381696',
#       'mappedPosition': {'latitude': 35.34018, 'longitude': 139.48684},
#       'originalPosition': {'latitude': 35.34014629, 'longitude': 139.48684615},
#       'spot': 0.14148,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -94.0,
#       'matchDistance': 3.81,
#       'minError': 4.0,
#       'routeLinkSeqNrMatched': 126,
#       'speedMps': 0.0,
#       'timestamp': 1611081121115,
#       'breakDetected': True,
#       'breakDuration': -120070},
#      {'linkId': '-17652381696',
#       'mappedPosition': {'latitude': 35.34017, 'longitude': 139.48663},
#       'originalPosition': {'latitude': 35.34009373, 'longitude': 139.48663667},
#       'spot': 0.36115,
#       'confidenceValue': 0.59,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -94.0,
#       'matchDistance': 8.52,
#       'minError': 9.0,
#       'routeLinkSeqNrMatched': 126,
#       'speedMps': 0.0,
#       'timestamp': 1611081061108},
#      {'linkId': '-17641485312',
#       'mappedPosition': {'latitude': 35.34015, 'longitude': 139.48601},
#       'originalPosition': {'latitude': 35.34017528, 'longitude': 139.48611102},
#       'spot': 1.0,
#       'confidenceValue': 0.43,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 73.0,
#       'headingMatched': -143.0,
#       'matchDistance': 11.59,
#       'minError': 4.0,
#       'routeLinkSeqNrMatched': 127,
#       'speedMps': 5.0,
#       'timestamp': 1611081001045},
#      {'linkId': '-17647681536',
#       'mappedPosition': {'latitude': 35.33914, 'longitude': 139.48522},
#       'originalPosition': {'latitude': 35.33919312, 'longitude': 139.48523983},
#       'spot': 1.0,
#       'confidenceValue': 0.79,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 81.0,
#       'headingMatched': -97.0,
#       'matchDistance': 6.31,
#       'minError': 5.0,
#       'routeLinkSeqNrMatched': 129,
#       'speedMps': 6.0,
#       'timestamp': 1611080941031},
#      {'linkId': '-17647681536',
#       'mappedPosition': {'latitude': 35.33909, 'longitude': 139.48476},
#       'originalPosition': {'latitude': 35.33920502, 'longitude': 139.48473979},
#       'spot': 0.34483,
#       'confidenceValue': 0.38,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': -97.0,
#       'matchDistance': 13.0,
#       'minError': 13.0,
#       'routeLinkSeqNrMatched': 129,
#       'speedMps': 0.0,
#       'timestamp': 1611080880929,
#       'breakDetected': True,
#       'breakDuration': -60066},
#      {'linkId': '-17667632128',
#       'mappedPosition': {'latitude': 35.33892, 'longitude': 139.48372},
#       'originalPosition': {'latitude': 35.33893505, 'longitude': 139.4837178},
#       'spot': 0.824,
#       'confidenceValue': 1.0,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 82.0,
#       'headingMatched': -97.0,
#       'matchDistance': 1.91,
#       'minError': 2.0,
#       'routeLinkSeqNrMatched': 130,
#       'speedMps': 9.0,
#       'timestamp': 1611080820863},
#      {'linkId': '+17376149504',
#       'mappedPosition': {'latitude': 35.33904, 'longitude': 139.48129},
#       'originalPosition': {'latitude': 35.33919926, 'longitude': 139.48101934},
#       'spot': 0.46154,
#       'confidenceValue': 0.14,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 36.0,
#       'matchDistance': 35.31,
#       'minError': 23.0,
#       'routeLinkSeqNrMatched': 133,
#       'speedMps': 0.0,
#       'timestamp': 1611080760763,
#       'breakDetected': True,
#       'breakDuration': -360222},
#      {'linkId': '+17376149504',
#       'mappedPosition': {'latitude': 35.33903, 'longitude': 139.48129},
#       'originalPosition': {'latitude': 35.33921252, 'longitude': 139.48098767},
#       'spot': 0.45536,
#       'confidenceValue': 0.13,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 36.0,
#       'matchDistance': 39.31,
#       'minError': 39.0,
#       'routeLinkSeqNrMatched': 133,
#       'speedMps': 0.0,
#       'timestamp': 1611080700708},
#      {'linkId': '+17376149504',
#       'mappedPosition': {'latitude': 35.33904, 'longitude': 139.48129},
#       'originalPosition': {'latitude': 35.33922461, 'longitude': 139.48098143},
#       'spot': 0.46485,
#       'confidenceValue': 0.12,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 36.0,
#       'matchDistance': 40.02,
#       'minError': 40.0,
#       'routeLinkSeqNrMatched': 133,
#       'speedMps': 0.0,
#       'timestamp': 1611080640690},
#      {'linkId': '+17376149504',
#       'mappedPosition': {'latitude': 35.33906, 'longitude': 139.48132},
#       'originalPosition': {'latitude': 35.33925135, 'longitude': 139.48099739},
#       'spot': 0.50574,
#       'confidenceValue': 0.12,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 36.0,
#       'matchDistance': 41.75,
#       'minError': 42.0,
#       'routeLinkSeqNrMatched': 133,
#       'speedMps': 0.0,
#       'timestamp': 1611080580678},
#      {'linkId': '+17376149504',
#       'mappedPosition': {'latitude': 35.33899, 'longitude': 139.48125},
#       'originalPosition': {'latitude': 35.33914079, 'longitude': 139.48099944},
#       'spot': 0.38216,
#       'confidenceValue': 0.15,
#       'elevation': 0.0,
#       'headingDegreeNorthClockwise': 10000.0,
#       'headingMatched': 36.0,
#       'matchDistance': 32.55,
#       'minError': 33.0,
# ...
#          35.33968,
#          139.48561,
#          35.33941,
#          139.48547,
#          35.33922,
#          139.48543],
#         'functionalClass': 4,
#         'confidence': 0.94},
#        {'linkId': '-17647735808',
#         'length': 20.97,
#         'remainDistance': 2549,
#         'remainTime': 93,
#         'shape': [35.33922, 139.48543, 35.33914, 139.48522],
#         'functionalClass': 4,
#         'confidence': 0.9},
#        {'linkId': '-17647681536',
#         'length': 122.97,
#         'remainDistance': 2528,
#         'remainTime': 93,
#         'shape': [35.33914,
#          139.48522,
#          35.33905,
#          139.48433,
#          35.33895,
#          139.48389],
#         'functionalClass': 4,
#         'confidence': 0.9},
#        {'linkId': '-17667632128',
#         'length': 90.02,
#         'remainDistance': 2405,
#         'remainTime': 90,
#         'shape': [35.33895,
#          139.48389,
#          35.33892,
#          139.48374,
#          35.33886,
#          139.48313,
#          35.33884,
#          139.48291],
#         'functionalClass': 4,
#         'confidence': 1.0},
#        {'linkId': '-17383424000',
#         'length': 79.68,
#         'remainDistance': 2315,
#         'remainTime': 89,
#         'shape': [35.33884, 139.48291, 35.3388, 139.48203],
#         'functionalClass': 4,
#         'confidence': 0.88},
#        {'linkId': '-17390246912',
#         'length': 84.4,
#         'remainDistance': 2235,
#         'remainTime': 89,
#         'shape': [35.3388, 139.48203, 35.33875, 139.4811],
#         'functionalClass': 4,
#         'confidence': 0.75},
#        {'linkId': '17376149504',
#         'length': 80.0,
#         'remainDistance': 2151,
#         'remainTime': 89,
#         'shape': [35.33875, 139.4811, 35.3389, 139.48117, 35.33935, 139.48157],
#         'functionalClass': 4,
#         'confidence': 0.75},
#        {'linkId': '17376149505',
#         'length': 104.13,
#         'remainDistance': 2071,
#         'remainTime': 84,
#         'shape': [35.33935,
#          139.48157,
#          35.33954,
#          139.48173,
#          35.33988,
#          139.48199,
#          35.34014,
#          139.48219],
#         'functionalClass': 4,
#         'confidence': 0.88},
#        {'linkId': '17376149506',
#         'length': 18.37,
#         'remainDistance': 1967,
#         'remainTime': 79,
#         'shape': [35.34014, 139.48219, 35.34028, 139.4823],
#         'functionalClass': 4,
#         'confidence': 1.0},
#        {'linkId': '-17654185984',
#         'length': 66.9,
#         'remainDistance': 1948,
#         'remainTime': 67,
#         'shape': [35.34028, 139.4823, 35.33998, 139.48293],
#         'functionalClass': 4,
#         'confidence': 1.0},
#        {'linkId': '-17647609856',
#         'length': 31.23,
#         'remainDistance': 1881,
#         'remainTime': 67,
#         'shape': [35.33998, 139.48293, 35.33984, 139.48323],
#         'functionalClass': 4,
#         'confidence': 0.83},
#        {'linkId': '-17642283008',
#         'length': 31.66,
#         'remainDistance': 1850,
#         'remainTime': 67,
#         'shape': [35.33984, 139.48323, 35.33971, 139.48354],
#         'functionalClass': 4,
#         'confidence': 0.65},
#        {'linkId': '-17643427840',
#         'length': 74.11,
#         'remainDistance': 1819,
#         'remainTime': 67,
#         'shape': [35.33971, 139.48354, 35.33947, 139.4843],
#         'functionalClass': 4,
#         'confidence': 0.65},
#        {'linkId': '-17649682432',
#         'length': 66.2,
#         'remainDistance': 1744,
#         'remainTime': 59,
#         'shape': [35.33947, 139.4843, 35.33925, 139.48498],
#         'functionalClass': 4,
#         'confidence': 0.69},
#        {'linkId': '-17641347072',
#         'length': 24.55,
#         'remainDistance': 1678,
#         'remainTime': 59,
#         'shape': [35.33925, 139.48498, 35.33914, 139.48522],
#         'functionalClass': 4,
#         'confidence': 0.75},
#        {'linkId': '17647735808',
#         'length': 20.97,
#         'remainDistance': 1654,
#         'remainTime': 59,
#         'shape': [35.33914, 139.48522, 35.33922, 139.48543],
#         'functionalClass': 4,
#         'confidence': 0.79},
#        {'linkId': '17639152640',
#         'length': 21.72,
#         'remainDistance': 1633,
#         'remainTime': 59,
#         'shape': [35.33922,
#          139.48543,
#          35.33924,
#          139.48554,
#          35.33925,
#          139.48566],
#         'functionalClass': 4,
#         'confidence': 0.81},
#        {'linkId': '17664318464',
#         'length': 111.98,
#         'remainDistance': 1611,
#         'remainTime': 59,
#         'shape': [35.33925, 139.48566, 35.33932, 139.48689],
#         'functionalClass': 4,
#         'confidence': 0.81},
#        {'linkId': '17645835264',
#         'length': 12.42,
#         'remainDistance': 1499,
#         'remainTime': 59,
#         'shape': [35.33932, 139.48689, 35.33933, 139.48703],
#         'functionalClass': 4,
#         'confidence': 0.81},
#        {'linkId': '-17667873792',
#         'length': 81.9,
#         'remainDistance': 1487,
#         'remainTime': 59,
#         'shape': [35.33933,
#          139.48703,
#          35.33937,
#          139.48713,
#          35.33938,
#          139.48737,
#          35.33941,
#          139.48748,
#          35.3394,
#          139.48759,
#          35.33937,
#          139.48765,
#          35.33932,
#          139.48776,
#          35.33926,
#          139.48786],
#         'functionalClass': 4,
#         'confidence': 0.81},
#        {'linkId': '17642933248',
#         'length': 99.05,
#         'remainDistance': 1405,
#         'remainTime': 53,
#         'shape': [35.33926,
#          139.48786,
#          35.33999,
#          139.48791,
#          35.34015,
#          139.4879],
#         'functionalClass': 4,
#         'confidence': 0.72},
#        {'linkId': '-17652382720',
#         'length': 80.36,
#         'remainDistance': 1306,
#         'remainTime': 53,
#         'shape': [35.34015, 139.4879, 35.34008, 139.48878],
#         'functionalClass': 4,
#         'confidence': 0.9},
#        {'linkId': '-17664386048',
#         'length': 81.15,
#         'remainDistance': 1225,
#         'remainTime': 49,
#         'shape': [35.34008,
#          139.48878,
#          35.34005,
#          139.48939,
#          35.34004,
#          139.48967],
#         'functionalClass': 4,
#         'confidence': 0.74},
#        {'linkId': '17647150080',
#         'length': 45.07,
#         'remainDistance': 1144,
#         'remainTime': 44,
#         'shape': [35.34004,
#          139.48967,
#          35.34007,
#          139.48986,
#          35.34012,
#          139.49016],
#         'functionalClass': 4,
#         'confidence': 0.87},
#        {'linkId': '17656833024',
#         'length': 19.06,
#         'remainDistance': 1099,
#         'remainTime': 44,
#         'shape': [35.34012, 139.49016, 35.34016, 139.49036],
#         'functionalClass': 4,
#         'confidence': 1.0},
#        {'linkId': '17664969728',
#         'length': 37.89,
#         'remainDistance': 1080,
#         'remainTime': 44,
#         'shape': [35.34016, 139.49036, 35.34025, 139.49077],
#         'functionalClass': 4,
#         'confidence': 1.0},
#        {'linkId': '17667089408',
#         'length': 91.91,
#         'remainDistance': 1042,
#         'remainTime': 43,
#         'shape': [35.34025,
#          139.49077,
#          35.34032,
#          139.49122,
#          35.34035,
#          139.49138,
#          35.34039,
#          139.49176],
#         'functionalClass': 4,
#         'confidence': 1.0},
#        {'linkId': '-17651906560',
#         'length': 84.5,
#         'remainDistance': 950,
#         'remainTime': 43,
#         'shape': [35.34039, 139.49176, 35.34038, 139.49269],
#         'functionalClass': 4,
#         'confidence': 1.0},
#        {'linkId': '-17640605696',
#         'length': 71.28,
#         'remainDistance': 866,
#         'remainTime': 42,
#         'shape': [35.34038, 139.49269, 35.34037, 139.49348],
#         'functionalClass': 4,
#         'confidence': 0.74},
#        {'linkId': '17669050368',
#         'length': 40.78,
#         'remainDistance': 794,
#         'remainTime': 33,
#         'shape': [35.34037, 139.49348, 35.34037, 139.49393],
#         'functionalClass': 4,
#         'confidence': 1.0},
#        {'linkId': '17657990144',
#         'length': 47.0,
#         'remainDistance': 754,
#         'remainTime': 31,
#         'shape': [35.34037, 139.49393, 35.34039, 139.49444],
#         'functionalClass': 4,
#         'confidence': 0.95},
#        {'linkId': '17663331328',
#         'length': 65.57,
#         'remainDistance': 707,
#         'remainTime': 31,
#         'shape': [35.34039, 139.49444, 35.34046, 139.49516],
#         'functionalClass': 4,
#         'confidence': 0.95},
#        {'linkId': '17648779264',
#         'length': 36.87,
#         'remainDistance': 641,
#         'remainTime': 29,
#         'shape': [35.34046, 139.49516, 35.34049, 139.49557],
#         'functionalClass': 4,
#         'confidence': 1.0},
#        {'linkId': '17638365184',
#         'length': 30.68,
#         'remainDistance': 604,
#         'remainTime': 29,
#         'shape': [35.34049, 139.49557, 35.34049, 139.4959],
#         'functionalClass': 4,
#         'confidence': 1.0},
#        {'linkId': '-17658278912',
#         'length': 24.35,
#         'remainDistance': 574,
#         'remainTime': 27,
#         'shape': [35.34049, 139.4959, 35.34048, 139.49617],
#         'functionalClass': 4,
#         'confidence': 0.98},
#        {'linkId': '-17642129411',
#         'length': 10.81,
#         'remainDistance': 549,
#         'remainTime': 27,
#         'shape': [35.34048, 139.49617, 35.34047, 139.49629],
#         'functionalClass': 4,
#         'confidence': 0.93},
#        {'linkId': '-17642129410',
#         'length': 46.17,
#         'remainDistance': 538,
#         'remainTime': 27,
#         'shape': [35.34047, 139.49629, 35.34046, 139.4968],
#         'functionalClass': 4,
#         'confidence': 0.89},
#        {'linkId': '-17642129409',
#         'length': 61.94,
#         'remainDistance': 492,
#         'remainTime': 27,
#         'shape': [35.34046, 139.4968, 35.34043, 139.49748],
#         'functionalClass': 4,
#         'confidence': 0.87},
#        {'linkId': '-17642129408',
#         'length': 16.07,
#         'remainDistance': 430,
#         'remainTime': 27,
#         'shape': [35.34043, 139.49748, 35.34043, 139.49766],
#         'functionalClass': 4,
#         'confidence': 0.85},
#        {'linkId': '17644811264',
#         'length': 50.06,
#         'remainDistance': 414,
#         'remainTime': 27,
#         'shape': [35.34043, 139.49766, 35.34043, 139.49821],
#         'functionalClass': 4,
#         'confidence': 0.85},
#        {'linkId': '-17666061312',
#         'length': 61.36,
#         'remainDistance': 364,
#         'remainTime': 27,
#         'shape': [35.34043,
#          139.49821,
#          35.34033,
#          139.49824,
#          35.33993,
#          139.49849],
#         'functionalClass': 4,
#         'confidence': 0.85},
#        {'linkId': '-17642044416',
#         'length': 67.02,
#         'remainDistance': 303,
#         'remainTime': 23,
#         'shape': [35.33993, 139.49849, 35.33939, 139.49883],
#         'functionalClass': 4,
#         'confidence': 0.96},
#        {'linkId': '-17658225665',
#         'length': 110.17,
#         'remainDistance': 236,
#         'remainTime': 23,
#         'shape': [35.33939, 139.49883, 35.33852, 139.49939],
#         'functionalClass': 4,
#         'confidence': 0.96},
#        {'linkId': '-17658225664',
#         'length': 71.8,
#         'remainDistance': 126,
#         'remainTime': 15,
#         'shape': [35.33852, 139.49939, 35.33795, 139.49976],
#         'functionalClass': 4,
#         'confidence': 0.93},
#        {'linkId': '17661700096',
#         'length': 42.25,
#         'remainDistance': 54,
#         'remainTime': 10,
#         'shape': [35.33795, 139.49976, 35.33811, 139.50018],
#         'functionalClass': 5,
#         'confidence': 0.89},
#        {'linkId': '17650785280',
#         'length': 52.91,
#         'remainDistance': 12,
#         'remainTime': 10,
#         'shape': [35.33811, 139.50018, 35.33834, 139.5007],
#         'functionalClass': 5,
#         'confidence': 0.89}],
#       'trafficTime': 386,
#       'baseTime': 386}],
#     'summary': {'travelTime': 386,
#      'distance': 10258,
#      'baseTime': 386,
#      'trafficTime': 386,
#      'flags': [],
#      'departure': '2021-01-20T04:59:06+09',
#      'arrival': '2021-01-20T05:05:32+09'},
#     'matchedVehicleType': [{'type': 'truck',
#       'subType': 'medium',
#       'confidence': 0.35},
#      {'type': 'truck', 'subType': 'heavy', 'confidence': 0.35},
#      {'type': 'truck', 'subType': 'light', 'confidence': 0.21},
#      {'type': 'car', 'confidence': 0.1}]}],
#   'warnings': [{'message': 'Vehicle stopped until trace point 10',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 0,
#     'toTracePointSeqNum': 10},
#    {'message': 'Vehicle stopped until trace point 27',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 23,
#     'toTracePointSeqNum': 27},
#    {'message': 'Vehicle stopped until trace point 32',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 28,
#     'toTracePointSeqNum': 32},
#    {'message': 'Vehicle stopped until trace point 34',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 33,
#     'toTracePointSeqNum': 34},
#    {'message': 'Vehicle stopped until trace point 40',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 38,
#     'toTracePointSeqNum': 40},
#    {'message': 'Vehicle stopped until trace point 52',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 41,
#     'toTracePointSeqNum': 52},
#    {'message': 'Vehicle stopped until trace point 56',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 54,
#     'toTracePointSeqNum': 56},
#    {'message': 'Vehicle stopped until trace point 72',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 58,
#     'toTracePointSeqNum': 72},
#    {'message': 'Vehicle stopped until trace point 75',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 73,
#     'toTracePointSeqNum': 75},
#    {'message': 'Vehicle stopped until trace point 81',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 77,
#     'toTracePointSeqNum': 81},
#    {'message': 'Vehicle stopped until trace point 85',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 84,
#     'toTracePointSeqNum': 85},
#    {'message': 'Vehicle stopped until trace point 88',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 86,
#     'toTracePointSeqNum': 88},
#    {'message': 'Vehicle stopped until trace point 91',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 90,
#     'toTracePointSeqNum': 91},
#    {'message': 'Vehicle stopped until trace point 98',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 92,
#     'toTracePointSeqNum': 98},
#    {'message': 'Vehicle stopped until trace point 104',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 100,
#     'toTracePointSeqNum': 104},
#    {'message': 'Vehicle stopped until trace point 110',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 105,
#     'toTracePointSeqNum': 110},
#    {'message': 'Vehicle stopped until trace point 114',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 111,
#     'toTracePointSeqNum': 114},
#    {'message': 'Vehicle stopped until trace point 117',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 116,
#     'toTracePointSeqNum': 117},
#    {'message': 'Vehicle stopped until trace point 125',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 118,
#     'toTracePointSeqNum': 125},
#    {'message': 'Vehicle stopped until trace point 127',
#     'code': 1010,
#     'routeLinkSeqNum': -1,
#     'tracePointSeqNum': 126,
#     'toTracePointSeqNum': 127},
#    {'message': 'Entering link 17642933248 at 35.34015,139.4879 into forbidden driving direction',
#     'code': 3,
#     'routeLinkSeqNum': 54,
#     'tracePointSeqNum': 41},
#    {'message': 'Suspicious u-turn onto link 16576532480',
#     'code': 2,
#     'routeLinkSeqNum': 77,
#     'tracePointSeqNum': -1},
#    {'message': 'Entering link 17642933248 at 35.34015,139.4879 into forbidden driving direction',
#     'code': 3,
#     'routeLinkSeqNum': 147,
#     'tracePointSeqNum': 104}],
#   'language': 'en-us'}}

# %%
response['response']['route'][0]
# Out:
# {'mode': {'type': 'matched',
#   'transportModes': ['car'],
#   'trafficMode': 'enabled'},
#  'boatFerry': False,
#  'railFerry': False,
#  'waypoint': [{'linkId': '+17641467904',
#    'mappedPosition': {'latitude': 35.33829, 'longitude': 139.50073},
#    'originalPosition': {'latitude': 35.33830382, 'longitude': 139.50076906},
#    'spot': 0.86143,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -25.0,
#    'matchDistance': 4.75,
#    'minError': 4.0,
#    'routeLinkSeqNrMatched': 0,
#    'speedMps': 0.0,
#    'timestamp': 1611086346054,
#    'breakDetected': True,
#    'breakDuration': -600566},
#   {'linkId': '+17641467904',
#    'mappedPosition': {'latitude': 35.33829, 'longitude': 139.50073},
#    'originalPosition': {'latitude': 35.33830283, 'longitude': 139.50076558},
#    'spot': 0.86143,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -25.0,
#    'matchDistance': 4.35,
#    'minError': 1000000.0,
#    'routeLinkSeqNrMatched': 0,
#    'speedMps': 0.0,
#    'timestamp': 1611086286049},
#   {'linkId': '+17641467904',
#    'mappedPosition': {'latitude': 35.33828, 'longitude': 139.50073},
#    'originalPosition': {'latitude': 35.33829415, 'longitude': 139.50077231},
#    'spot': 0.83717,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -25.0,
#    'matchDistance': 4.97,
#    'minError': 5.0,
#    'routeLinkSeqNrMatched': 0,
#    'speedMps': 0.0,
#    'timestamp': 1611086225947},
#   {'linkId': '+17641467904',
#    'mappedPosition': {'latitude': 35.33827, 'longitude': 139.50074},
#    'originalPosition': {'latitude': 35.33826498, 'longitude': 139.50073697},
#    'spot': 0.80196,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -25.0,
#    'matchDistance': 0.65,
#    'minError': 1.0,
#    'routeLinkSeqNrMatched': 0,
#    'speedMps': 0.0,
#    'timestamp': 1611086165918},
#   {'linkId': '+17641467904',
#    'mappedPosition': {'latitude': 35.33826, 'longitude': 139.50074},
#    'originalPosition': {'latitude': 35.33825346, 'longitude': 139.50072245},
#    'spot': 0.78852,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -25.0,
#    'matchDistance':

#   {'linkId': '-17650785280',
#    'mappedPosition': {'latitude': 35.33834, 'longitude': 139.5007},
#    'originalPosition': {'latitude': 35.33853997, 'longitude': 139.50108858},
#    'spot': 0.0,
#    'confidenceValue': 0.1,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 148.0,
#    'headingMatched': -118.0,
#    'matchDistance': 48.64,
#    'minError': 49.0,
#    'routeLinkSeqNrMatched': 1,
#    'speedMps': 0.0,
#    'timestamp': 1611084964905,
#    'breakDetected': True,
#    'breakDuration': -240341},
#   {'linkId': '-17650785280',
#    'mappedPosition': {'latitude': 35.33833, 'longitude': 139.50068},
#    'originalPosition': {'latitude': 35.3383665, 'longitude': 139.50065896},
#    'spot': 0.96519,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 309.0,
#    'headingMatched': -118.0,
#    'matchDistance': 4.61,
#    'minError': 2.0,
#    'routeLinkSeqNrMatched': 1,
#    'speedMps': 1.0,
#    'timestamp': 1611084904865},
#   {'linkId': '-17650785280',
#    'mappedPosition': {'latitude': 35.33834, 'longitude': 139.5007},
#    'originalPosition': {'latitude': 35.33824491, 'longitude': 139.50085557},
#    'spot': 0.0,
#    'confidenceValue': 0.25,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -118.0,
#    'matchDistance': 20.29,
#    'minError': 20.0,
#    'routeLinkSeqNrMatched': 1,
#    'speedMps': 0.0,
#    'timestamp': 1611084844765},
#   {'linkId': '-17650785280',
#    'mappedPosition': {'latitude': 35.33834, 'longitude': 139.5007},
#    'originalPosition': {'latitude': 35.33819186, 'longitude': 139.50094361},
#    'spot': 0.0,
#    'confidenceValue': 0.16,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -118.0,
#    'matchDistance': 31.73,
#    'minError': 32.0,
#    'routeLinkSeqNrMatched': 1,
#    'speedMps': 0.0,
#    'timestamp': 1611084784665},
#   {'linkId': '+17642044416',
#    'mappedPosition': {'latitude': 35.33964, 'longitude': 139.49867},
#    'originalPosition': {'latitude': 35.33963864, 'longitude': 139.49866784},
#    'spot': 0.46389,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 152.0,
#    'headingMatched': -27.0,
#    'matchDistance': 0.54,
#    'minError': 0.0,
#    'routeLinkSeqNrMatched': 5,
#    'speedMps': 8.0,
#    'timestamp': 1611084724564},
#   {'linkId': '+17666061312',
#    'mappedPosition': {'latitude': 35.34016, 'longitude': 139.49835},
#    'originalPosition': {'latitude': 35.34027917, 'longitude': 139.49864256},
#    'spot': 0.46118,
#    'confidenceValue': 0.14,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -27.0,
#    'matchDistance': 35.47,
#    'minError': 20.0,
#    'routeLinkSeqNrMatched': 6,
#    'speedMps': 0.0,
#    'timestamp': 1611084664463,
#    'breakDetected': True,
#    'breakDuration': -240210},
#   {'linkId': '+17666061312',
#    'mappedPosition': {'latitude': 35.34016, 'longitude': 139.49835},
#    'originalPosition': {'latitude': 35.34028769, 'longitude': 139.49864509},
#    'spot': 0.46118,
#    'confidenceValue': 0.14,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -27.0,
#    'matchDistance': 36.11,
#    'minError': 1000000.0,
#    'routeLinkSeqNrMatched': 6,
#    'speedMps': 0.0,
#    'timestamp': 1611084604385},
#   {'linkId': '+17666061312',
#    'mappedPosition': {'latitude': 35.34017, 'longitude': 139.49834},
#    'originalPosition': {'latitude': 35.34029617, 'longitude': 139.49865026},
#    'spot': 0.48346,
#    'confidenceValue': 0.13,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -27.0,
#    'matchDistance': 37.28,
#    'minError': 37.0,
#    'routeLinkSeqNrMatched': 6,
#    'speedMps': 0.0,
#    'timestamp': 1611084544358},
#   {'linkId': '+17666061312',
#    'mappedPosition': {'latitude': 35.34017, 'longitude': 139.49834},
#    'originalPosition': {'latitude': 35.34029454, 'longitude': 139.49862883},
#    'spot': 0.49522,
#    'confidenceValue': 0.14,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -27.0,
#    'matchDistance': 35.01,
#    'minError': 35.0,
#    'routeLinkSeqNrMatched': 6,
#    'speedMps': 0.0,
#    'timestamp': 1611084484257},
#   {'linkId': '+17666061312',
#    'mappedPosition': {'latitude': 35.34016, 'longitude': 139.49835},
#    'originalPosition': {'latitude': 35.34023312, 'longitude': 139.49855135},
#    'spot': 0.46118,
#    'confidenceValue': 0.21,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 55.0,
#    'headingMatched': -27.0,
#    'matchDistance': 24.15,
#    'minError': 20.0,
#    'routeLinkSeqNrMatched': 6,
#    'speedMps': 3.0,
#    'timestamp': 1611084424253},
#   {'linkId': '+17658278912',
#    'mappedPosition': {'latitude': 35.34048, 'longitude': 139.49605},
#    'originalPosition': {'latitude': 35.34051308, 'longitude': 139.49604915},
#    'spot': 0.45348,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -87.0,
#    'matchDistance': 3.18,
#    'minError': 3.0,
#    'routeLinkSeqNrMatched': 12,
#    'speedMps': 0.0,
#    'timestamp': 1611084364243,
#    'breakDetected': True,
#    'breakDuration': -60083},
#   {'linkId': '+17651906560',
#    'mappedPosition': {'latitude': 35.34038, 'longitude': 139.49259},
#    'originalPosition': {'latitude': 35.3403375, 'longitude': 139.49258535},
#    'spot': 0.11177,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 91.0,
#    'headingMatched': -89.0,
#    'matchDistance': 4.86,
#    'minError': 5.0,
#    'routeLinkSeqNrMatched': 19,
#    'speedMps': 6.0,
#    'timestamp': 1611084304160},
#   {'linkId': '-17656833024',
#    'mappedPosition': {'latitude': 35.34012, 'longitude': 139.49018},
#    'originalPosition': {'latitude': 35.34006126, 'longitude': 139.49020078},
#    'spot': 0.10907,
#    'confidenceValue': 0.68,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 78.0,
#    'headingMatched': -104.0,
#    'matchDistance': 7.33,
#    'minError': 1.0,
#    'routeLinkSeqNrMatched': 22,
#    'speedMps': 7.0,
#    'timestamp': 1611084244156},
#   {'linkId': '-17652381696',
#    'mappedPosition': {'latitude': 35.34017, 'longitude': 139.48656},
#    'originalPosition': {'latitude': 35.3402119, 'longitude': 139.48655334},
#    'spot': 0.56586,
#    'confidenceValue': 0.97,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 95.0,
#    'headingMatched': -95.0,
#    'matchDistance': 5.14,
#    'minError': 5.0,
#    'routeLinkSeqNrMatched': 28,
#    'speedMps': 6.0,
#    'timestamp': 1611084184121},
#   {'linkId': '+17661078528',
#    'mappedPosition': {'latitude': 35.34124, 'longitude': 139.48383},
#    'originalPosition': {'latitude': 35.34123467, 'longitude': 139.48381579},
#    'spot': 0.71222,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 145.0,
#    'headingMatched': -41.0,
#    'matchDistance': 1.79,
#    'minError': 2.0,
#    'routeLinkSeqNrMatched': 36,
#    'speedMps': 6.0,
#    'timestamp': 1611084124029},
#   {'linkId': '-17654185984',
#    'mappedPosition': {'latitude': 35.34016, 'longitude': 139.48255},
#    'originalPosition': {'latitude': 35.34016632, 'longitude': 139.48254896},
#    'spot': 0.60895,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 120.0,
#    'matchDistance': 0.5,
#    'minError': 0.0,
#    'routeLinkSeqNrMatched': 43,
#    'speedMps': 0.0,
#    'timestamp': 1611084063923,
#    'breakDetected': True,
#    'breakDuration': -120203},
#   {'linkId': '+17664318464',
#    'mappedPosition': {'latitude': 35.33927, 'longitude': 139.48605},
#    'originalPosition': {'latitude': 35.33950406, 'longitude': 139.4860282},
#    'spot': 0.31548,
#    'confidenceValue': 0.19,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 86.0,
#    'matchDistance': 25.91,
#    'minError': 9.0,
#    'routeLinkSeqNrMatched': 51,
#    'speedMps': 0.0,
#    'timestamp': 1611084003821},
#   {'linkId': '+17664318464',
#    'mappedPosition': {'latitude': 35.33927, 'longitude': 139.48606},
#    'originalPosition': {'latitude': 35.33938469, 'longitude': 139.48605316},
#    'spot': 0.32741,
#    'confidenceValue': 0.4,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 266.0,
#    'headingMatched': 86.0,
#    'matchDistance': 12.49,
#    'minError': 2.0,
#    'routeLinkSeqNrMatched': 51,
#    'speedMps': 5.0,
#    'timestamp': 1611083943720},
#   {'linkId': '-17667873792',
#    'mappedPosition': {'latitude': 35.33938, 'longitude': 139.48737},
#    'originalPosition': {'latitude': 35.33930677, 'longitude': 139.4873696},
#    'spot': 0.61425,
#    'confidenceValue': 0.61,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 87.0,
#    'matchDistance': 8.14,
#    'minError': 7.0,
#    'routeLinkSeqNrMatched': 53,
#    'speedMps': 0.0,
#    'timestamp': 1611083883708,
#    'breakDetected': True,
#    'breakDuration': -660654},
#   {'linkId': '-17667873792',
#    'mappedPosition': {'latitude': 35.33938, 'longitude': 139.48737},
#    'originalPosition': {'latitude': 35.33932948, 'longitude': 139.4873765},
#    'spot': 0.39129,
#    'confidenceValue': 0.88,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 72.0,
#    'matchDistance': 5.67,
#    'minError': 6.0,
#    'routeLinkSeqNrMatched': 53,
#    'speedMps': 0.0,
#    'timestamp': 1611083823678},
#   {'linkId': '-17667873792',
#    'mappedPosition': {'latitude': 35.33938, 'longitude': 139.48738},
#    'originalPosition': {'latitude': 35.33934437, 'longitude': 139.48739978},
#    'spot': 0.40731,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 72.0,
#    'matchDistance': 4.54,
#    'minError': 5.0,
#    'routeLinkSeqNrMatched': 53,
#    'speedMps': 0.0,
#    'timestamp': 1611083763578},
#   {'linkId': '-17667873792',
#    'mappedPosition': {'latitude': 35.33938, 'longitude': 139.48738},
#    'originalPosition': {'latitude': 35.33934035, 'longitude': 139.48739833},
#    'spot': 0.40731,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 72.0,
#    'matchDistance': 4.86,
#    'minError': 1000000.0,
#    'routeLinkSeqNrMatched': 53,
#    'speedMps': 0.0,
#    'timestamp': 1611083703470},
#   {'linkId': '-17667873792',
#    'mappedPosition': {'latitude': 35.33941, 'longitude': 139.48748},
#    'originalPosition': {'latitude': 35.3396331, 'longitude': 139.48744994},
#    'spot': 0.52034,
#    'confidenceValue': 0.2,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 173.0,
#    'headingMatched': 96.0,
#    'matchDistance': 25.06,
#    'minError': 25.0,
#    'routeLinkSeqNrMatched': 53,
#    'speedMps': 0.0,
#    'timestamp': 1611083643435},
#   {'linkId': '-17667873792',
#    'mappedPosition': {'latitude': 35.3394, 'longitude': 139.48759},
#    'originalPosition': {'latitude': 35.33950308, 'longitude': 139.48762115},
#    'spot': 0.64348,
#    'confidenceValue': 0.42,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 122.0,
#    'matchDistance': 11.99,
#    'minError': 12.0,
#    'routeLinkSeqNrMatched': 53,
#    'speedMps': 0.0,
#    'timestamp': 1611083583343},
#   {'linkId': '+17642933248',
#    'mappedPosition': {'latitude': 35.33955, 'longitude': 139.48788},
#    'originalPosition': {'latitude': 35.33955357, 'longitude': 139.4877657},
#    'spot': 0.32403,
#    'confidenceValue': 0.39,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 3.0,
#    'matchDistance': 12.73,
#    'minError': 13.0,
#    'routeLinkSeqNrMatched': 54,
#    'speedMps': 0.0,
#    'timestamp': 1611083523327},
#   {'linkId': '+17642933248',
#    'mappedPosition': {'latitude': 35.33959, 'longitude': 139.48788},
#    'originalPosition': {'latitude': 35.3396004, 'longitude': 139.48769518},
#    'spot': 0.37288,
#    'confidenceValue': 0.24,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 3.0,
#    'matchDistance': 20.6,
#    'minError': 21.0,
#    'routeLinkSeqNrMatched': 54,
#    'speedMps': 0.0,
#    'timestamp': 1611083463225},
#   {'linkId': '+17642933248',
#    'mappedPosition': {'latitude': 35.33926, 'longitude': 139.48786},
#    'originalPosition': {'latitude': 35.33927633, 'longitude': 139.48737901},
#    'spot': 0.0,
#    'confidenceValue': 0.09,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 3.0,
#    'matchDistance': 53.57,
#    'minError': 54.0,
#    'routeLinkSeqNrMatched': 54,
#    'speedMps': 0.0,
#    'timestamp': 1611083403219},
#   {'linkId': '+17642933248',
#    'mappedPosition': {'latitude': 35.33927, 'longitude': 139.48786},
#    'originalPosition': {'latitude': 35.33929014, 'longitude': 139.48745115},
#    'spot': 0.01289,
#    'confidenceValue': 0.11,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 3.0,
#    'matchDistance': 45.56,
#    'minError': 46.0,
#    'routeLinkSeqNrMatched': 54,
#    'speedMps': 0.0,
#    'timestamp': 1611083343163},
#   {'linkId': '+17642933248',
#    'mappedPosition': {'latitude': 35.33932, 'longitude': 139.48786},
#    'originalPosition': {'latitude': 35.33934272, 'longitude': 139.48746387},
#    'spot': 0.07243,
#    'confidenceValue': 0.11,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 3.0,
#    'matchDistance': 44.16,
#    'minError': 44.0,
#    'routeLinkSeqNrMatched': 54,
#    'speedMps': 0.0,
#    'timestamp': 1611083283155},
#   {'linkId': '+17642933248',
#    'mappedPosition': {'latitude': 35.33983, 'longitude': 139.4879},
#    'originalPosition': {'latitude': 35.33982407, 'longitude': 139.48793027},
#    'spot': 0.63543,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 210.0,
#    'headingMatched': 3.0,
#    'matchDistance': 3.51,
#    'minError': 3.0,
#    'routeLinkSeqNrMatched': 54,
#    'speedMps': 3.0,
#    'timestamp': 1611083223054},
#   {'linkId': '-17644083201',
#    'mappedPosition': {'latitude': 35.33982, 'longitude': 139.4903},
#    'originalPosition': {'latitude': 35.33981067, 'longitude': 139.49025267},
#    'spot': 0.55349,
#    'confidenceValue': 0.98,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 343.0,
#    'headingMatched': 162.0,
#    'matchDistance': 5.11,
#    'minError': 4.0,
#    'routeLinkSeqNrMatched': 58,
#    'speedMps': 12.0,
#    'timestamp': 1611083163032},
#   {'linkId': '-17640504320',
#    'mappedPosition': {'latitude': 35.33637, 'longitude': 139.49001},
#    'originalPosition': {'latitude': 35.33634417, 'longitude': 139.49012999},
#    'spot': 0.84745,
#    'confidenceValue': 0.35,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 165.0,
#    'headingMatched': -164.0,
#    'matchDistance': 14.16,
#    'minError': 12.0,
#    'routeLinkSeqNrMatched': 69,
#    'speedMps': 1.0,
#    'timestamp': 1611083103013,
#    'breakDetected': True,
#    'breakDuration': -120123},
#   {'linkId': '-17640504320',
#    'mappedPosition': {'latitude': 35.3363, 'longitude': 139.48998},
#    'originalPosition': {'latitude': 35.33628181, 'longitude': 139.49007694},
#    'spot': 0.2087,
#    'confidenceValue': 0.46,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -164.0,
#    'matchDistance': 10.98,
#    'minError': 11.0,
#    'routeLinkSeqNrMatched': 69,
#    'speedMps': 0.0,
#    'timestamp': 1611083042911},
#   {'linkId': '-16576349184',
#    'mappedPosition': {'latitude': 35.3311, 'longitude': 139.48815},
#    'originalPosition': {'latitude': 35.3311081, 'longitude': 139.48812623},
#    'spot': 0.63101,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 15.0,
#    'headingMatched': -164.0,
#    'matchDistance': 2.38,
#    'minError': 2.0,
#    'routeLinkSeqNrMatched': 75,
#    'speedMps': 10.0,
#    'timestamp': 1611082982890},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32906, 'longitude': 139.4876},
#    'originalPosition': {'latitude': 35.32860256, 'longitude': 139.48812396},
#    'spot': 0.0,
#    'confidenceValue': 0.06,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 245.0,
#    'headingMatched': 9.0,
#    'matchDistance': 77.41,
#    'minError': 2.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 4.0,
#    'timestamp': 1611082922869},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32935, 'longitude': 139.48766},
#    'originalPosition': {'latitude': 35.32931872, 'longitude': 139.48790258},
#    'spot': 0.27913,
#    'confidenceValue': 0.18,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 9.0,
#    'matchDistance': 27.69,
#    'minError': 23.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 0.0,
#    'timestamp': 1611082862850,
#    'breakDetected': True,
#    'breakDuration': -900781},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32935, 'longitude': 139.48766},
#    'originalPosition': {'latitude': 35.3293155, 'longitude': 139.48791592},
#    'spot': 0.27772,
#    'confidenceValue': 0.17,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 9.0,
#    'matchDistance': 28.74,
#    'minError': 29.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 0.0,
#    'timestamp': 1611082802846},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32934, 'longitude': 139.48765},
#    'originalPosition': {'latitude': 35.32930204, 'longitude': 139.48793563},
#    'spot': 0.26746,
#    'confidenceValue': 0.16,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 9.0,
#    'matchDistance': 32.07,
#    'minError': 32.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 0.0,
#    'timestamp': 1611082742745},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32933, 'longitude': 139.48765},
#    'originalPosition': {'latitude': 35.32929445, 'longitude': 139.48796048},
#    'spot': 0.26332,
#    'confidenceValue': 0.14,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 9.0,
#    'matchDistance': 34.78,
#    'minError': 35.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 0.0,
#    'timestamp': 1611082682678},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32934, 'longitude': 139.48765},
#    'originalPosition': {'latitude': 35.32929413, 'longitude': 139.48797865},
#    'spot': 0.2652,
#    'confidenceValue': 0.14,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 9.0,
#    'matchDistance': 36.93,
#    'minError': 37.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 0.0,
#    'timestamp': 1611082622662},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32931, 'longitude': 139.48765},
#    'originalPosition': {'latitude': 35.3292686, 'longitude': 139.48798706},
#    'spot': 0.24225,
#    'confidenceValue': 0.13,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 9.0,
#    'matchDistance': 37.8,
#    'minError': 38.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 0.0,
#    'timestamp': 1611082562631},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32929, 'longitude': 139.48765},
#    'originalPosition': {'latitude': 35.329253, 'longitude': 139.48797076},
#    'spot': 0.22565,
#    'confidenceValue': 0.14,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 9.0,
#    'matchDistance': 35.94,
#    'minError': 36.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 0.0,
#    'timestamp': 1611082502551},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32927, 'longitude': 139.48764},
#    'originalPosition': {'latitude': 35.32922408, 'longitude': 139.48801806},
#    'spot': 0.2042,
#    'confidenceValue': 0.12,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 9.0,
#    'matchDistance': 42.39,
#    'minError': 42.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 0.0,
#    'timestamp': 1611082442490},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32925, 'longitude': 139.48764},
#    'originalPosition': {'latitude': 35.32919776, 'longitude': 139.4880241},
#    'spot': 0.18022,
#    'confidenceValue': 0.12,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 9.0,
#    'matchDistance': 43.14,
#    'minError': 43.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 0.0,
#    'timestamp': 1611082382487},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32923, 'longitude': 139.48763},
#    'originalPosition': {'latitude': 35.3291807, 'longitude': 139.48804487},
#    'spot': 0.16671,
#    'confidenceValue': 0.11,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 9.0,
#    'matchDistance': 46.5,
#    'minError': 46.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 0.0,
#    'timestamp': 1611082322445},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32937, 'longitude': 139.48766},
#    'originalPosition': {'latitude': 35.32929483, 'longitude': 139.48826787},
#    'spot': 0.3006,
#    'confidenceValue': 0.07,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 238.0,
#    'headingMatched': 9.0,
#    'matchDistance': 68.17,
#    'minError': 68.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 0.0,
#    'timestamp': 1611082262342},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32935, 'longitude': 139.48766},
#    'originalPosition': {'latitude': 35.32915146, 'longitude': 139.48807138},
#    'spot': 0.27913,
#    'confidenceValue': 0.1,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 284.0,
#    'headingMatched': 9.0,
#    'matchDistance': 51.27,
#    'minError': 30.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 1.0,
#    'timestamp': 1611082202240},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.3294, 'longitude': 139.48767},
#    'originalPosition': {'latitude': 35.3292874, 'longitude': 139.48853095},
#    'spot': 0.3252,
#    'confidenceValue': 0.05,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 255.0,
#    'headingMatched': 9.0,
#    'matchDistance': 97.16,
#    'minError': 9.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 1.0,
#    'timestamp': 1611082082193},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32968, 'longitude': 139.48772},
#    'originalPosition': {'latitude': 35.32956817, 'longitude': 139.48856453},
#    'spot': 0.59272,
#    'confidenceValue': 0.05,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 301.0,
#    'headingMatched': 9.0,
#    'matchDistance': 94.93,
#    'minError': 7.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 1.0,
#    'timestamp': 1611082022092},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32968, 'longitude': 139.48772},
#    'originalPosition': {'latitude': 35.32946755, 'longitude': 139.48819214},
#    'spot': 0.59272,
#    'confidenceValue': 0.09,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 341.0,
#    'headingMatched': 9.0,
#    'matchDistance': 57.61,
#    'minError': 24.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 2.0,
#    'timestamp': 1611081962069},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32968, 'longitude': 139.48772},
#    'originalPosition': {'latitude': 35.32899919, 'longitude': 139.488321},
#    'spot': 0.59272,
#    'confidenceValue': 0.05,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 340.0,
#    'headingMatched': 9.0,
#    'matchDistance': 100.89,
#    'minError': 6.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 1.0,
#    'timestamp': 1611081902004,
#    'breakDetected': True,
#    'breakDuration': -120049},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32972, 'longitude': 139.48773},
#    'originalPosition': {'latitude': 35.32966277, 'longitude': 139.48815049},
#    'spot': 0.63178,
#    'confidenceValue': 0.11,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 9.0,
#    'matchDistance': 47.59,
#    'minError': 31.0,
#    'routeLinkSeqNrMatched': 77,
#    'speedMps': 0.0,
#    'timestamp': 1611081841964},
#   {'linkId': '-17665159168',
#    'mappedPosition': {'latitude': 35.33723, 'longitude': 139.4898},
#    'originalPosition': {'latitude': 35.3378034, 'longitude': 139.4888163},
#    'spot': 1.0,
#    'confidenceValue': 0.04,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -148.0,
#    'matchDistance': 126.73,
#    'minError': 10.0,
#    'routeLinkSeqNrMatched': 90,
#    'speedMps': 0.0,
#    'timestamp': 1611081781955},
#   {'linkId': '-16576532480',
#    'mappedPosition': {'latitude': 35.32972, 'longitude': 139.48773},
#    'originalPosition': {'latitude': 35.329709, 'longitude': 139.4878285},
#    'spot': 0.63649,
#    'confidenceValue': 0.44,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -171.0,
#    'matchDistance': 11.36,
#    'minError': 9.0,
#    'routeLinkSeqNrMatched': 101,
#    'speedMps': 0.0,
#    'timestamp': 1611081721871},
#   {'linkId': '-16576532480',
#    'mappedPosition': {'latitude': 35.32961, 'longitude': 139.48771},
#    'originalPosition': {'latitude': 35.32952987, 'longitude': 139.48831923},
#    'spot': 0.47266,
#    'confidenceValue': 0.07,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -171.0,
#    'matchDistance': 68.39,
#    'minError': 68.0,
#    'routeLinkSeqNrMatched': 101,
#    'speedMps': 0.0,
#    'timestamp': 1611081661774,
#    'breakDetected': True,
#    'breakDuration': -240258},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32972, 'longitude': 139.48773},
#    'originalPosition': {'latitude': 35.32925496, 'longitude': 139.48784613},
#    'spot': 0.63649,
#    'confidenceValue': 0.09,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 29.0,
#    'headingMatched': 9.0,
#    'matchDistance': 53.63,
#    'minError': 19.0,
#    'routeLinkSeqNrMatched': 102,
#    'speedMps': 1.0,
#    'timestamp': 1611081601670},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32952, 'longitude': 139.48769},
#    'originalPosition': {'latitude': 35.32955579, 'longitude': 139.48737095},
#    'spot': 0.43776,
#    'confidenceValue': 0.14,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 9.0,
#    'matchDistance': 35.73,
#    'minError': 36.0,
#    'routeLinkSeqNrMatched': 102,
#    'speedMps': 0.0,
#    'timestamp': 1611081541578},
#   {'linkId': '+16576532480',
#    'mappedPosition': {'latitude': 35.32972, 'longitude': 139.48773},
#    'originalPosition': {'latitude': 35.32947682, 'longitude': 139.48759994},
#    'spot': 0.63649,
#    'confidenceValue': 0.16,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 82.0,
#    'headingMatched': 9.0,
#    'matchDistance': 30.75,
#    'minError': 7.0,
#    'routeLinkSeqNrMatched': 102,
#    'speedMps': 1.0,
#    'timestamp': 1611081481569},
#   {'linkId': '+16576349184',
#    'mappedPosition': {'latitude': 35.33026, 'longitude': 139.48786},
#    'originalPosition': {'latitude': 35.33024998, 'longitude': 139.48791895},
#    'spot': 0.10332,
#    'confidenceValue': 0.7,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 194.0,
#    'headingMatched': 16.0,
#    'matchDistance': 7.1,
#    'minError': 6.0,
#    'routeLinkSeqNrMatched': 103,
#    'speedMps': 10.0,
#    'timestamp': 1611081421516},
#   {'linkId': '+17664087040',
#    'mappedPosition': {'latitude': 35.33342, 'longitude': 139.48896},
#    'originalPosition': {'latitude': 35.33340493, 'longitude': 139.48900799},
#    'spot': 0.25624,
#    'confidenceValue': 0.85,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 197.0,
#    'headingMatched': 15.0,
#    'matchDistance': 5.89,
#    'minError': 5.0,
#    'routeLinkSeqNrMatched': 106,
#    'speedMps': 9.0,
#    'timestamp': 1611081361409},
#   {'linkId': '+17640734724',
#    'mappedPosition': {'latitude': 35.33864, 'longitude': 139.49042},
#    'originalPosition': {'latitude': 35.33864283, 'longitude': 139.49048144},
#    'spot': 0.07871,
#    'confidenceValue': 0.74,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 185.0,
#    'headingMatched': 2.0,
#    'matchDistance': 6.75,
#    'minError': 6.0,
#    'routeLinkSeqNrMatched': 118,
#    'speedMps': 10.0,
#    'timestamp': 1611081301301},
#   {'linkId': '-17647150080',
#    'mappedPosition': {'latitude': 35.34007, 'longitude': 139.48983},
#    'originalPosition': {'latitude': 35.33988755, 'longitude': 139.48987355},
#    'spot': 0.32884,
#    'confidenceValue': 0.25,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -101.0,
#    'matchDistance': 20.35,
#    'minError': 13.0,
#    'routeLinkSeqNrMatched': 121,
#    'speedMps': 0.0,
#    'timestamp': 1611081241230,
#    'breakDetected': True,
#    'breakDuration': -60013},
#   {'linkId': '-17652381696',
#    'mappedPosition': {'latitude': 35.34019, 'longitude': 139.48698},
#    'originalPosition': {'latitude': 35.34019256, 'longitude': 139.48720263},
#    'spot': 1.0,
#    'confidenceValue': 0.2,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 99.0,
#    'headingMatched': -90.0,
#    'matchDistance': 24.78,
#    'minError': 0.0,
#    'routeLinkSeqNrMatched': 126,
#    'speedMps': 5.0,
#    'timestamp': 1611081181217},
#   {'linkId': '-17652381696',
#    'mappedPosition': {'latitude': 35.34018, 'longitude': 139.48684},
#    'originalPosition': {'latitude': 35.34014629, 'longitude': 139.48684615},
#    'spot': 0.14148,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -94.0,
#    'matchDistance': 3.81,
#    'minError': 4.0,
#    'routeLinkSeqNrMatched': 126,
#    'speedMps': 0.0,
#    'timestamp': 1611081121115,
#    'breakDetected': True,
#    'breakDuration': -120070},
#   {'linkId': '-17652381696',
#    'mappedPosition': {'latitude': 35.34017, 'longitude': 139.48663},
#    'originalPosition': {'latitude': 35.34009373, 'longitude': 139.48663667},
#    'spot': 0.36115,
#    'confidenceValue': 0.59,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -94.0,
#    'matchDistance': 8.52,
#    'minError': 9.0,
#    'routeLinkSeqNrMatched': 126,
#    'speedMps': 0.0,
#    'timestamp': 1611081061108},
#   {'linkId': '-17641485312',
#    'mappedPosition': {'latitude': 35.34015, 'longitude': 139.48601},
#    'originalPosition': {'latitude': 35.34017528, 'longitude': 139.48611102},
#    'spot': 1.0,
#    'confidenceValue': 0.43,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 73.0,
#    'headingMatched': -143.0,
#    'matchDistance': 11.59,
#    'minError': 4.0,
#    'routeLinkSeqNrMatched': 127,
#    'speedMps': 5.0,
#    'timestamp': 1611081001045},
#   {'linkId': '-17647681536',
#    'mappedPosition': {'latitude': 35.33914, 'longitude': 139.48522},
#    'originalPosition': {'latitude': 35.33919312, 'longitude': 139.48523983},
#    'spot': 1.0,
#    'confidenceValue': 0.79,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 81.0,
#    'headingMatched': -97.0,
#    'matchDistance': 6.31,
#    'minError': 5.0,
#    'routeLinkSeqNrMatched': 129,
#    'speedMps': 6.0,
#    'timestamp': 1611080941031},
#   {'linkId': '-17647681536',
#    'mappedPosition': {'latitude': 35.33909, 'longitude': 139.48476},
#    'originalPosition': {'latitude': 35.33920502, 'longitude': 139.48473979},
#    'spot': 0.34483,
#    'confidenceValue': 0.38,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': -97.0,
#    'matchDistance': 13.0,
#    'minError': 13.0,
#    'routeLinkSeqNrMatched': 129,
#    'speedMps': 0.0,
#    'timestamp': 1611080880929,
#    'breakDetected': True,
#    'breakDuration': -60066},
#   {'linkId': '-17667632128',
#    'mappedPosition': {'latitude': 35.33892, 'longitude': 139.48372},
#    'originalPosition': {'latitude': 35.33893505, 'longitude': 139.4837178},
#    'spot': 0.824,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 82.0,
#    'headingMatched': -97.0,
#    'matchDistance': 1.91,
#    'minError': 2.0,
#    'routeLinkSeqNrMatched': 130,
#    'speedMps': 9.0,
#    'timestamp': 1611080820863},
#   {'linkId': '+17376149504',
#    'mappedPosition': {'latitude': 35.33904, 'longitude': 139.48129},
#    'originalPosition': {'latitude': 35.33919926, 'longitude': 139.48101934},
#    'spot': 0.46154,
#    'confidenceValue': 0.14,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 36.0,
#    'matchDistance': 35.31,
#    'minError': 23.0,
#    'routeLinkSeqNrMatched': 133,
#    'speedMps': 0.0,
#    'timestamp': 1611080760763,
#    'breakDetected': True,
#    'breakDuration': -360222},
#   {'linkId': '+17376149504',
#    'mappedPosition': {'latitude': 35.33903, 'longitude': 139.48129},
#    'originalPosition': {'latitude': 35.33921252, 'longitude': 139.48098767},
#    'spot': 0.45536,
#    'confidenceValue': 0.13,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 36.0,
#    'matchDistance': 39.31,
#    'minError': 39.0,
#    'routeLinkSeqNrMatched': 133,
#    'speedMps': 0.0,
#    'timestamp': 1611080700708},
#   {'linkId': '+17376149504',
#    'mappedPosition': {'latitude': 35.33904, 'longitude': 139.48129},
#    'originalPosition': {'latitude': 35.33922461, 'longitude': 139.48098143},
#    'spot': 0.46485,
#    'confidenceValue': 0.12,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 36.0,
#    'matchDistance': 40.02,
#    'minError': 40.0,
#    'routeLinkSeqNrMatched': 133,
#    'speedMps': 0.0,
#    'timestamp': 1611080640690},
#   {'linkId': '+17376149504',
#    'mappedPosition': {'latitude': 35.33906, 'longitude': 139.48132},
#    'originalPosition': {'latitude': 35.33925135, 'longitude': 139.48099739},
#    'spot': 0.50574,
#    'confidenceValue': 0.12,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 36.0,
#    'matchDistance': 41.75,
#    'minError': 42.0,
#    'routeLinkSeqNrMatched': 133,
#    'speedMps': 0.0,
#    'timestamp': 1611080580678},
#   {'linkId': '+17376149504',
#    'mappedPosition': {'latitude': 35.33899, 'longitude': 139.48125},
#    'originalPosition': {'latitude': 35.33914079, 'longitude': 139.48099944},
#    'spot': 0.38216,
#    'confidenceValue': 0.15,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 36.0,
#    'matchDistance': 32.55,
#    'minError': 33.0,
#    'routeLinkSeqNrMatched': 133,
#    'speedMps': 0.0,
#    'timestamp': 1611080520669},
#   {'linkId': '+17376149504',
#    'mappedPosition': {'latitude': 35.33904, 'longitude': 139.48129},
#    'originalPosition': {'latitude': 35.33917476, 'longitude': 139.4810586},
#    'spot': 0.4601,
#    'confidenceValue': 0.17,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 36.0,
#    'matchDistance': 29.8,
#    'minError': 30.0,
#    'routeLinkSeqNrMatched': 133,
#    'speedMps': 0.0,
#    'timestamp': 1611080460643},
#   {'linkId': '+17376149504',
#    'mappedPosition': {'latitude': 35.33904, 'longitude': 139.48129},
#    'originalPosition': {'latitude': 35.3391091, 'longitude': 139.48098082},
#    'spot': 0.46154,
#    'confidenceValue': 0.14,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 281.0,
#    'headingMatched': 36.0,
#    'matchDistance': 35.58,
#    'minError': 20.0,
#    'routeLinkSeqNrMatched': 133,
#    'speedMps': 3.0,
#    'timestamp': 1611080400541},
#   {'linkId': '-17643427840',
#    'mappedPosition': {'latitude': 35.33947, 'longitude': 139.48428},
#    'originalPosition': {'latitude': 35.33907845, 'longitude': 139.48409619},
#    'spot': 0.0206,
#    'confidenceValue': 0.1,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 256.0,
#    'headingMatched': 111.0,
#    'matchDistance': 48.85,
#    'minError': 9.0,
#    'routeLinkSeqNrMatched': 139,
#    'speedMps': 7.0,
#    'timestamp': 1611080340439},
#   {'linkId': '-17667873792',
#    'mappedPosition': {'latitude': 35.33937, 'longitude': 139.48721},
#    'originalPosition': {'latitude': 35.33941925, 'longitude': 139.48720844},
#    'spot': 0.7855,
#    'confidenceValue': 0.98,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 87.0,
#    'matchDistance': 5.11,
#    'minError': 4.0,
#    'routeLinkSeqNrMatched': 146,
#    'speedMps': 0.0,
#    'timestamp': 1611080280338,
#    'breakDetected': True,
#    'breakDuration': -240253},
#   {'linkId': '-17667873792',
#    'mappedPosition': {'latitude': 35.33937, 'longitude': 139.48719},
#    'originalPosition': {'latitude': 35.33941943, 'longitude': 139.48718899},
#    'spot': 0.1929,
#    'confidenceValue': 0.91,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 87.0,
#    'matchDistance': 5.5,
#    'minError': 6.0,
#    'routeLinkSeqNrMatched': 146,
#    'speedMps': 0.0,
#    'timestamp': 1611080220232},
#   {'linkId': '-17667873792',
#    'mappedPosition': {'latitude': 35.33937, 'longitude': 139.48719},
#    'originalPosition': {'latitude': 35.33946593, 'longitude': 139.48718625},
#    'spot': 0.19309,
#    'confidenceValue': 0.47,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 87.0,
#    'matchDistance': 10.69,
#    'minError': 11.0,
#    'routeLinkSeqNrMatched': 146,
#    'speedMps': 0.0,
#    'timestamp': 1611080160131},
#   {'linkId': '-17667873792',
#    'mappedPosition': {'latitude': 35.33937, 'longitude': 139.48718},
#    'originalPosition': {'latitude': 35.33950259, 'longitude': 139.48717059},
#    'spot': 0.17824,
#    'confidenceValue': 0.34,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 87.0,
#    'matchDistance': 14.79,
#    'minError': 15.0,
#    'routeLinkSeqNrMatched': 146,
#    'speedMps': 0.0,
#    'timestamp': 1611080100090},
#   {'linkId': '-17667873792',
#    'mappedPosition': {'latitude': 35.33937, 'longitude': 139.48765},
#    'originalPosition': {'latitude': 35.33940193, 'longitude': 139.48767436},
#    'spot': 0.27574,
#    'confidenceValue': 1.0,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 248.0,
#    'headingMatched': 119.0,
#    'matchDistance': 4.42,
#    'minError': 4.0,
#    'routeLinkSeqNrMatched': 146,
#    'speedMps': 4.0,
#    'timestamp': 1611080040085},
#   {'linkId': '-17652382720',
#    'mappedPosition': {'latitude': 35.34012, 'longitude': 139.48822},
#    'originalPosition': {'latitude': 35.34024841, 'longitude': 139.48823229},
#    'spot': 0.6392,
#    'confidenceValue': 0.36,
#    'elevation': 0.0,
#    'headingDegreeNorthClockwise': 10000.0,
#    'headingMatched': 96.0,
#    'matchDistance': 13.86,
#    'minError': 14.0,
#    'routeLinkSeqNrMatched': 148,
# ...
#      'remainTime': 114,
#      'shape': [35.33325, 139.4889, 35.3339, 139.48912],
#      'functionalClass': 2,
#      'confidence': 1.0},
#     {'linkId': '17644162048',
#      'length': 72.06,
#      'remainDistance': 3756,
#      'remainTime': 113,
#      'shape': [35.3339, 139.48912, 35.33452, 139.48935],
#      'functionalClass': 2,
#      'confidence': 0.94},
#     {'linkId': '17639108608',
#      'length': 94.34,
#      'remainDistance': 3684,
#      'remainTime': 113,
#      'shape': [35.33452, 139.48935, 35.33533, 139.48965],
#      'functionalClass': 2,
#      'confidence': 0.83},
#     {'linkId': '17640504320',
#      'length': 141.44,
#      'remainDistance': 3590,
#      'remainTime': 113,
#      'shape': [35.33533, 139.48965, 35.33656, 139.49007],
#      'functionalClass': 2,
#      'confidence': 0.67},
#     {'linkId': '17640504321',
#      'length': 6.31,
#      'remainDistance': 3448,
#      'remainTime': 113,
#      'shape': [35.33656, 139.49007, 35.33661, 139.49009],
#      'functionalClass': 2,
#      'confidence': 0.61},
#     {'linkId': '17640504322',
#      'length': 3.5,
#      'remainDistance': 3442,
#      'remainTime': 113,
#      'shape': [35.33661, 139.49009, 35.33664, 139.4901],
#      'functionalClass': 2,
#      'confidence': 0.6},
#     {'linkId': '17641232384',
#      'length': 20.63,
#      'remainDistance': 3439,
#      'remainTime': 113,
#      'shape': [35.33664, 139.4901, 35.33673, 139.49014, 35.33682, 139.49017],
#      'functionalClass': 2,
#      'confidence': 0.58},
#     {'linkId': '17641232385',
#      'length': 43.6,
#      'remainDistance': 3418,
#      'remainTime': 113,
#      'shape': [35.33682, 139.49017, 35.33714, 139.49026, 35.3372, 139.49027],
#      'functionalClass': 2,
#      'confidence': 0.54},
#     {'linkId': '17640734720',
#      'length': 77.18,
#      'remainDistance': 3374,
#      'remainTime': 113,
#      'shape': [35.3372, 139.49027, 35.33789, 139.49034],
#      'functionalClass': 2,
#      'confidence': 0.62},
#     {'linkId': '17640734721',
#      'length': 11.52,
#      'remainDistance': 3297,
#      'remainTime': 113,
#      'shape': [35.33789, 139.49034, 35.33799, 139.49035],
#      'functionalClass': 2,
#      'confidence': 0.66},
#     {'linkId': '17640734722',
#      'length': 44.59,
#      'remainDistance': 3286,
#      'remainTime': 113,
#      'shape': [35.33799, 139.49035, 35.3382, 139.49038, 35.33839, 139.4904],
#      'functionalClass': 2,
#      'confidence': 0.7},
#     {'linkId': '17640734723',
#      'length': 26.17,
#      'remainDistance': 3241,
#      'remainTime': 113,
#      'shape': [35.33839, 139.4904, 35.33863, 139.49042],
#      'functionalClass': 2,
#      'confidence': 0.74},
#     {'linkId': '17640734724',
#      'length': 21.93,
#      'remainDistance': 3215,
#      'remainTime': 113,
#      'shape': [35.33863, 139.49042, 35.33882, 139.49043],
#      'functionalClass': 2,
#      'confidence': 0.96},
#     {'linkId': '17644083200',
#      'length': 68.95,
#      'remainDistance': 3193,
#      'remainTime': 110,
#      'shape': [35.33882,
#       139.49043,
#       35.33896,
#       139.49043,
#       35.33901,
#       139.49043,
#       35.33922,
#       139.49043,
#       35.33944,
#       139.49041],
#      'functionalClass': 2,
#      'confidence': 0.91},
#     {'linkId': '17644083201',
#      'length': 79.0,
#      'remainDistance': 3124,
#      'remainTime': 110,
#      'shape': [35.33944,
#       139.49041,
#       35.33969,
#       139.49035,
#       35.33989,
#       139.49027,
#       35.34012,
#       139.49016],
#      'functionalClass': 2,
#      'confidence': 0.85},
#     {'linkId': '-17647150080',
#      'length': 45.07,
#      'remainDistance': 3045,
#      'remainTime': 110,
#      'shape': [35.34012, 139.49016, 35.34007, 139.48986, 35.34004, 139.48967],
#      'functionalClass': 4,
#      'confidence': 0.85},
#     {'linkId': '17664386048',
#      'length': 81.15,
#      'remainDistance': 3000,
#      'remainTime': 107,
#      'shape': [35.34004, 139.48967, 35.34005, 139.48939, 35.34008, 139.48878],
#      'functionalClass': 4,
#      'confidence': 0.85},
#     {'linkId': '17652382720',
#      'length': 80.36,
#      'remainDistance': 2919,
#      'remainTime': 107,
#      'shape': [35.34008, 139.48878, 35.34015, 139.4879],
#      'functionalClass': 4,
#      'confidence': 0.86},
#     {'linkId': '17659747328',
#      'length': 57.28,
#      'remainDistance': 2838,
#      'remainTime': 107,
#      'shape': [35.34015, 139.4879, 35.34019, 139.48727],
#      'functionalClass': 4,
#      'confidence': 0.87},
#     {'linkId': '17641101312',
#      'length': 26.4,
#      'remainDistance': 2781,
#      'remainTime': 107,
#      'shape': [35.34019, 139.48727, 35.34019, 139.48698],
#      'functionalClass': 4,
#      'confidence': 0.87},
#     {'linkId': '-17652381696',
#      'length': 88.41,
#      'remainDistance': 2755,
#      'remainTime': 107,
#      'shape': [35.34019,
#       139.48698,
#       35.34019,
#       139.48693,
#       35.34017,
#       139.48661,
#       35.34014,
#       139.48622,
#       35.34014,
#       139.48614,
#       35.34015,
#       139.48601],
#      'functionalClass': 4,
#      'confidence': 0.87},
#     {'linkId': '-17641485312',
#      'length': 117.45,
#      'remainDistance': 2666,
#      'remainTime': 104,
#      'shape': [35.34015,
#       139.48601,
#       35.3399,
#       139.48578,
#       35.33968,
#       139.48561,
#       35.33941,
#       139.48547,
#       35.33922,
#       139.48543],
#      'functionalClass': 4,
#      'confidence': 0.94},
#     {'linkId': '-17647735808',
#      'length': 20.97,
#      'remainDistance': 2549,
#      'remainTime': 93,
#      'shape': [35.33922, 139.48543, 35.33914, 139.48522],
#      'functionalClass': 4,
#      'confidence': 0.9},
#     {'linkId': '-17647681536',
#      'length': 122.97,
#      'remainDistance': 2528,
#      'remainTime': 93,
#      'shape': [35.33914, 139.48522, 35.33905, 139.48433, 35.33895, 139.48389],
#      'functionalClass': 4,
#      'confidence': 0.9},
#     {'linkId': '-17667632128',
#      'length': 90.02,
#      'remainDistance': 2405,
#      'remainTime': 90,
#      'shape': [35.33895,
#       139.48389,
#       35.33892,
#       139.48374,
#       35.33886,
#       139.48313,
#       35.33884,
#       139.48291],
#      'functionalClass': 4,
#      'confidence': 1.0},
#     {'linkId': '-17383424000',
#      'length': 79.68,
#      'remainDistance': 2315,
#      'remainTime': 89,
#      'shape': [35.33884, 139.48291, 35.3388, 139.48203],
#      'functionalClass': 4,
#      'confidence': 0.88},
#     {'linkId': '-17390246912',
#      'length': 84.4,
#      'remainDistance': 2235,
#      'remainTime': 89,
#      'shape': [35.3388, 139.48203, 35.33875, 139.4811],
#      'functionalClass': 4,
#      'confidence': 0.75},
#     {'linkId': '17376149504',
#      'length': 80.0,
#      'remainDistance': 2151,
#      'remainTime': 89,
#      'shape': [35.33875, 139.4811, 35.3389, 139.48117, 35.33935, 139.48157],
#      'functionalClass': 4,
#      'confidence': 0.75},
#     {'linkId': '17376149505',
#      'length': 104.13,
#      'remainDistance': 2071,
#      'remainTime': 84,
#      'shape': [35.33935,
#       139.48157,
#       35.33954,
#       139.48173,
#       35.33988,
#       139.48199,
#       35.34014,
#       139.48219],
#      'functionalClass': 4,
#      'confidence': 0.88},
#     {'linkId': '17376149506',
#      'length': 18.37,
#      'remainDistance': 1967,
#      'remainTime': 79,
#      'shape': [35.34014, 139.48219, 35.34028, 139.4823],
#      'functionalClass': 4,
#      'confidence': 1.0},
#     {'linkId': '-17654185984',
#      'length': 66.9,
#      'remainDistance': 1948,
#      'remainTime': 67,
#      'shape': [35.34028, 139.4823, 35.33998, 139.48293],
#      'functionalClass': 4,
#      'confidence': 1.0},
#     {'linkId': '-17647609856',
#      'length': 31.23,
#      'remainDistance': 1881,
#      'remainTime': 67,
#      'shape': [35.33998, 139.48293, 35.33984, 139.48323],
#      'functionalClass': 4,
#      'confidence': 0.83},
#     {'linkId': '-17642283008',
#      'length': 31.66,
#      'remainDistance': 1850,
#      'remainTime': 67,
#      'shape': [35.33984, 139.48323, 35.33971, 139.48354],
#      'functionalClass': 4,
#      'confidence': 0.65},
#     {'linkId': '-17643427840',
#      'length': 74.11,
#      'remainDistance': 1819,
#      'remainTime': 67,
#      'shape': [35.33971, 139.48354, 35.33947, 139.4843],
#      'functionalClass': 4,
#      'confidence': 0.65},
#     {'linkId': '-17649682432',
#      'length': 66.2,
#      'remainDistance': 1744,
#      'remainTime': 59,
#      'shape': [35.33947, 139.4843, 35.33925, 139.48498],
#      'functionalClass': 4,
#      'confidence': 0.69},
#     {'linkId': '-17641347072',
#      'length': 24.55,
#      'remainDistance': 1678,
#      'remainTime': 59,
#      'shape': [35.33925, 139.48498, 35.33914, 139.48522],
#      'functionalClass': 4,
#      'confidence': 0.75},
#     {'linkId': '17647735808',
#      'length': 20.97,
#      'remainDistance': 1654,
#      'remainTime': 59,
#      'shape': [35.33914, 139.48522, 35.33922, 139.48543],
#      'functionalClass': 4,
#      'confidence': 0.79},
#     {'linkId': '17639152640',
#      'length': 21.72,
#      'remainDistance': 1633,
#      'remainTime': 59,
#      'shape': [35.33922, 139.48543, 35.33924, 139.48554, 35.33925, 139.48566],
#      'functionalClass': 4,
#      'confidence': 0.81},
#     {'linkId': '17664318464',
#      'length': 111.98,
#      'remainDistance': 1611,
#      'remainTime': 59,
#      'shape': [35.33925, 139.48566, 35.33932, 139.48689],
#      'functionalClass': 4,
#      'confidence': 0.81},
#     {'linkId': '17645835264',
#      'length': 12.42,
#      'remainDistance': 1499,
#      'remainTime': 59,
#      'shape': [35.33932, 139.48689, 35.33933, 139.48703],
#      'functionalClass': 4,
#      'confidence': 0.81},
#     {'linkId': '-17667873792',
#      'length': 81.9,
#      'remainDistance': 1487,
#      'remainTime': 59,
#      'shape': [35.33933,
#       139.48703,
#       35.33937,
#       139.48713,
#       35.33938,
#       139.48737,
#       35.33941,
#       139.48748,
#       35.3394,
#       139.48759,
#       35.33937,
#       139.48765,
#       35.33932,
#       139.48776,
#       35.33926,
#       139.48786],
#      'functionalClass': 4,
#      'confidence': 0.81},
#     {'linkId': '17642933248',
#      'length': 99.05,
#      'remainDistance': 1405,
#      'remainTime': 53,
#      'shape': [35.33926, 139.48786, 35.33999, 139.48791, 35.34015, 139.4879],
#      'functionalClass': 4,
#      'confidence': 0.72},
#     {'linkId': '-17652382720',
#      'length': 80.36,
#      'remainDistance': 1306,
#      'remainTime': 53,
#      'shape': [35.34015, 139.4879, 35.34008, 139.48878],
#      'functionalClass': 4,
#      'confidence': 0.9},
#     {'linkId': '-17664386048',
#      'length': 81.15,
#      'remainDistance': 1225,
#      'remainTime': 49,
#      'shape': [35.34008, 139.48878, 35.34005, 139.48939, 35.34004, 139.48967],
#      'functionalClass': 4,
#      'confidence': 0.74},
#     {'linkId': '17647150080',
#      'length': 45.07,
#      'remainDistance': 1144,
#      'remainTime': 44,
#      'shape': [35.34004, 139.48967, 35.34007, 139.48986, 35.34012, 139.49016],
#      'functionalClass': 4,
#      'confidence': 0.87},
#     {'linkId': '17656833024',
#      'length': 19.06,
#      'remainDistance': 1099,
#      'remainTime': 44,
#      'shape': [35.34012, 139.49016, 35.34016, 139.49036],
#      'functionalClass': 4,
#      'confidence': 1.0},
#     {'linkId': '17664969728',
#      'length': 37.89,
#      'remainDistance': 1080,
#      'remainTime': 44,
#      'shape': [35.34016, 139.49036, 35.34025, 139.49077],
#      'functionalClass': 4,
#      'confidence': 1.0},
#     {'linkId': '17667089408',
#      'length': 91.91,
#      'remainDistance': 1042,
#      'remainTime': 43,
#      'shape': [35.34025,
#       139.49077,
#       35.34032,
#       139.49122,
#       35.34035,
#       139.49138,
#       35.34039,
#       139.49176],
#      'functionalClass': 4,
#      'confidence': 1.0},
#     {'linkId': '-17651906560',
#      'length': 84.5,
#      'remainDistance': 950,
#      'remainTime': 43,
#      'shape': [35.34039, 139.49176, 35.34038, 139.49269],
#      'functionalClass': 4,
#      'confidence': 1.0},
#     {'linkId': '-17640605696',
#      'length': 71.28,
#      'remainDistance': 866,
#      'remainTime': 42,
#      'shape': [35.34038, 139.49269, 35.34037, 139.49348],
#      'functionalClass': 4,
#      'confidence': 0.74},
#     {'linkId': '17669050368',
#      'length': 40.78,
#      'remainDistance': 794,
#      'remainTime': 33,
#      'shape': [35.34037, 139.49348, 35.34037, 139.49393],
#      'functionalClass': 4,
#      'confidence': 1.0},
#     {'linkId': '17657990144',
#      'length': 47.0,
#      'remainDistance': 754,
#      'remainTime': 31,
#      'shape': [35.34037, 139.49393, 35.34039, 139.49444],
#      'functionalClass': 4,
#      'confidence': 0.95},
#     {'linkId': '17663331328',
#      'length': 65.57,
#      'remainDistance': 707,
#      'remainTime': 31,
#      'shape': [35.34039, 139.49444, 35.34046, 139.49516],
#      'functionalClass': 4,
#      'confidence': 0.95},
#     {'linkId': '17648779264',
#      'length': 36.87,
#      'remainDistance': 641,
#      'remainTime': 29,
#      'shape': [35.34046, 139.49516, 35.34049, 139.49557],
#      'functionalClass': 4,
#      'confidence': 1.0},
#     {'linkId': '17638365184',
#      'length': 30.68,
#      'remainDistance': 604,
#      'remainTime': 29,
#      'shape': [35.34049, 139.49557, 35.34049, 139.4959],
#      'functionalClass': 4,
#      'confidence': 1.0},
#     {'linkId': '-17658278912',
#      'length': 24.35,
#      'remainDistance': 574,
#      'remainTime': 27,
#      'shape': [35.34049, 139.4959, 35.34048, 139.49617],
#      'functionalClass': 4,
#      'confidence': 0.98},
#     {'linkId': '-17642129411',
#      'length': 10.81,
#      'remainDistance': 549,
#      'remainTime': 27,
#      'shape': [35.34048, 139.49617, 35.34047, 139.49629],
#      'functionalClass': 4,
#      'confidence': 0.93},
#     {'linkId': '-17642129410',
#      'length': 46.17,
#      'remainDistance': 538,
#      'remainTime': 27,
#      'shape': [35.34047, 139.49629, 35.34046, 139.4968],
#      'functionalClass': 4,
#      'confidence': 0.89},
#     {'linkId': '-17642129409',
#      'length': 61.94,
#      'remainDistance': 492,
#      'remainTime': 27,
#      'shape': [35.34046, 139.4968, 35.34043, 139.49748],
#      'functionalClass': 4,
#      'confidence': 0.87},
#     {'linkId': '-17642129408',
#      'length': 16.07,
#      'remainDistance': 430,
#      'remainTime': 27,
#      'shape': [35.34043, 139.49748, 35.34043, 139.49766],
#      'functionalClass': 4,
#      'confidence': 0.85},
#     {'linkId': '17644811264',
#      'length': 50.06,
#      'remainDistance': 414,
#      'remainTime': 27,
#      'shape': [35.34043, 139.49766, 35.34043, 139.49821],
#      'functionalClass': 4,
#      'confidence': 0.85},
#     {'linkId': '-17666061312',
#      'length': 61.36,
#      'remainDistance': 364,
#      'remainTime': 27,
#      'shape': [35.34043, 139.49821, 35.34033, 139.49824, 35.33993, 139.49849],
#      'functionalClass': 4,
#      'confidence': 0.85},
#     {'linkId': '-17642044416',
#      'length': 67.02,
#      'remainDistance': 303,
#      'remainTime': 23,
#      'shape': [35.33993, 139.49849, 35.33939, 139.49883],
#      'functionalClass': 4,
#      'confidence': 0.96},
#     {'linkId': '-17658225665',
#      'length': 110.17,
#      'remainDistance': 236,
#      'remainTime': 23,
#      'shape': [35.33939, 139.49883, 35.33852, 139.49939],
#      'functionalClass': 4,
#      'confidence': 0.96},
#     {'linkId': '-17658225664',
#      'length': 71.8,
#      'remainDistance': 126,
#      'remainTime': 15,
#      'shape': [35.33852, 139.49939, 35.33795, 139.49976],
#      'functionalClass': 4,
#      'confidence': 0.93},
#     {'linkId': '17661700096',
#      'length': 42.25,
#      'remainDistance': 54,
#      'remainTime': 10,
#      'shape': [35.33795, 139.49976, 35.33811, 139.50018],
#      'functionalClass': 5,
#      'confidence': 0.89},
#     {'linkId': '17650785280',
#      'length': 52.91,
#      'remainDistance': 12,
#      'remainTime': 10,
#      'shape': [35.33811, 139.50018, 35.33834, 139.5007],
#      'functionalClass': 5,
#      'confidence': 0.89}],
#    'trafficTime': 386,
#    'baseTime': 386}],
#  'summary': {'travelTime': 386,
#   'distance': 10258,
#   'baseTime': 386,
#   'trafficTime': 386,
#   'flags': [],
#   'departure': '2021-01-20T04:59:06+09',
#   'arrival': '2021-01-20T05:05:32+09'},
#  'matchedVehicleType': [{'type': 'truck',
#    'subType': 'medium',
#    'confidence': 0.35},
#   {'type': 'truck', 'subType': 'heavy', 'confidence': 0.35},
#   {'type': 'truck', 'subType': 'light', 'confidence': 0.21},
#   {'type': 'car', 'confidence': 0.1}]}

# %%
df_m = pd.json_normalize(response['response']['route'][0]['waypoint'])
df_m
# Out:
#            linkId     spot  confidenceValue  elevation  \
# 0    +17641467904  0.86143             1.00        0.0
# 1    +17641467904  0.86143             1.00        0.0
# 2    +17641467904  0.83717             1.00        0.0
# 3    +17641467904  0.80196             1.00        0.0
# 4    +17641467904  0.78852             1.00        0.0
# 5    +17641467904  0.78852             1.00        0.0
# 6    +17641467904  0.78994             1.00        0.0
# 7    +17641467904  0.82011             1.00        0.0
# 8    +17641467904  0.84953             1.00        0.0
# 9    +17641467904  0.84953             1.00        0.0
# 10   -17650785280  0.22207             0.65        0.0
# 11   -17650785280  0.06948             0.94        0.0
# 12   -17650785280  0.06948             0.97        0.0
# 13   -17650785280  0.04073             0.93        0.0
# 14   -17650785280  0.00000             0.66        0.0
# 15   -17650785280  0.00000             0.60        0.0
# 16   -17650785280  0.00000             0.49        0.0
# 17   -17650785280  0.00000             0.51        0.0
# 18   -17650785280  0.00000             0.50        0.0
# 19   -17650785280  0.00000             0.44        0.0
# 20   -17650785280  0.00000             0.41        0.0
# 21   -17650785280  0.20568             0.70        0.0
# 22   -17650785280  0.18552             1.00        0.0
# 23   -17650785280  0.00000             0.10        0.0
# 24   -17650785280  0.96519             1.00        0.0
# 25   -17650785280  0.00000             0.25        0.0
# 26   -17650785280  0.00000             0.16        0.0
# 27   +17642044416  0.46389             1.00        0.0
# 28   +17666061312  0.46118             0.14        0.0
# 29   +17666061312  0.46118             0.14        0.0
# 30   +17666061312  0.48346             0.13        0.0
# 31   +17666061312  0.49522             0.14        0.0
# 32   +17666061312  0.46118             0.21        0.0
# 33   +17658278912  0.45348             1.00        0.0
# 34   +17651906560  0.11177             1.00        0.0
# 35   -17656833024  0.10907             0.68        0.0
# 36   -17652381696  0.56586             0.97        0.0
# 37   +17661078528  0.71222             1.00        0.0
# 38   -17654185984  0.60895             1.00        0.0
# 39   +17664318464  0.31548             0.19        0.0
# 40   +17664318464  0.32741             0.40        0.0
# 41   -17667873792  0.61425             0.61        0.0
# 42   -17667873792  0.39129             0.88        0.0
# 43   -17667873792  0.40731             1.00        0.0
# 44   -17667873792  0.40731             1.00        0.0
# 45   -17667873792  0.52034             0.20        0.0
# 20                       1       0.0  1611085145004           NaN
# 21                       1       0.0  1611085084954           NaN
# 22                       1       0.0  1611085024944           NaN
# 23                       1       0.0  1611084964905          True
# 24                       1       1.0  1611084904865           NaN
# 25                       1       0.0  1611084844765           NaN
# 26                       1       0.0  1611084784665           NaN
# 27                       5       8.0  1611084724564           NaN
# 28                       6       0.0  1611084664463          True
# 29                       6       0.0  1611084604385           NaN
# 30                       6       0.0  1611084544358           NaN
# 31                       6       0.0  1611084484257           NaN
# 32                       6       3.0  1611084424253           NaN
# 33                      12       0.0  1611084364243          True
# 34                      19       6.0  1611084304160           NaN
# 35                      22       7.0  1611084244156           NaN
# 36                      28       6.0  1611084184121           NaN
# 37                      36       6.0  1611084124029           NaN
# 38                      43       0.0  1611084063923          True
# 39                      51       0.0  1611084003821           NaN
# 40                      51       5.0  1611083943720           NaN
# 41                      53       0.0  1611083883708          True
# 42                      53       0.0  1611083823678           NaN
# 43                      53       0.0  1611083763578           NaN
# 44                      53       0.0  1611083703470           NaN
# 45                      53       0.0  1611083643435           NaN
# 46                      53       0.0  1611083583343           NaN
# 47                      54       0.0  1611083523327           NaN
# 48                      54       0.0  1611083463225           NaN
# 49                      54       0.0  1611083403219           NaN
# 50                      54       0.0  1611083343163           NaN
# 51                      54       0.0  1611083283155           NaN
# 52                      54       3.0  1611083223054           NaN
# 53                      58      12.0  1611083163032           NaN
# 54                      69       1.0  1611083103013          True
# 55                      69       0.0  1611083042911           NaN
# 56                      75      10.0  1611082982890           NaN
# 57                      77       4.0  1611082922869           NaN
# 58                      77       0.0  1611082862850          True
# 59                      77       0.0  1611082802846           NaN
# 60                      77       0.0  1611082742745           NaN
# 61                      77       0.0  1611082682678           NaN
# 62                      77       0.0  1611082622662           NaN
# 63                      77       0.0  1611082562631           NaN
# 64                      77       0.0  1611082502551           NaN
# 65                      77       0.0  1611082442490           NaN
# 66                      77       0.0  1611082382487           NaN
# 67                      77       0.0  1611082322445           NaN
# 68                      77       0.0  1611082262342           NaN
# 69                      77       1.0  1611082202240           NaN
# 70                      77       1.0  1611082082193           NaN
# 71                      77       1.0  1611082022092           NaN
# 72                      77       2.0  1611081962069           NaN
# 73                      77       1.0  1611081902004          True
# 74                      77       0.0  1611081841964           NaN
# 75                      90       0.0  1611081781955           NaN
# 76                     101       0.0  1611081721871           NaN
# 77                     101       0.0  1611081661774          True
# 78                     102       1.0  1611081601670           NaN
# 79                     102       0.0  1611081541578           NaN
# 80                     102       1.0  1611081481569           NaN
# 81                     103      10.0  1611081421516           NaN
# 82                     106       9.0  1611081361409           NaN
# 83                     118      10.0  1611081301301           NaN
# 84                     121       0.0  1611081241230          True
# 85                     126       5.0  1611081181217           NaN
# 86                     126       0.0  1611081121115          True
# 87                     126       0.0  1611081061108           NaN
# 88                     127       5.0  1611081001045           NaN
# 89                     129       6.0  1611080941031           NaN
# 90                     129       0.0  1611080880929          True
# 91                     130       9.0  1611080820863           NaN
# 92                     133       0.0  1611080760763          True
# 93                     133       0.0  1611080700708           NaN
# 94                     133       0.0  1611080640690           NaN
# 95                     133       0.0  1611080580678           NaN
# 96                     133       0.0  1611080520669           NaN
# 97                     133       0.0  1611080460643           NaN
# 98                     133       3.0  1611080400541           NaN
# 99                     139       7.0  1611080340439           NaN
# 100                    146       0.0  1611080280338          True
# 101                    146       0.0  1611080220232           NaN
# 102                    146       0.0  1611080160131           NaN
# 103                    146       0.0  1611080100090           NaN
# 104                    146       4.0  1611080040085           NaN
# 105                    148       0.0  1611079980022          True
# 106                    149       1.0  1611079919926           NaN
# 107                    152       0.0  1611079859817           NaN
# 108                    152       0.0  1611079799723           NaN
# 109                    154       0.0  1611079739614           NaN
# 110                    155       2.0  1611079679505           NaN
# 111                    155       0.0  1611079619412          True
# 112                    155       0.0  1611079559306           NaN
# 113                    155       0.0  1611079499200           NaN
# 114                    155       3.0  1611079439099           NaN
# 115                    156       3.0  1611079379006           NaN
# 116                    158       0.0  1611079318998          True
# 117                    160       8.0  1611079258945           NaN
# 118                    167       0.0  1611079198935          True
# 119                    167       0.0  1611079138931           NaN
# 120                    167       0.0  1611079078901           NaN
# 121                    167       0.0  1611079018809           NaN
# 122                    167       0.0  1611078958791           NaN
# 123                    167       0.0  1611078898713           NaN
# 124                    167       0.0  1611078838658           NaN
# 125                    169       6.0  1611078778634           NaN
# 126                    172       0.0  1611078718576          True
# 127                    172       2.0  1611078658565           NaN
# 128                    172       1.0  1611078598542          True
# 129                    172       0.0  1611078538522           NaN
# 130                    172       0.0  1611078478469           NaN
# 131                    172       0.0  1611078418445           NaN
# 132                    172       0.0  1611078358343          True
# 133                    172       0.0  1611078298339           NaN
# 134                    172       0.0  1611078238320           NaN
# 135                    172       0.0  1611078178318           NaN
# 136                    172       1.0  1611078118219           NaN
# 137                    172       0.0  1611078058195           NaN
# 138                    172       0.0  1611077998140           NaN
# 139                    172       0.0  1611077938052           NaN
# 140                    172       0.0  1611077878048           NaN
# 141                    172       0.0  1611077818047           NaN
# 142                    172       0.0  1611077757997           NaN
# 143                    172       0.0  1611077697895           NaN
# 144                    172       0.0  1611077637810          True
# 145                    172       0.0  1611077577730           NaN
# 146                    172       0.0  1611077517629           NaN
# 147                    172       0.0  1611077457524           NaN
#
#      breakDuration  mappedPosition.latitude  mappedPosition.longitude  \
# 0        -600566.0                 35.33829                 139.50073
# 1              NaN                 35.33829                 139.50073
# 2              NaN                 35.33828                 139.50073
# 3              NaN                 35.33827                 139.50074
# 4              NaN                 35.33826                 139.50074
# 5              NaN                 35.33826                 139.50074
# 6              NaN                 35.33826                 139.50074
# 7              NaN                 35.33827                 139.50074
# 8              NaN                 35.33828                 139.50073
# 9              NaN                 35.33828                 139.50073
# 10             NaN                 35.33829                 139.50058
# 11       -600489.0                 35.33832                 139.50066
# 12             NaN                 35.33832                 139.50066
# 13             NaN                 35.33833                 139.50068
# 14             NaN                 35.33834                 139.50070
# 15             NaN                 35.33834                 139.50070
# 16             NaN                 35.33834                 139.50070
# 17             NaN                 35.33834                 139.50070
# 18             NaN                 35.33834                 139.50070
# 122                  35.340243                  139.498472
# 123                  35.340377                  139.498472
# 124                  35.340393                  139.498474
# 125                  35.338817                  139.499121
# 126                  35.338267                  139.500819
# 127                  35.338394                  139.500805
# 128                  35.338340                  139.500799
# 129                  35.338277                  139.500856
# 130                  35.338272                  139.500658
# 131                  35.338275                  139.500682
# 132                  35.338320                  139.500715
# 133                  35.338314                  139.500712
# 134                  35.338311                  139.500723
# 135                  35.338314                  139.500733
# 136                  35.338313                  139.500778
# 137                  35.338273                  139.500697
# 138                  35.338276                  139.500694
# 139                  35.338283                  139.500705
# 140                  35.338284                  139.500726
# 141                  35.338283                  139.500711
# 142                  35.338281                  139.500683
# 143                  35.338239                  139.500629
# 144                  35.338277                  139.500636
# 145                  35.338271                  139.500628
# 146                  35.338268                  139.500620
# 147                  35.338239                  139.500628

# %%
arr = df_m.iloc[:, 13:15].values
print(arr)

# 線の地図レイヤへの追加
line = folium.vector_layers.PolyLine(
            locations= arr,        
            color='red',                                  
            weight=2)
m.add_child(line)
# Out:
# [[ 35.33829 139.50073]
#  [ 35.33829 139.50073]
#  [ 35.33828 139.50073]
#  [ 35.33827 139.50074]
#  [ 35.33826 139.50074]
#  [ 35.33826 139.50074]
#  [ 35.33826 139.50074]
#  [ 35.33827 139.50074]
#  [ 35.33828 139.50073]
#  [ 35.33828 139.50073]
#  [ 35.33829 139.50058]
#  [ 35.33832 139.50066]
#  [ 35.33832 139.50066]
#  [ 35.33833 139.50068]
#  [ 35.33834 139.5007 ]
#  [ 35.33834 139.5007 ]
#  [ 35.33834 139.5007 ]
#  [ 35.33834 139.5007 ]
#  [ 35.33834 139.5007 ]
#  [ 35.33834 139.5007 ]
#  [ 35.33834 139.5007 ]
#  [ 35.33829 139.50059]
#  [ 35.3383  139.5006 ]
#  [ 35.33834 139.5007 ]
#  [ 35.33833 139.50068]
#  [ 35.33834 139.5007 ]
#  [ 35.33834 139.5007 ]
#  [ 35.33964 139.49867]
#  [ 35.34016 139.49835]
#  [ 35.34016 139.49835]
#  [ 35.34017 139.49834]
#  [ 35.34017 139.49834]
#  [ 35.34016 139.49835]
#  [ 35.34048 139.49605]
#  [ 35.34038 139.49259]
#  [ 35.34012 139.49018]
#  [ 35.34017 139.48656]
#  [ 35.34124 139.48383]
#  [ 35.34016 139.48255]
#  [ 35.33927 139.48605]
#  [ 35.33927 139.48606]
#  [ 35.33938 139.48737]
#  [ 35.33938 139.48737]
#  [ 35.33938 139.48738]
#  [ 35.33938 139.48738]
#  [ 35.33941 139.48748]
#  [ 35.3394  139.48759]
#  [ 35.33955 139.48788]
#  [ 35.33959 139.48788]
#  [ 35.33926 139.48786]
#  [ 35.33927 139.48786]
#  [ 35.33932 139.48786]
#  [ 35.33983 139.4879 ]
#  [ 35.33982 139.4903 ]
#  [ 35.33637 139.49001]
#  [ 35.3363  139.48998]
#  [ 35.3311  139.48815]
#  [ 35.32906 139.4876 ]
#  [ 35.32935 139.48766]
#  [ 35.32935 139.48766]
#  [ 35.32934 139.48765]
#  [ 35.32933 139.48765]
#  [ 35.32934 139.48765]
#  [ 35.32931 139.48765]
#  [ 35.32929 139.48765]
#  [ 35.32927 139.48764]
#  [ 35.32925 139.48764]
#  [ 35.32923 139.48763]
#  [ 35.32937 139.48766]
#  [ 35.32935 139.48766]
#  [ 35.3294  139.48767]
#  [ 35.32968 139.48772]
#  [ 35.32968 139.48772]
#  [ 35.32968 139.48772]
#  [ 35.32972 139.48773]
#  [ 35.33723 139.4898 ]
#  [ 35.32972 139.48773]
#  [ 35.32961 139.48771]
#  [ 35.32972 139.48773]
#  [ 35.32952 139.48769]
#  [ 35.32972 139.48773]
#  [ 35.33026 139.48786]
#  [ 35.33342 139.48896]
#  [ 35.33864 139.49042]
#  [ 35.34007 139.48983]
#  [ 35.34019 139.48698]
#  [ 35.34018 139.48684]
#  [ 35.34017 139.48663]
#  [ 35.34015 139.48601]
#  [ 35.33914 139.48522]
#  [ 35.33909 139.48476]
#  [ 35.33892 139.48372]
#  [ 35.33904 139.48129]
#  [ 35.33903 139.48129]
#  [ 35.33904 139.48129]
#  [ 35.33906 139.48132]
#  [ 35.33899 139.48125]
#  [ 35.33904 139.48129]
#  [ 35.33904 139.48129]
#  [ 35.33947 139.48428]
#  [ 35.33937 139.48721]
#  [ 35.33937 139.48719]
#  [ 35.33937 139.48719]
#  [ 35.33937 139.48718]
#  [ 35.33937 139.48765]
#  [ 35.34012 139.48822]
#  [ 35.34006 139.48925]
#  [ 35.34018 139.49045]
#  [ 35.34018 139.49044]
#  [ 35.34039 139.49187]
#  [ 35.34038 139.49269]
#  [ 35.34038 139.49269]
#  [ 35.34038 139.49269]
#  [ 35.34038 139.49269]
#  [ 35.34038 139.49282]
#  [ 35.34037 139.49369]
#  [ 35.34041 139.49462]
#  [ 35.34049 139.49584]
#  [ 35.34019 139.49833]
#  [ 35.34018 139.49833]
#  [ 35.34016 139.49835]
#  [ 35.34016 139.49835]
#  [ 35.34018 139.49833]
#  [ 35.34029 139.49826]
#  [ 35.3403  139.49826]
#  [ 35.33884 139.49918]
#  [ 35.33834 139.5007 ]
#  [ 35.33834 139.5007 ]
#  [ 35.33834 139.5007 ]
#  [ 35.33834 139.5007 ]
#  [ 35.33831 139.50063]
#  [ 35.33832 139.50065]
#  [ 35.33834 139.5007 ]
#  [ 35.33834 139.5007 ]
#  [ 35.33834 139.5007 ]
#  [ 35.33834 139.5007 ]
#  [ 35.33834 139.5007 ]
#  [ 35.33832 139.50066]
#  [ 35.33832 139.50066]
#  [ 35.33833 139.50067]
#  [ 35.33834 139.50069]
#  [ 35.33833 139.50068]
#  [ 35.33832 139.50066]
#  [ 35.33829 139.50059]
#  [ 35.3383  139.50062]
#  [ 35.3383  139.50061]
#  [ 35.3383  139.50061]
#  [ 35.33834 139.5007 ]]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_55820580be2443b5a6778f3e02986717%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_55820580be2443b5a6778f3e02986717%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_55820580be2443b5a6778f3e02986717%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_55820580be2443b5a6778f3e02986717%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.338528%2C%20139.487632%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
#map matching前後の比較（blue：前/red：後）
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_55820580be2443b5a6778f3e02986717%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_55820580be2443b5a6778f3e02986717%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_55820580be2443b5a6778f3e02986717%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_55820580be2443b5a6778f3e02986717%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.338528%2C%20139.487632%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ## 駐車位置プロット（mapmatchあり）

# %%
print(arr.shape)
arr[:5]
# Out:
# (148, 2)
# array([[ 35.33829, 139.50073],
#        [ 35.33829, 139.50073],
#        [ 35.33828, 139.50073],
#        [ 35.33827, 139.50074],
#        [ 35.33826, 139.50074]])

# %%
#空の配列を用意
array = []
# 駐車と見做す誤差の値を設定
x = 0.00002

for num in range(1, len(arr)):
# 以下for文
    margin_lat = abs(arr[num-1][0] - arr[num][0])
    print('margin_lat: ', margin_lat)
    margin_lng = abs(arr[num-1][1] - arr[num][1])
    print('margin_lng: ', margin_lng)
    # if文：「前の時刻との緯度差分 + 経度差分 <= 0.00002」であれば駐車していると見做す
    margin = margin_lat + margin_lng
    if margin <= x:
        print('駐車位置')
        array.append(num)
    else:
        print('移動中')
# Out:
# margin_lat:  0.0
# margin_lng:  0.0
# 駐車位置
# margin_lat:  1.0000000003174137e-05
# margin_lng:  0.0
# 駐車位置
# margin_lat:  9.999999996068709e-06
# margin_lng:  1.0000000003174137e-05
# 駐車位置
# margin_lat:  1.0000000003174137e-05
# margin_lng:  0.0
# 駐車位置
# margin_lat:  0.0
# margin_lng:  0.0
# 駐車位置
# margin_lat:  0.0
# margin_lng:  0.0
# 駐車位置
# margin_lat:  1.0000000003174137e-05
# margin_lng:  0.0
# 駐車位置
# margin_lat:  9.999999996068709e-06
# margin_lng:  1.0000000003174137e-05
# 駐車位置
# margin_lat:  0.0
# margin_lng:  0.0
# 駐車位置
# margin_lat:  1.0000000003174137e-05
# margin_lng:  0
# 移動中
# margin_lat:  9.999999996068709e-06
# margin_lng:  1.9999999977926564e-05
# 移動中
# margin_lat:  3.0000000002416982e-05
# margin_lng:  7.000000002221896e-05
# 移動中
# margin_lat:  9.999999996068709e-06
# margin_lng:  3.000000000952241e-05
# 移動中
# margin_lat:  0.0
# margin_lng:  1.0000000003174137e-05
# 駐車位置
# margin_lat:  0.0
# margin_lng:  0.0
# 駐車位置
# margin_lat:  4.000000000559112e-05
# margin_lng:  9.000000000014552e-05
# 移動中

# %%
df_p = pd.DataFrame(a[array])
print(df_p.shape)
df_p.head()
# Out:
# (59, 2)
#            0           1
# 0  35.338303  139.500766
# 1  35.338294  139.500772
# 2  35.338265  139.500737
# 3  35.338253  139.500722
# 4  35.338254  139.500717

# %% [markdown]
# ## 駐車点を統一

# %%
# マスタを作成
stop_lat = [0]
stop_lng = [0]
y = 0.0008
count = 0

# %%
# 59行ある駐車位置候補場所から１つずつ取り出す
for p_lat, p_lng in zip(df_p[0].values, df_p[1].values):
    print("p_lat, p_lng", p_lat, p_lng)
    # 確定駐車位置から0個目を取り出す（初めは[0,0]）
    for s_lat, s_lng in zip(stop_lat, stop_lng):
        print("s_lat, s_lng:", s_lat, s_lng)
        # 駐車位置候補の0個目と、確定駐車位置の0個目の差分を取る
        margin_lat_after = abs(s_lat - p_lat)
        margin_lng_after = abs(s_lng - p_lng)
        margin_after = margin_lat_after + margin_lng_after
        # marginが一定以下（=同じ駐車位置）だったらカウントして、除外対象とする
        if margin_after  <= y:
            count = count + 1
            print('count:', count)
    #再度まで見た後、カウント数が0個だったら（=どの既存駐車位置にも当てはまらなかったら）記録
    if count == 0:
        stop_lat.append(p_lat)
        stop_lng.append(p_lng)
    else:
        print("重複、スキップ")
    #カウントをリセット
    count = 0
# Out:
# p_lat, p_lng 35.33830283 139.50076558
# s_lat, s_lng: 0 0
# p_lat, p_lng 35.33829415 139.50077231
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33826498 139.50073697
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33825346 139.50072245
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33825408 139.50071666
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33824909 139.50070919
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33825934 139.50070044
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33826772 139.50068763
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.3382739 139.50069065
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33828721 139.50069256
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.338301 139.50076329
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33829898 139.50078262
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33830426 139.50078106
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33830742 139.50078375
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.3383095 139.50079755
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33831769 139.50080663
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.3382736 139.5006193
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33819186 139.50094361
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.34028769 139.49864509
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# p_lat, p_lng 35.34029617 139.49865026
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.34029454 139.49862883
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.34023312 139.49855135
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33938469 139.48605316
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# p_lat, p_lng 35.33932948 139.4873765
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# p_lat, p_lng 35.33934437 139.48739978
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33934035 139.48739833
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33929014 139.48745115
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.3293155 139.48791592
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# p_lat, p_lng 35.32930204 139.48793563
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.32929445 139.48796048
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.32929413 139.48797865
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.329253 139.48797076
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.32919776 139.4880241
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.32915146 139.48807138
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.32946755 139.48819214
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.32899919 139.488321
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33921252 139.48098767
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# p_lat, p_lng 35.33922461 139.48098143
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.3391091 139.48098082
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.33946593 139.48718625
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# count: 1
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# 重複、スキップ
# p_lat, p_lng 35.33950259 139.48717059
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# count: 1
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# 重複、スキップ
# p_lat, p_lng 35.34020943 139.49043245
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# p_lat, p_lng 35.34019373 139.49236228
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# p_lat, p_lng 35.34022409 139.4923027
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# s_lat, s_lng: 35.34019373 139.49236228
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.34023651 139.49232954
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# s_lat, s_lng: 35.34019373 139.49236228
# count: 1
# 重複、スキップ
# p_lat, p_lng 35.34025547 139.49850724
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# count: 1
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# s_lat, s_lng: 35.34019373 139.49236228
# 重複、スキップ
# p_lat, p_lng 35.34023244 139.49852207
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# count: 1
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# s_lat, s_lng: 35.34019373 139.49236228
# 重複、スキップ
# p_lat, p_lng 35.34039316 139.49847376
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# s_lat, s_lng: 35.34028769 139.49864509
# count: 1
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# s_lat, s_lng: 35.34019373 139.49236228
# 重複、スキップ
# p_lat, p_lng 35.33839352 139.50080493
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# s_lat, s_lng: 35.34019373 139.49236228
# 重複、スキップ
# p_lat, p_lng 35.33834023 139.50079875
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# s_lat, s_lng: 35.34019373 139.49236228
# 重複、スキップ
# p_lat, p_lng 35.33827677 139.50085612
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# s_lat, s_lng: 35.34019373 139.49236228
# 重複、スキップ
# p_lat, p_lng 35.33831393 139.50071217
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# s_lat, s_lng: 35.34019373 139.49236228
# 重複、スキップ
# p_lat, p_lng 35.33831082 139.5007235
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# s_lat, s_lng: 35.34019373 139.49236228
# 重複、スキップ
# p_lat, p_lng 35.33831433 139.50073318
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# s_lat, s_lng: 35.34019373 139.49236228
# 重複、スキップ
# p_lat, p_lng 35.33831278 139.5007776
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# s_lat, s_lng: 35.34019373 139.49236228
# 重複、スキップ
# p_lat, p_lng 35.33827649 139.50069365
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# s_lat, s_lng: 35.34019373 139.49236228
# 重複、スキップ
# p_lat, p_lng 35.33828275 139.50070454
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# s_lat, s_lng: 35.34019373 139.49236228
# 重複、スキップ
# p_lat, p_lng 35.33827109 139.50062819
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# s_lat, s_lng: 35.34019373 139.49236228
# 重複、スキップ
# p_lat, p_lng 35.33826835 139.50062026
# s_lat, s_lng: 0 0
# s_lat, s_lng: 35.33830283 139.50076558
# count: 1
# s_lat, s_lng: 35.34028769 139.49864509
# s_lat, s_lng: 35.33938469 139.48605316
# s_lat, s_lng: 35.33932948 139.4873765
# s_lat, s_lng: 35.3293155 139.48791592
# s_lat, s_lng: 35.33921252 139.48098767
# s_lat, s_lng: 35.34020943 139.49043245
# s_lat, s_lng: 35.34019373 139.49236228
# 重複、スキップ

# %%
df_s = pd.DataFrame({'lat': stop_lat[1:], 'lng': stop_lng[1:]})
print(df_s.shape)
df_s.head(3)
# Out:
# (8, 2)
#          lat         lng
# 0  35.338303  139.500766
# 1  35.340288  139.498645
# 2  35.339385  139.486053

# %%
# マーカーの地図レイヤへの追加
for i, row in df_s.iterrows():
    folium.Marker(
        location=[row['lat'], row['lng']],
        popup='駐車位置',
        icon=folium.Icon(color='blue')
    ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_55820580be2443b5a6778f3e02986717%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_55820580be2443b5a6778f3e02986717%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_55820580be2443b5a6778f3e02986717%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_55820580be2443b5a6778f3e02986717%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.338528%2C%20139.487632%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ## 渡すデータ
# ### 走行データ（mapmatch前）

# %%
# df
df_before = pd.DataFrame({'latitude': a[:,0], 'longitude': a[:,1]})
print(df_before.shape)
df_before.head(3)
# Out:
# (148, 2)
#     latitude   longitude
# 0  35.338304  139.500769
# 1  35.338303  139.500766
# 2  35.338294  139.500772

# %%
# nparray
arr_before = a
print(arr_before.shape)
arr_before[:3]
# Out:
# (148, 2)
# array([[ 35.33830382, 139.50076906],
#        [ 35.33830283, 139.50076558],
#        [ 35.33829415, 139.50077231]])

# %% [markdown]
# ### 走行データ（mapmatch後）

# %%
# df
df_after = df_m.iloc[:, 13:15]
print(df_after.shape)
df_after.head(3)
# Out:
# (148, 2)
#    mappedPosition.latitude  mappedPosition.longitude
# 0                 35.33829                 139.50073
# 1                 35.33829                 139.50073
# 2                 35.33828                 139.50073

# %%
# nparray
arr_after = df_m.iloc[:, 13:15].values
print(arr_after.shape)
arr_after[:3]
# Out:
# (148, 2)
# array([[ 35.33829, 139.50073],
#        [ 35.33829, 139.50073],
#        [ 35.33828, 139.50073]])

# %% [markdown]
# ### Stoppoint

# %%
# df
print(df_s.shape)
df_s.head(3)
# Out:
# (8, 2)
#          lat         lng
# 0  35.338303  139.500766
# 1  35.340288  139.498645
# 2  35.339385  139.486053

# %%
# nparray
arr_s = df_s.values
print(arr_s.shape)
arr_s[:3]
# Out:
# (8, 2)
# array([[ 35.33830283, 139.50076558],
#        [ 35.34028769, 139.49864509],
#        [ 35.33938469, 139.48605316]])
